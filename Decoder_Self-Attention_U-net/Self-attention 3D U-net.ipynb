# %%
pwd
# Out:
# '/scratch/hp2173/mri'

# %% [markdown]
# # 2.Preprocess the Datasets

# %%
pip install nibabel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nibabel in /home/hp2173/.local/lib/python3.8/site-packages (3.2.1)
# Requirement already satisfied: numpy>=1.14 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages/numpy-1.19.2-py3.8-linux-x86_64.egg (from nibabel) (1.19.2)
# Requirement already satisfied: packaging>=14.3 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from nibabel) (20.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from packaging>=14.3->nibabel) (2.4.7)
# Requirement already satisfied: six in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from packaging>=14.3->nibabel) (1.15.0)
# WARNING: You are using pip version 20.2.3; however, version 21.1.1 is available.
# You should consider upgrading via the '/share/apps/python/3.8.6/intel/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
from nibabel.testing import data_path
import nibabel as nib
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1) Visualize the MRI images

# %%
T1_weighted_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_mprage_pp.nii').get_data()
T2_weighted_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_t2_pp.nii').get_data()
PD_weighted_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_pd_pp.nii').get_data()
T2_weighted_flair_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_flair_pp.nii').get_data()
mask1_example = nib.load('/scratch/hp2173/training/training01/masks/training01_01_mask1.nii').get_data()
mask2_example = nib.load('/scratch/hp2173/training/training01/masks/training01_01_mask2.nii').get_data()
plt.figure(figsize=(25,10))
plt.subplot(2,4,1)
plt.imshow(T1_weighted_example[:,:,90],'gray')
plt.title('T1_weighted_example')
plt.subplot(2,4,2)
plt.imshow(T2_weighted_example[:,:,90],'gray')
plt.title('T2_weighted_example')
plt.subplot(2,4,3)
plt.imshow(PD_weighted_example[:,:,90],'gray')
plt.title('PD_weighted_example')
plt.subplot(2,4,4)
plt.imshow(T2_weighted_flair_example[:,:,90],'gray')
plt.title('T2_weighted_flair_example')
plt.subplot(2,4,5)
plt.imshow(mask1_example[:,:,90],'gray')
plt.title('mask1_example')
plt.subplot(2,4,6)
plt.imshow(mask2_example[:,:,90],'gray')
plt.title('mask2_example')

plt.pause(3)
# Out:
# <ipython-input-3-daae39f04b2f>:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   T1_weighted_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_mprage_pp.nii').get_data()
# <ipython-input-3-daae39f04b2f>:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   T2_weighted_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_t2_pp.nii').get_data()
# <ipython-input-3-daae39f04b2f>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   PD_weighted_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_pd_pp.nii').get_data()
# <ipython-input-3-daae39f04b2f>:4: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   T2_weighted_flair_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_flair_pp.nii').get_data()
# <ipython-input-3-daae39f04b2f>:5: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1_example = nib.load('/scratch/hp2173/training/training01/masks/training01_01_mask1.nii').get_data()
# <ipython-input-3-daae39f04b2f>:6: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2_example = nib.load('/scratch/hp2173/training/training01/masks/training01_01_mask2.nii').get_data()

# %%
# ipywidgets for some interactive plots
from ipywidgets.widgets import * 
import ipywidgets as widgets
# slide through dicom images using a slide bar 
def dicom_animation(x):
    plt.figure(figsize=(20,10))
    plt.imshow(T1_weighted_example[:,:,x],'gray')
    return x
interact(dicom_animation, x=(0, len(T1_weighted_example)-1))
# Out:
# interactive(children=(IntSlider(value=90, description='x', max=180), Output()), _dom_classes=('widget-interact…
# <function __main__.dicom_animation(x)>

# %% [markdown]
# ## 2) Define function to process 2 raters' groundtruth

# %%
def weight_ground_truth(mask1_path, mask2_path):
  mask1=nib.load(mask1_path).get_data()
  mask2=nib.load(mask2_path).get_data()
  if mask1.shape==mask2.shape:
    fig_shape = mask1.shape 
  else:
    print('Number inconformity for mask, double check path!')
  
  n=fig_shape[2]

  mask_and_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)
  mask_or_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)
  mask_rnd_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)

  for i in range(n):
    mask_and_weight[:,:,i] = mask1[:,:,i] & mask2[:,:,i]
    mask_or_weight[:,:,i] = mask1[:,:,i] | mask2[:,:,i]
    mask_rnd_weight = (mask_or_weight - mask_and_weight)*np.random.randint(0,2,(fig_shape[0],fig_shape[1],n)) + mask_and_weight


  return mask_and_weight, mask_or_weight, mask_rnd_weight

# %%
root = '/scratch/hp2173/training/'
#mask_or_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)
#mask_and_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)
mask1_path = os.path.join(root,'training01/masks/training01_01_mask1.nii')
mask2_path = os.path.join(root,'training01/masks/training01_01_mask2.nii')
mask3_path = os.path.join(root,'training02/masks/training02_02_mask1.nii')
mask4_path = os.path.join(root,'training02/masks/training02_02_mask2.nii')

mask_and_weight, mask_or_weight, mask_rnd_weight = weight_ground_truth(mask1_path, mask2_path)
mask_and_weight2, mask_or_weight2, mask_rnd_weight2 = weight_ground_truth(mask3_path, mask4_path)

plt.figure(figsize=(25,10))
plt.subplot(2,3,1)
plt.imshow(mask_and_weight[:,:,90],'gray')
plt.title('mask_and_weight')
plt.subplot(2,3,2)
plt.imshow(mask_or_weight[:,:,90],'gray')
plt.title('mask_or_weight')
plt.subplot(2,3,3)
plt.imshow(mask_rnd_weight[:,:,90],'gray')
plt.title('mask_rnd_weight')
plt.subplot(2,3,4)
plt.imshow(mask_and_weight2[:,:,90],'gray')
plt.title('mask_and_weight')
plt.subplot(2,3,5)
plt.imshow(mask_or_weight2[:,:,90],'gray')
plt.title('mask_or_weight')
plt.subplot(2,3,6)
plt.imshow(mask_rnd_weight2[:,:,90],'gray')
plt.title('mask_rnd_weight')
# Out:
# <ipython-input-5-527bb657da25>:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1=nib.load(mask1_path).get_data()
# <ipython-input-5-527bb657da25>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2=nib.load(mask2_path).get_data()
# Text(0.5, 1.0, 'mask_rnd_weight')

# %%
root = '/content/gdrive/MyDrive/ImageVedioPrecessingProject/training/'
#mask_or_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)
#mask_and_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)


mask_and_weight, mask_or_weight, mask_rnd_weight = weight_ground_truth(mask1_path, mask2_path)
plt.figure(figsize=(25,10))
plt.subplot(1,3,1)
plt.imshow(mask_and_weight[:,:,90],'gray')
plt.title('mask_and_weight')
plt.subplot(1,3,2)
plt.imshow(mask_or_weight[:,:,90],'gray')
plt.title('mask_or_weight')
plt.subplot(1,3,3)
plt.imshow(mask_rnd_weight[:,:,90],'gray')
plt.title('mask_rnd_weight')
# Out:
# <ipython-input-5-527bb657da25>:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1=nib.load(mask1_path).get_data()
# <ipython-input-5-527bb657da25>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2=nib.load(mask2_path).get_data()
# Text(0.5, 1.0, 'mask_rnd_weight')

# %% [markdown]
# ## 3) Make the custom dataset

# %%
import glob

# %%
base_path = '/scratch/hp2173/training/'
second_path_list = ['training01/','training02/','training03/','training04/','training05/']
mri_list = []
mask1_list = []
mask2_list = []
for i in range(5):
    timepoint1_path = os.path.join(base_path, second_path_list[i], 'preprocessed/*_01_*.nii')
    timepoint2_path = os.path.join(base_path, second_path_list[i], 'preprocessed/*_02_*.nii')
    timepoint3_path = os.path.join(base_path, second_path_list[i], 'preprocessed/*_03_*.nii')
    timepoint4_path = os.path.join(base_path, second_path_list[i], 'preprocessed/*_04_*.nii')
    if i==2:
        timepoint5_path = os.path.join(base_path, second_path_list[i], 'preprocessed/*_05_*.nii')
    mask1_path = os.path.join(base_path, second_path_list[i], 'masks/*1.nii')
    mask2_path = os.path.join(base_path, second_path_list[i], 'masks/*2.nii')
    timepoint1_list = sorted(glob.glob(timepoint1_path))
    timepoint2_list = sorted(glob.glob(timepoint2_path))
    timepoint3_list = sorted(glob.glob(timepoint3_path))
    timepoint4_list = sorted(glob.glob(timepoint4_path))
    if i==2:
        timepoint5_list = sorted(glob.glob(timepoint5_path))
    mri_list.append(timepoint1_list)
    mri_list.append(timepoint2_list)
    mri_list.append(timepoint3_list)
    mri_list.append(timepoint4_list)
    if i==2:
        mri_list.append(timepoint5_list)
    mask1_list = mask1_list + sorted(glob.glob(mask1_path))
    mask2_list = mask2_list + sorted(glob.glob(mask2_path))
print('Data Collected:', len(mri_list))
print('Mask1 Collected:', len(mask1_list))
print('Mask2 Collected:', len(mask2_list))
# Out:
# Data Collected: 21
# Mask1 Collected: 21
# Mask2 Collected: 21

# %%
# 0-3:training 1(4 time points)
# 4-7:training 2(4 time points)
# 8-12:training 3(5 time points)
# 13-16:training 4(4 time points)
# 17-20:training 5(4 time points)
# order in one training set: t2_flair_weight, t1_weight, pd_weight, t2_weight

#Display one timepoint(4 type MRI) for one of the training set
index = 0
for i in range(4):
    ex = nib.load(mri_list[0][index+i]).get_data()
    ms1 = nib.load(mask1_list[0]).get_data()
    ms2 = nib.load(mask2_list[0]).get_data()
    plt.figure(figsize=(15,25))
    plt.subplot(5,3,3*i+1)
    plt.imshow(ex[:,:,90],'gray')
    plt.subplot(5,3,3*i+2)
    plt.imshow(ms1[:,:,90],'gray')
    plt.subplot(5,3,3*i+3)
    plt.imshow(ms2[:,:,90],'gray')
# Out:
# <ipython-input-5-bbfdd6332bd2>:11: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   ex = nib.load(mri_list[0][index+i]).get_data()
# <ipython-input-5-bbfdd6332bd2>:12: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   ms1 = nib.load(mask1_list[0]).get_data()
# <ipython-input-5-bbfdd6332bd2>:13: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   ms2 = nib.load(mask2_list[0]).get_data()

# %%
from random import shuffle
def shuffle_two_lists(listA, listB, listC):
  temp = list(zip(listA, listB, listC))
  shuffle(temp)
  return zip(*temp)
train_split_ratio = 0.8
test_split_ratio = 0.1
num_samples = len(mri_list)

train_size = int(num_samples * train_split_ratio)
test_size = int(num_samples * test_split_ratio)
val_size = num_samples - train_size - test_size
mri_list_shuffled, mask1_list_shuffled, mask2_list_shuffled = shuffle_two_lists(mri_list, mask1_list, mask2_list)

train_img_list, train_label1_list, train_label2_list = mri_list_shuffled[:train_size], mask1_list_shuffled[:train_size], mask2_list_shuffled[:train_size]
val_img_list, val_label1_list, val_label2_list = mri_list_shuffled[train_size:train_size+ val_size], mask1_list_shuffled[train_size:train_size + val_size], mask2_list_shuffled[train_size:train_size + val_size]
test_img_list, test_label1_list, test_label2_list = mri_list_shuffled[train_size+ val_size:], mask1_list_shuffled[train_size+ val_size:], mask2_list_shuffled[train_size+ val_size:]

print ("Training set size: {}". format(len(train_img_list)))
print ("Validation set size: {}". format(len(val_img_list)))
print ("Test set size: {}". format(len(test_img_list)))
# Out:
# Training set size: 16
# Validation set size: 3
# Test set size: 2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
from torchvision import transforms, datasets
from torch.utils.data import Dataset
from tqdm import tqdm

class MRIDataset(Dataset):
    def __init__(self, img_path_list, label1_path_list, label2_path_list, RULE = 'and', IF_TRAIN= False):
        self.mri_path_list = img_path_list
        self.label1_path_list = label1_path_list
        self.label2_path_list = label2_path_list
        self.rule = RULE
        self.IF_TRAIN = IF_TRAIN
        #self.transform=transforms.Compose([transforms.Normalize((0.5,),(0.5,))])
        self.mri_list, self.mask1_list, self.mask2_list, self.mask_and_list, self.mask_or_list, self.mask_rnd_list = self.preprocess() 

    def __len__(self):
        return len(self.mri_list)

    def preprocess(self):
        mri_list, mask1_list, mask2_list, mask_and_list, mask_or_list, mask_rnd_list = [], [], [], [], [], []
        for idx in tqdm(range(len(self.mri_path_list))):
            mri_t2f = torch.Tensor(nib.load(self.mri_path_list[idx][0]).get_data())
            mri_t2f = (mri_t2f-mri_t2f.min())/(mri_t2f.max()-mri_t2f.min())
            
            mri_t1w = torch.Tensor(nib.load(self.mri_path_list[idx][1]).get_data())
            mri_t1w = (mri_t1w-mri_t1w.min())/(mri_t1w.max()-mri_t1w.min())
            
            mri_pd = torch.Tensor(nib.load(self.mri_path_list[idx][2]).get_data())
            mri_pd = (mri_pd-mri_pd.min())/(mri_pd.max()-mri_pd.min())
            
            mri_t2w = torch.Tensor(nib.load(self.mri_path_list[idx][3]).get_data())
            mri_t2w = (mri_t2w-mri_t2w.min())/(mri_t2w.max()-mri_t2w.min())
            
            mri = torch.cat((mri_t1w.unsqueeze(0),mri_t2w.unsqueeze(0),mri_pd.unsqueeze(0),mri_t2f.unsqueeze(0)),axis=0)
            #mri = self.transform(mri)
            mask_and, mask_or, mask_rnd = weight_ground_truth(self.label1_path_list[idx], self.label2_path_list[idx])
            mask1 = torch.Tensor(nib.load(self.label1_path_list[idx]).get_data())
            mask2 = torch.Tensor(nib.load(self.label2_path_list[idx]).get_data())
            
            mri_list.append(mri)
            mask1_list.append(mask1)
            mask2_list.append(mask2)
            mask_and_list.append(mask_and)
            mask_or_list.append(mask_or)
            mask_rnd_list.append(mask_rnd)
        return mri_list, mask1_list, mask2_list, mask_and_list, mask_or_list, mask_rnd_list

    def __getitem__ (self,idx):
        img = self.mri_list[idx]
        if self.rule=='and':
            mask = self.mask_and_list[idx]
        elif self.rule=='or':
            mask = self.mask_or_list[idx]
        elif self.rule=='random':
            mask = self.mask_rnd_list[idx]
        elif self.rule=='mask1':
            mask = self.mask1_list[idx]
        elif self.rule=='mask2':
            mask = self.mask2_list[idx]
            
        label = torch.Tensor(mask)

        return img, label

# %%
dataset = MRIDataset(test_img_list, test_label1_list, test_label2_list, RULE = 'and', IF_TRAIN= True)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]<ipython-input-12-976d5a4983b3>:25: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2f = torch.Tensor(nib.load(self.mri_path_list[idx][0]).get_data())
# <ipython-input-12-976d5a4983b3>:28: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t1w = torch.Tensor(nib.load(self.mri_path_list[idx][1]).get_data())
# <ipython-input-12-976d5a4983b3>:31: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_pd = torch.Tensor(nib.load(self.mri_path_list[idx][2]).get_data())
# <ipython-input-12-976d5a4983b3>:34: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2w = torch.Tensor(nib.load(self.mri_path_list[idx][3]).get_data())
# <ipython-input-5-527bb657da25>:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1=nib.load(mask1_path).get_data()
# <ipython-input-5-527bb657da25>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2=nib.load(mask2_path).get_data()
# <ipython-input-12-976d5a4983b3>:40: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1 = torch.Tensor(nib.load(self.label1_path_list[idx]).get_data())
# <ipython-input-12-976d5a4983b3>:41: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2 = torch.Tensor(nib.load(self.label2_path_list[idx]).get_data())
# 100%|██████████| 2/2 [00:28<00:00, 14.25s/it]

# %%
img, mask = dataset[0]
print(img.shape)
print(mask.shape)
plt.figure(figsize = (16,32))
plt.subplot(1,5,1)
plt.imshow(img[0,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.subplot(1,5,2)
plt.imshow(img[1,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.subplot(1,5,3)
plt.imshow(img[2,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.subplot(1,5,4)
plt.imshow(img[3,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.subplot(1,5,5)
plt.imshow(mask.cpu().numpy()[:,:,90],'gray')
print(img[0,:,:,:].cpu().numpy().max())
print(img[1,:,:,:].cpu().numpy().max())
print(img[2,:,:,:].cpu().numpy().max())
print(img[3,:,:,:].cpu().numpy().max())
# Out:
# torch.Size([4, 181, 217, 181])
# torch.Size([181, 217, 181])
# 1.0
# 1.0
# 1.0
# 1.0

# %%
train_dataset = MRIDataset(train_img_list, train_label1_list, train_label2_list, RULE = 'and', IF_TRAIN= True)
val_dataset = MRIDataset(val_img_list, val_label1_list, val_label2_list, RULE = 'and', IF_TRAIN= False)
test_dataset = MRIDataset(test_img_list, test_label1_list, test_label2_list, RULE = 'and', IF_TRAIN= False)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]<ipython-input-7-976d5a4983b3>:25: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2f = torch.Tensor(nib.load(self.mri_path_list[idx][0]).get_data())
# <ipython-input-7-976d5a4983b3>:28: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t1w = torch.Tensor(nib.load(self.mri_path_list[idx][1]).get_data())
# <ipython-input-7-976d5a4983b3>:31: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_pd = torch.Tensor(nib.load(self.mri_path_list[idx][2]).get_data())
# <ipython-input-7-976d5a4983b3>:34: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2w = torch.Tensor(nib.load(self.mri_path_list[idx][3]).get_data())
# <ipython-input-16-527bb657da25>:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1=nib.load(mask1_path).get_data()
# <ipython-input-16-527bb657da25>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2=nib.load(mask2_path).get_data()
# <ipython-input-7-976d5a4983b3>:40: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1 = torch.Tensor(nib.load(self.label1_path_list[idx]).get_data())
# <ipython-input-7-976d5a4983b3>:41: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2 = torch.Tensor(nib.load(self.label2_path_list[idx]).get_data())
# 100%|██████████| 16/16 [03:48<00:00, 14.29s/it]
# 100%|██████████| 3/3 [00:43<00:00, 14.36s/it]
# 100%|██████████| 2/2 [00:28<00:00, 14.32s/it]

# %%
NUM_EPOCH = 400
BATCH_SIZE = 4
LR = 0.0001
SAVE_PATH = "/scratch/hp2173/mri/SelfAttention_U-net_3D_model/"

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, 
                                           batch_size=BATCH_SIZE, 
                                           shuffle=True, 
                                           num_workers=0)
val_loader = torch.utils.data.DataLoader(val_dataset, 
                                         batch_size=BATCH_SIZE, 
                                         shuffle=False, 
                                         num_workers=0)
test_loader = torch.utils.data.DataLoader(test_dataset, 
                                         batch_size=BATCH_SIZE, 
                                         shuffle=False, 
                                         num_workers=0)

# %% [markdown]
# # 3.Build the Network

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class SelfAttention_3D(nn.Module):
    def __init__(self, feature_dims, dim_q):
        super(SelfAttention_3D, self).__init__()
        self.fc_q1 = nn.Linear(feature_dims, dim_q)
        self.fc_k1 = nn.Linear(feature_dims, dim_q)
        self.fc_v1 = nn.Linear(feature_dims, dim_q)
        
        self.fc_q2 = nn.Linear(feature_dims, dim_q)
        self.fc_k2 = nn.Linear(feature_dims, dim_q)
        self.fc_v2 = nn.Linear(feature_dims, dim_q)
        
        self.fc_q3 = nn.Linear(feature_dims, dim_q)
        self.fc_k3 = nn.Linear(feature_dims, dim_q)
        self.fc_v3 = nn.Linear(feature_dims, dim_q)
        
        self.fc_o = nn.Linear(3*dim_q, feature_dims)

    def forward(self, input_data):
        # Expect input_data to be of shape (batch_size, channels, l, w, h).
        batch_size, channels, l, w, h  = input_data.size()
        # (batch_size, n_pixels, channels)
        input_data = input_data.flatten().reshape(batch_size, channels, -1)

        # Linear transforms(head_1).
        queries1 = self.fc_q1(input=input_data)  # (batch_size, feature_dims, dim_q)
        keys1 = self.fc_k1(input=input_data)  # (batch_size, feature_dims, dim_q)
        values1 = self.fc_v1(input=input_data)  # (batch_size, feature_dims, dim_q)
        
        # Attention matrix1.
        dot1 = torch.bmm(queries1, keys1.transpose(1, 2))  # (batch_size, channels, channels)
        scaled_dot1 = torch.div(dot1, torch.sqrt(torch.tensor(l*w*h).float())) # scale
        atten_matrix1 = F.softmax(scaled_dot1, dim=1)
        atten_weighted1 = torch.bmm(atten_matrix1, values1)
        
        # Linear transforms(head_2).
        queries2 = self.fc_q2(input=input_data)  # (batch_size, feature_dims, dim_q)
        keys2 = self.fc_k2(input=input_data)  # (batch_size, feature_dims, dim_q)
        values2 = self.fc_v2(input=input_data)  # (batch_size, feature_dims, dim_q)
        
        # Attention matrix2.
        dot2 = torch.bmm(queries2, keys2.transpose(1, 2))  # (batch_size, channels, channels)
        scaled_dot2 = torch.div(dot2, torch.sqrt(torch.tensor(l*w*h).float())) # scale
        atten_matrix2 = F.softmax(scaled_dot2, dim=1)
        atten_weighted2 = torch.bmm(atten_matrix2, values2)
        
        # Linear transforms(head_3).
        queries3 = self.fc_q3(input=input_data)  # (batch_size, feature_dims, dim_q)
        keys3 = self.fc_k3(input=input_data)  # (batch_size, feature_dims, dim_q)
        values3 = self.fc_v3(input=input_data)  # (batch_size, feature_dims, dim_q)
        
        # Attention matrix1.
        dot3 = torch.bmm(queries3, keys3.transpose(1, 2))  # (batch_size, channels, channels)
        scaled_dot3 = torch.div(dot3, torch.sqrt(torch.tensor(l*w*h).float())) # scale
        atten_matrix3 = F.softmax(scaled_dot3, dim=1)
        atten_weighted3 = torch.bmm(atten_matrix3, values3)
        
        catlayer = torch.cat((atten_weighted1,atten_weighted2,atten_weighted3),dim=2)
        output = self.fc_o(catlayer).flatten().reshape(batch_size, channels, l, w, h)
        
        return output

# %%
'''feature map for each pixels
class SelfAttention_3D(nn.Module):
    def __init__(self, n_channels, dim_q):
        super(SelfAttention_3D, self).__init__()
        self.fc_q1 = nn.Linear(n_channels, dim_q)
        self.fc_k1 = nn.Linear(n_channels, dim_q)
        self.fc_v1 = nn.Linear(n_channels, dim_q)
        
        self.fc_q2 = nn.Linear(n_channels, dim_q)
        self.fc_k2 = nn.Linear(n_channels, dim_q)
        self.fc_v2 = nn.Linear(n_channels, dim_q)
        
        self.fc_q3 = nn.Linear(n_channels, dim_q)
        self.fc_k3 = nn.Linear(n_channels, dim_q)
        self.fc_v3 = nn.Linear(n_channels, dim_q)
        
        self.fc_o = nn.Linear(3*dim_q, n_channels)

    def forward(self, input_data):
        # Expect input_data to be of shape (batch_size, channels, l, w, h).
        batch_size, channels, l, w, h  = input_data.size()
        # (batch_size, n_pixels, channels)
        input_data = input_data.flatten().reshape(batch_size, -1, channels)

        # Linear transforms(head_1).
        queries1 = self.fc_q1(input=input_data)  # (batch_size, n_pixels, dim_q)
        keys1 = self.fc_k1(input=input_data)  # (batch_size, n_pixels, dim_q)
        values1 = self.fc_v1(input=input_data)  # (batch_size, n_pixels, dim_q)
        
        # Attention matrix1.
        dot1 = torch.bmm(queries1, keys1.transpose(1, 2))  # (batch_size, n_pixels, n_pixels)
        scaled_dot1 = torch.div(dot1, torch.sqrt(torch.tensor(channels).float())) # scale
        atten_matrix1 = F.softmax(scaled_dot1, dim=1)
        atten_weighted1 = torch.bmm(atten_matrix1, values1)
        
        # Linear transforms(head_2).
        queries2 = self.fc_q2(input=input_data)  # (batch_size, n_pixels, dim_q)
        keys2 = self.fc_k2(input=input_data)  # (batch_size, n_pixels, dim_q)
        values2 = self.fc_v2(input=input_data)  # (batch_size, n_pixels, dim_q)
        
        # Attention matrix2.
        dot2 = torch.bmm(queries2, keys2.transpose(1, 2))  # (batch_size, n_pixels, n_pixels)
        scaled_dot2 = torch.div(dot2, torch.sqrt(torch.tensor(channels).float())) # scale
        atten_matrix2 = F.softmax(scaled_dot2, dim=1)
        atten_weighted2 = torch.bmm(atten_matrix2, values2)
        
        # Linear transforms(head_3).
        queries3 = self.fc_q3(input=input_data)  # (batch_size, n_pixels, dim_q)
        keys3 = self.fc_k3(input=input_data)  # (batch_size, n_pixels, dim_q)
        values3 = self.fc_v3(input=input_data)  # (batch_size, n_pixels, dim_q)
        
        # Attention matrix1.
        dot3 = torch.bmm(queries3, keys3.transpose(1, 2))  # (batch_size, n_pixels, n_pixels)
        scaled_dot3 = torch.div(dot3, torch.sqrt(torch.tensor(channels).float())) # scale
        atten_matrix3 = F.softmax(scaled_dot3, dim=1)
        atten_weighted3 = torch.bmm(atten_matrix3, values3)
        
        catlayer = torch.cat((atten_weighted1,atten_weighted2,atten_weighted3),dim=2)
        output = self.fc_o(catlayer).permute(0,2,1).flatten().reshape(batch_size, channels, l, w, h)
        
        return output
'''
# Out:
# 'feature map for each pixels\nclass SelfAttention_3D(nn.Module):\n    def __init__(self, n_channels, dim_q):\n        super(SelfAttention_3D, self).__init__()\n        self.fc_q1 = nn.Linear(n_channels, dim_q)\n        self.fc_k1 = nn.Linear(n_channels, dim_q)\n        self.fc_v1 = nn.Linear(n_channels, dim_q)\n        \n        self.fc_q2 = nn.Linear(n_channels, dim_q)\n        self.fc_k2 = nn.Linear(n_channels, dim_q)\n        self.fc_v2 = nn.Linear(n_channels, dim_q)\n        \n        self.fc_q3 = nn.Linear(n_channels, dim_q)\n        self.fc_k3 = nn.Linear(n_channels, dim_q)\n        self.fc_v3 = nn.Linear(n_channels, dim_q)\n        \n        self.fc_o = nn.Linear(3*dim_q, n_channels)\n\n    def forward(self, input_data):\n        # Expect input_data to be of shape (batch_size, channels, l, w, h).\n        batch_size, channels, l, w, h  = input_data.size()\n        # (batch_size, n_pixels, channels)\n        input_data = input_data.flatten().reshape(batch_size, -1, channels)\n\n        # Linear transforms(head_1).\n        queries1 = self.fc_q1(input=input_data)  # (batch_size, n_pixels, dim_q)\n        keys1 = self.fc_k1(input=input_data)  # (batch_size, n_pixels, dim_q)\n        values1 = self.fc_v1(input=input_data)  # (batch_size, n_pixels, dim_q)\n        \n        # Attention matrix1.\n        dot1 = torch.bmm(queries1, keys1.transpose(1, 2))  # (batch_size, n_pixels, n_pixels)\n        scaled_dot1 = torch.div(dot1, torch.sqrt(torch.tensor(channels).float())) # scale\n        atten_matrix1 = F.softmax(scaled_dot1, dim=1)\n        atten_weighted1 = torch.bmm(atten_matrix1, values1)\n        \n        # Linear transforms(head_2).\n        queries2 = self.fc_q2(input=input_data)  # (batch_size, n_pixels, dim_q)\n        keys2 = self.fc_k2(input=input_data)  # (batch_size, n_pixels, dim_q)\n        values2 = self.fc_v2(input=input_data)  # (batch_size, n_pixels, dim_q)\n        \n        # Attention matrix2.\n        dot2 = torch.bmm(queries2, keys2.transpose(1, 2))  # (batch_size, n_pixels, n_pixels)\n        scaled_dot2 = torch.div(dot2, torch.sqrt(torch.tensor(channels).float())) # scale\n        atten_matrix2 = F.softmax(scaled_dot2, dim=1)\n        atten_weighted2 = torch.bmm(atten_matrix2, values2)\n        \n        # Linear transforms(head_3).\n        queries3 = self.fc_q3(input=input_data)  # (batch_size, n_pixels, dim_q)\n        keys3 = self.fc_k3(input=input_data)  # (batch_size, n_pixels, dim_q)\n        values3 = self.fc_v3(input=input_data)  # (batch_size, n_pixels, dim_q)\n        \n        # Attention matrix1.\n        dot3 = torch.bmm(queries3, keys3.transpose(1, 2))  # (batch_size, n_pixels, n_pixels)\n        scaled_dot3 = torch.div(dot3, torch.sqrt(torch.tensor(channels).float())) # scale\n        atten_matrix3 = F.softmax(scaled_dot3, dim=1)\n        atten_weighted3 = torch.bmm(atten_matrix3, values3)\n        \n        catlayer = torch.cat((atten_weighted1,atten_weighted2,atten_weighted3),dim=2)\n        output = self.fc_o(catlayer).permute(0,2,1).flatten().reshape(batch_size, channels, l, w, h)\n        \n        return output\n'

# %%
net = SelfAttention_3D(1000, 10)
a = torch.zeros(4, 90, 10, 10, 10)
b = net(a)
print(a.shape)
print(b.shape)
# Out:
# torch.Size([4, 90, 10, 10, 10])
# torch.Size([4, 90, 10, 10, 10])

# %%
class SelfAttention_UNet(nn.Module):


    def __init__(self, in_channels, n_classes, base_n_filter=8):
        super(SelfAttention_UNet, self).__init__()
        self.in_channels = in_channels
        self.n_classes = n_classes
        self.base_n_filter = base_n_filter

        self.lrelu = nn.LeakyReLU()
        self.dropout3d = nn.Dropout3d(p=0.6)
        self.upsacle = nn.Upsample(scale_factor=2, mode='nearest')
        self.softmax = nn.Softmax(dim=1)

        self.conv3d_c1_1 = nn.Conv3d(self.in_channels, self.base_n_filter, kernel_size=3, stride=1, padding=1,bias=False)
        self.conv3d_c1_2 = nn.Conv3d(self.base_n_filter, self.base_n_filter, kernel_size=3, stride=1, padding=1,bias=False)
        self.lrelu_conv_c1 = self.lrelu_conv(self.base_n_filter, self.base_n_filter)
        self.inorm3d_c1 = nn.InstanceNorm3d(self.base_n_filter)

        self.conv3d_c2 = nn.Conv3d(self.base_n_filter, self.base_n_filter * 2, kernel_size=3, stride=2, padding=1,bias=False)
        self.norm_lrelu_conv_c2 = self.norm_lrelu_conv(self.base_n_filter * 2, self.base_n_filter * 2)
        self.inorm3d_c2 = nn.InstanceNorm3d(self.base_n_filter * 2)

        self.conv3d_c3 = nn.Conv3d(self.base_n_filter * 2, self.base_n_filter * 4, kernel_size=3, stride=2, padding=1,bias=False)
        self.norm_lrelu_conv_c3 = self.norm_lrelu_conv(self.base_n_filter * 4, self.base_n_filter * 4)
        self.inorm3d_c3 = nn.InstanceNorm3d(self.base_n_filter * 4)

        self.conv3d_c4 = nn.Conv3d(self.base_n_filter * 4, self.base_n_filter * 8, kernel_size=3, stride=2, padding=1,bias=False)
        self.norm_lrelu_conv_c4 = self.norm_lrelu_conv(self.base_n_filter * 8, self.base_n_filter * 8)
        self.inorm3d_c4 = nn.InstanceNorm3d(self.base_n_filter * 8)

        self.conv3d_c5 = nn.Conv3d(self.base_n_filter * 8, self.base_n_filter * 16, kernel_size=3, stride=2, padding=1,bias=False)
        self.norm_lrelu_conv_c5 = self.norm_lrelu_conv(self.base_n_filter * 16, self.base_n_filter * 16)
        self.norm_lrelu_upscale_conv_norm_lrelu_l0 = self.norm_lrelu_upscale_conv_norm_lrelu(self.base_n_filter * 16, self.base_n_filter * 8)

        self.conv3d_l0 = nn.Conv3d(self.base_n_filter * 8, self.base_n_filter * 8, kernel_size=1, stride=1, padding=0,bias=False)
        self.inorm3d_l0 = nn.InstanceNorm3d(self.base_n_filter * 8)

        self.conv_norm_lrelu_l1 = self.conv_norm_lrelu(self.base_n_filter * 16, self.base_n_filter * 16)
        self.conv3d_l1 = nn.Conv3d(self.base_n_filter * 16, self.base_n_filter * 8, kernel_size=1, stride=1, padding=0, bias=False)
        self.norm_lrelu_upscale_conv_norm_lrelu_l1 = self.norm_lrelu_upscale_conv_norm_lrelu(self.base_n_filter * 8,self.base_n_filter * 4)

        self.conv_norm_lrelu_l2 = self.conv_norm_lrelu(self.base_n_filter * 8, self.base_n_filter * 8)
        self.conv3d_l2 = nn.Conv3d(self.base_n_filter * 8, self.base_n_filter * 4, kernel_size=1, stride=1, padding=0,bias=False)
        self.norm_lrelu_upscale_conv_norm_lrelu_l2 = self.norm_lrelu_upscale_conv_norm_lrelu(self.base_n_filter * 4,self.base_n_filter * 2)

        self.conv_norm_lrelu_l3 = self.conv_norm_lrelu(self.base_n_filter * 4, self.base_n_filter * 4)
        self.conv3d_l3 = nn.Conv3d(self.base_n_filter * 4, self.base_n_filter * 2, kernel_size=1, stride=1, padding=0,bias=False)
        self.norm_lrelu_upscale_conv_norm_lrelu_l3 = self.norm_lrelu_upscale_conv_norm_lrelu(self.base_n_filter * 2,self.base_n_filter)

        self.conv_norm_lrelu_l4 = self.conv_norm_lrelu(self.base_n_filter * 2, self.base_n_filter * 2)
        self.conv3d_l4 = nn.Conv3d(self.base_n_filter * 2, self.n_classes, kernel_size=1, stride=1, padding=0,bias=False)

        self.ds2_1x1_conv3d = nn.Conv3d(self.base_n_filter * 8, self.n_classes, kernel_size=1, stride=1, padding=0,bias=False)
        self.ds3_1x1_conv3d = nn.Conv3d(self.base_n_filter * 4, self.n_classes, kernel_size=1, stride=1, padding=0,bias=False)
        self.sigmoid = nn.Sigmoid()
        
        self.attention1 = SelfAttention_3D(feature_dims=23*28*23, dim_q=10)
        self.attention2 = SelfAttention_3D(feature_dims=46*55*46, dim_q=10)
        self.attention3 = SelfAttention_3D(feature_dims=91*109*91, dim_q=10)
        #self.attention4 = SelfAttention_3D(feature_dims=181*217*181, dim_q=10)

    def conv_norm_lrelu(self, feat_in, feat_out):
        return nn.Sequential(
            nn.Conv3d(feat_in, feat_out, kernel_size=3, stride=1, padding=1, bias=False),
            nn.InstanceNorm3d(feat_out),
            nn.LeakyReLU())

    def norm_lrelu_conv(self, feat_in, feat_out):
        return nn.Sequential(
            nn.InstanceNorm3d(feat_in),
            nn.LeakyReLU(),
            nn.Conv3d(feat_in, feat_out, kernel_size=3, stride=1, padding=1, bias=False))

    def lrelu_conv(self, feat_in, feat_out):
        return nn.Sequential(
            nn.LeakyReLU(),
            nn.Conv3d(feat_in, feat_out, kernel_size=3, stride=1, padding=1, bias=False))

    def norm_lrelu_upscale_conv_norm_lrelu(self, feat_in, feat_out):
        return nn.Sequential(
            nn.InstanceNorm3d(feat_in),
            nn.LeakyReLU(),
            nn.Upsample(scale_factor=2, mode='nearest'),
            # should be feat_in*2 or feat_in
            nn.Conv3d(feat_in, feat_out, kernel_size=3, stride=1, padding=1, bias=False),
            nn.InstanceNorm3d(feat_out),
            nn.LeakyReLU())

    def forward(self, x):
        #  Level 1 context pathway
        out = self.conv3d_c1_1(x)
        residual_1 = out
        out = self.lrelu(out)
        out = self.conv3d_c1_2(out)
        out = self.dropout3d(out)
        out = self.lrelu_conv_c1(out)
        # Element Wise Summation
        out += residual_1
        context_1 = self.lrelu(out)
        out = self.inorm3d_c1(out)
        out = self.lrelu(out)

        # Level 2 context pathway
        out = self.conv3d_c2(out)
        residual_2 = out
        out = self.norm_lrelu_conv_c2(out)
        out = self.dropout3d(out)
        out = self.norm_lrelu_conv_c2(out)
        out += residual_2
        out = self.inorm3d_c2(out)
        out = self.lrelu(out)
        context_2 = out

        # Level 3 context pathway
        out = self.conv3d_c3(out)
        residual_3 = out
        out = self.norm_lrelu_conv_c3(out)
        out = self.dropout3d(out)
        out = self.norm_lrelu_conv_c3(out)
        out += residual_3
        out = self.inorm3d_c3(out)
        out = self.lrelu(out)
        context_3 = out

        # Level 4 context pathway
        out = self.conv3d_c4(out)
        residual_4 = out
        out = self.norm_lrelu_conv_c4(out)
        out = self.dropout3d(out)
        out = self.norm_lrelu_conv_c4(out)
        out += residual_4
        out = self.inorm3d_c4(out)
        out = self.lrelu(out)
        context_4 = out

        # Level 5
        out = self.conv3d_c5(out)
        residual_5 = out
        out = self.norm_lrelu_conv_c5(out)
        out = self.dropout3d(out)
        out = self.norm_lrelu_conv_c5(out)
        out += residual_5
        out = self.norm_lrelu_upscale_conv_norm_lrelu_l0(out)

        out = self.conv3d_l0(out)
        out = self.inorm3d_l0(out)
        out = self.lrelu(out)

        # Level 1 localization pathway
        out = out[:,:,0:-1,:,0:-1]
        out = torch.cat([out, context_4], dim=1)
        out = self.attention1(out)
        out = self.conv_norm_lrelu_l1(out)
        out = self.conv3d_l1(out)
        out = self.norm_lrelu_upscale_conv_norm_lrelu_l1(out)

        # Level 2 localization pathway
        out = out[:,:,:,0:-1,:]
        out = torch.cat([out, context_3], dim=1)
        out = self.attention2(out)
        out = self.conv_norm_lrelu_l2(out)
        ds2 = out
        out = self.conv3d_l2(out)
        out = self.norm_lrelu_upscale_conv_norm_lrelu_l2(out)

        # Level 3 localization pathway
        out = out[:,:,0:-1,0:-1,0:-1]
        out = torch.cat([out, context_2], dim=1)
        out = self.attention3(out)
        out = self.conv_norm_lrelu_l3(out)
        ds3 = out
        out = self.conv3d_l3(out)
        out = self.norm_lrelu_upscale_conv_norm_lrelu_l3(out)

        # Level 4 localization pathway
        out = out[:,:,0:-1,0:-1,0:-1]
        out = torch.cat([out, context_1], dim=1)
        #out = self.attention4(out)
        out = self.conv_norm_lrelu_l4(out)
        out_pred = self.conv3d_l4(out)

        ds2_1x1_conv = self.ds2_1x1_conv3d(ds2)
        ds1_ds2_sum_upscale = self.upsacle(ds2_1x1_conv)
        ds3_1x1_conv = self.ds3_1x1_conv3d(ds3)
        ds1_ds2_sum_upscale = ds1_ds2_sum_upscale[:,:,0:-1,0:-1,0:-1]
        ds1_ds2_sum_upscale_ds3_sum = ds1_ds2_sum_upscale + ds3_1x1_conv
        ds1_ds2_sum_upscale_ds3_sum_upscale = self.upsacle(ds1_ds2_sum_upscale_ds3_sum)
        
        ds1_ds2_sum_upscale_ds3_sum_upscale = ds1_ds2_sum_upscale_ds3_sum_upscale[:,:,0:-1,0:-1,0:-1]
        out = out_pred + ds1_ds2_sum_upscale_ds3_sum_upscale
        seg_layer = out
        return seg_layer

# %%
net = SelfAttention_UNet(4,1).to(device)
a = torch.zeros(1, 4, 181, 217, 181).to(device)
b = net(a)
print(a.shape)
print(b.shape)
# Out:
# torch.Size([1, 4, 181, 217, 181])
# torch.Size([1, 1, 181, 217, 181])

# %% [markdown]
# # 4.Dice Loss

# %%
# define dice coefficient
def dice_coeff(pred, target):
    smooth = 1
    # First let's flatten the matrix to [Batch Size, -1]
    # The flatten operation does not afftect the computation of the above equation
    num = pred.size(0)
    m1 = pred. view(num, -1). float() # Flatten
    m2 = target. view(num, -1). float() # Flatten
    # Then we compute the intersection and the sum of cardinality
    intersection = 2*torch.sum(m1*m2,dim= 1) + smooth
    cardinality = torch.sum(m1**2,dim= 1) + torch.sum(m2**2,dim= 1) + smooth
    # Followed by Dice
    dice = intersection/cardinality
    return dice.mean()
# define SoftDICE loss as 1 - SoftDICE
class SoftDICELoss(nn. Module):
    def __init__(self, smooth = 1):
        super(SoftDICELoss, self). __init__()
        self. smooth = smooth
    def forward(self, pred, target):
        loss = 1 - dice_coeff(pred, target)
        return loss.mean()

# %% [markdown]
# # 5.Training

# %%
def train_epoch(net, data_loader, optimizer, criterion, epoch):

    net = net.train()
    optimizer.zero_grad()
    loss_stat = []
    for i, img_mask in enumerate(data_loader):
        img, mask = img_mask

        img = img.to(device)
        mask = mask.to(device)

        pred = net(img)

        loss = criterion(pred, mask)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        loss_stat += [loss.item()]*img.shape[0]
        print ("Epoch {}: [{}/{}] Loss: {:.3f}". format(epoch, len(data_loader), len(data_loader),np. mean(loss_stat)))
    return np.mean(loss_stat)

# %%
def eval_epoch(net, data_loader, metric, criterion):
    # set model in eval mode to avoid updating BN layer
    net = net.eval()
    
    metric_stat = []
    val_loss_stat = []
    for i, img_mask in enumerate(data_loader):
        img, mask = img_mask
        # send data to device
        img = img.to(device)
        mask = mask.to(device)
        # feed data to the model. No need to compute grad.
        with torch.no_grad():
            pred = net(img)
            val_loss = criterion(pred, mask)
            
        # eval the results using DICE function as the metric
        # Convert probability to prediction mask
        pred = pred>0.4
        err = dice_coeff(pred, mask)
        metric_stat += [err.item()]*img.shape[0]
        val_loss_stat += [val_loss.item()]*img.shape[0]
        
    print ("Dice: {:.3f}  Val Loss: {:.3f} ".format(np.mean(metric_stat), np.mean(val_loss_stat)))
    
    return np.mean(val_loss_stat), np.mean(metric_stat)

# %%
net = SelfAttention_UNet(4,1).to(device)
print(net)
n_params = sum(p.numel() for p in net.parameters() if p.requires_grad)
print('Number of parameters in network: ', n_params)
# Out:
# SelfAttention_UNet(
#   (lrelu): LeakyReLU(negative_slope=0.01)
#   (dropout3d): Dropout3d(p=0.6, inplace=False)
#   (upsacle): Upsample(scale_factor=2.0, mode=nearest)
#   (softmax): Softmax(dim=1)
#   (conv3d_c1_1): Conv3d(4, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (conv3d_c1_2): Conv3d(8, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (lrelu_conv_c1): Sequential(
#     (0): LeakyReLU(negative_slope=0.01)
#     (1): Conv3d(8, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   )
#   (inorm3d_c1): InstanceNorm3d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (conv3d_c2): Conv3d(8, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#   (norm_lrelu_conv_c2): Sequential(
#     (0): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   )
#   (inorm3d_c2): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (conv3d_c3): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#   (norm_lrelu_conv_c3): Sequential(
#     (0): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   )
#   (inorm3d_c3): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (conv3d_c4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#   (norm_lrelu_conv_c4): Sequential(
#     (0): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   )
#   (inorm3d_c4): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (conv3d_c5): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#   (norm_lrelu_conv_c5): Sequential(
#     (0): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   )
#   (norm_lrelu_upscale_conv_norm_lrelu_l0): Sequential(
#     (0): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Upsample(scale_factor=2.0, mode=nearest)
#     (3): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (4): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (5): LeakyReLU(negative_slope=0.01)
#   )
#   (conv3d_l0): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (inorm3d_l0): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (conv_norm_lrelu_l1): Sequential(
#     (0): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (1): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (conv3d_l1): Conv3d(128, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (norm_lrelu_upscale_conv_norm_lrelu_l1): Sequential(
#     (0): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Upsample(scale_factor=2.0, mode=nearest)
#     (3): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (4): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (5): LeakyReLU(negative_slope=0.01)
#   )
#   (conv_norm_lrelu_l2): Sequential(
#     (0): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (1): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (conv3d_l2): Conv3d(64, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (norm_lrelu_upscale_conv_norm_lrelu_l2): Sequential(
#     (0): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Upsample(scale_factor=2.0, mode=nearest)
#     (3): Conv3d(32, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (4): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (5): LeakyReLU(negative_slope=0.01)
#   )
#   (conv_norm_lrelu_l3): Sequential(
#     (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (1): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (conv3d_l3): Conv3d(32, 16, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (norm_lrelu_upscale_conv_norm_lrelu_l3): Sequential(
#     (0): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Upsample(scale_factor=2.0, mode=nearest)
#     (3): Conv3d(16, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (4): InstanceNorm3d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (5): LeakyReLU(negative_slope=0.01)
#   )
#   (conv_norm_lrelu_l4): Sequential(
#     (0): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (1): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (conv3d_l4): Conv3d(16, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (ds2_1x1_conv3d): Conv3d(64, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (ds3_1x1_conv3d): Conv3d(32, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (sigmoid): Sigmoid()
#   (attention1): SelfAttention_3D(
#     (fc_q1): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_k1): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_v1): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_q2): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_k2): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_v2): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_q3): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_k3): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_v3): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_o): Linear(in_features=30, out_features=14812, bias=True)
#   )
#   (attention2): SelfAttention_3D(
#     (fc_q1): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_k1): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_v1): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_q2): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_k2): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_v2): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_q3): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_k3): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_v3): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_o): Linear(in_features=30, out_features=116380, bias=True)
#   )
#   (attention3): SelfAttention_3D(
#     (fc_q1): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_k1): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_v1): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_q2): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_k2): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_v2): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_q3): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_k3): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_v3): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_o): Linear(in_features=30, out_features=902629, bias=True)
#   )
# )
# Number of parameters in network:  126874451

# %%
optimizer = optim.Adam(net.parameters(), lr= LR)
criterion = SoftDICELoss()

train_loss_list = []
val_loss_list = []

# %%
for epoch in range(NUM_EPOCH):    
    loss = train_epoch(net, train_loader, optimizer, criterion, epoch)
    val_loss, dice = eval_epoch(net, val_loader, dice_coeff, criterion)
    
    # Record losses for each epoch
    train_loss_list.append(loss)
    val_loss_list.append(val_loss)
    
    # Save the model after each epoch
    if os.path.isdir(SAVE_PATH):
        torch.save(net.state_dict(),SAVE_PATH + 'MRISegEpoch{}.pth'.format(epoch + 1))
    else:
        os.makedirs(SAVE_PATH, exist_ok=True)
        torch.save(net.state_dict(),SAVE_PATH + 'MRISegEpoch{}.pth'.format(epoch + 1))
    print('Checkpoint {} saved to {}'.format(epoch + 1, SAVE_PATH + 'MRISegEpoch{}.pth'.format(epoch + 1)))
# Out:
# Epoch 0: [4/4] Loss: 0.999
# Epoch 0: [4/4] Loss: 0.999
# Epoch 0: [4/4] Loss: 0.999
# Epoch 0: [4/4] Loss: 0.999
# Dice: 0.006  Val Loss: 0.995
# Checkpoint 1 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch1.pth
# Epoch 1: [4/4] Loss: 0.997
# Epoch 1: [4/4] Loss: 0.997
# Epoch 1: [4/4] Loss: 0.997
# Epoch 1: [4/4] Loss: 0.998
# Dice: 0.008  Val Loss: 0.992
# Checkpoint 2 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch2.pth
# Epoch 2: [4/4] Loss: 0.997
# Epoch 2: [4/4] Loss: 0.995
# Epoch 2: [4/4] Loss: 0.996
# Epoch 2: [4/4] Loss: 0.996
# Dice: 0.009  Val Loss: 0.989
# Checkpoint 3 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch3.pth
# Epoch 3: [4/4] Loss: 0.997
# Epoch 3: [4/4] Loss: 0.997
# Epoch 3: [4/4] Loss: 0.996
# Epoch 3: [4/4] Loss: 0.995
# Dice: 0.011  Val Loss: 0.986
# Checkpoint 4 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch4.pth
# Epoch 4: [4/4] Loss: 0.991
# Epoch 4: [4/4] Loss: 0.994
# Epoch 4: [4/4] Loss: 0.994
# Epoch 4: [4/4] Loss: 0.994
# Dice: 0.012  Val Loss: 0.984
# Checkpoint 5 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch5.pth
# Epoch 5: [4/4] Loss: 0.996
# Epoch 5: [4/4] Loss: 0.993
# Epoch 5: [4/4] Loss: 0.994
# Epoch 5: [4/4] Loss: 0.993
# Dice: 0.014  Val Loss: 0.980
# Checkpoint 6 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch6.pth
# Epoch 6: [4/4] Loss: 0.987
# Epoch 6: [4/4] Loss: 0.990
# Epoch 6: [4/4] Loss: 0.990
# Epoch 6: [4/4] Loss: 0.991
# Dice: 0.016  Val Loss: 0.976
# Checkpoint 7 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch7.pth
# Epoch 7: [4/4] Loss: 0.992
# Epoch 7: [4/4] Loss: 0.994
# Epoch 7: [4/4] Loss: 0.992
# Epoch 7: [4/4] Loss: 0.989
# Dice: 0.018  Val Loss: 0.972
# Checkpoint 8 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch8.pth
# Epoch 8: [4/4] Loss: 0.985
# Epoch 8: [4/4] Loss: 0.984
# Epoch 8: [4/4] Loss: 0.987
# Epoch 8: [4/4] Loss: 0.988
# Dice: 0.021  Val Loss: 0.968
# Checkpoint 9 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch9.pth
# Epoch 9: [4/4] Loss: 0.993
# Epoch 9: [4/4] Loss: 0.985
# Epoch 9: [4/4] Loss: 0.983
# Epoch 9: [4/4] Loss: 0.986
# Dice: 0.026  Val Loss: 0.961
# Checkpoint 10 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch10.pth
# Epoch 10: [4/4] Loss: 0.982
# Epoch 10: [4/4] Loss: 0.979
# Epoch 10: [4/4] Loss: 0.980
# Epoch 10: [4/4] Loss: 0.983
# Dice: 0.032  Val Loss: 0.954
# Checkpoint 11 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch11.pth
# Epoch 11: [4/4] Loss: 0.978
# Epoch 11: [4/4] Loss: 0.973
# Epoch 11: [4/4] Loss: 0.976
# Epoch 11: [4/4] Loss: 0.979
# Dice: 0.041  Val Loss: 0.945
# Checkpoint 12 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch12.pth
# Epoch 12: [4/4] Loss: 0.990
# Epoch 12: [4/4] Loss: 0.975
# Epoch 12: [4/4] Loss: 0.971
# Epoch 12: [4/4] Loss: 0.976
# Dice: 0.051  Val Loss: 0.936
# Checkpoint 13 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch13.pth
# Epoch 13: [4/4] Loss: 0.984
# Epoch 13: [4/4] Loss: 0.976
# Epoch 13: [4/4] Loss: 0.973
# Epoch 13: [4/4] Loss: 0.971
# Dice: 0.072  Val Loss: 0.923
# Checkpoint 14 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch14.pth
# Epoch 14: [4/4] Loss: 0.944
# Epoch 14: [4/4] Loss: 0.962
# Epoch 14: [4/4] Loss: 0.962
# Epoch 14: [4/4] Loss: 0.966
# Dice: 0.101  Val Loss: 0.909
# Checkpoint 15 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch15.pth
# Epoch 15: [4/4] Loss: 0.950
# Epoch 15: [4/4] Loss: 0.963
# Epoch 15: [4/4] Loss: 0.959
# Epoch 15: [4/4] Loss: 0.958
# Dice: 0.144  Val Loss: 0.894
# Checkpoint 16 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch16.pth
# Epoch 16: [4/4] Loss: 0.946
# Epoch 16: [4/4] Loss: 0.962
# Epoch 16: [4/4] Loss: 0.947
# Epoch 16: [4/4] Loss: 0.951
# Dice: 0.188  Val Loss: 0.881
# Checkpoint 17 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch17.pth
# Epoch 17: [4/4] Loss: 0.970
# Epoch 17: [4/4] Loss: 0.929
# Epoch 17: [4/4] Loss: 0.937
# Epoch 17: [4/4] Loss: 0.944
# Dice: 0.195  Val Loss: 0.865
# Checkpoint 18 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch18.pth
# Epoch 18: [4/4] Loss: 0.953
# Epoch 18: [4/4] Loss: 0.946
# Epoch 18: [4/4] Loss: 0.948
# Epoch 18: [4/4] Loss: 0.935
# Dice: 0.253  Val Loss: 0.846
# Checkpoint 19 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch19.pth
# Epoch 19: [4/4] Loss: 0.905
# Epoch 19: [4/4] Loss: 0.904
# Epoch 19: [4/4] Loss: 0.912
# Epoch 19: [4/4] Loss: 0.927
# Dice: 0.267  Val Loss: 0.822
# Checkpoint 20 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch20.pth
# Epoch 20: [4/4] Loss: 0.884
# Epoch 20: [4/4] Loss: 0.922
# Epoch 20: [4/4] Loss: 0.930
# Epoch 20: [4/4] Loss: 0.916
# Dice: 0.309  Val Loss: 0.803
# Checkpoint 21 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch21.pth
# Epoch 21: [4/4] Loss: 0.903
# Epoch 21: [4/4] Loss: 0.877
# Epoch 21: [4/4] Loss: 0.896
# Epoch 21: [4/4] Loss: 0.906
# Dice: 0.352  Val Loss: 0.783
# Checkpoint 22 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch22.pth
# Epoch 22: [4/4] Loss: 0.919
# Epoch 22: [4/4] Loss: 0.932
# Epoch 22: [4/4] Loss: 0.901
# Epoch 22: [4/4] Loss: 0.889
# Dice: 0.377  Val Loss: 0.761
# Checkpoint 23 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch23.pth
# Epoch 23: [4/4] Loss: 0.908
# Epoch 23: [4/4] Loss: 0.879
# Epoch 23: [4/4] Loss: 0.883
# Epoch 23: [4/4] Loss: 0.878
# Dice: 0.397  Val Loss: 0.732
# Checkpoint 24 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch24.pth
# Epoch 24: [4/4] Loss: 0.853
# Epoch 24: [4/4] Loss: 0.861
# Epoch 24: [4/4] Loss: 0.853
# Epoch 24: [4/4] Loss: 0.858
# Dice: 0.419  Val Loss: 0.708
# Checkpoint 25 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch25.pth
# Epoch 25: [4/4] Loss: 0.868
# Epoch 25: [4/4] Loss: 0.897
# Epoch 25: [4/4] Loss: 0.867
# Epoch 25: [4/4] Loss: 0.848
# Dice: 0.430  Val Loss: 0.707
# Checkpoint 26 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch26.pth
# Epoch 26: [4/4] Loss: 0.940
# Epoch 26: [4/4] Loss: 0.854
# Epoch 26: [4/4] Loss: 0.869
# Epoch 26: [4/4] Loss: 0.849
# Dice: 0.446  Val Loss: 0.682
# Checkpoint 27 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch27.pth
# Epoch 27: [4/4] Loss: 0.886
# Epoch 27: [4/4] Loss: 0.827
# Epoch 27: [4/4] Loss: 0.817
# Epoch 27: [4/4] Loss: 0.823
# Dice: 0.446  Val Loss: 0.651
# Checkpoint 28 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch28.pth
# Epoch 28: [4/4] Loss: 0.796
# Epoch 28: [4/4] Loss: 0.813
# Epoch 28: [4/4] Loss: 0.800
# Epoch 28: [4/4] Loss: 0.800
# Dice: 0.465  Val Loss: 0.627
# Checkpoint 29 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch29.pth
# Epoch 29: [4/4] Loss: 0.773
# Epoch 29: [4/4] Loss: 0.809
# Epoch 29: [4/4] Loss: 0.796
# Epoch 29: [4/4] Loss: 0.778
# Dice: 0.476  Val Loss: 0.616
# Checkpoint 30 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch30.pth
# Epoch 30: [4/4] Loss: 0.812
# Epoch 30: [4/4] Loss: 0.836
# Epoch 30: [4/4] Loss: 0.815
# Epoch 30: [4/4] Loss: 0.762
# Dice: 0.489  Val Loss: 0.608
# Checkpoint 31 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch31.pth
# Epoch 31: [4/4] Loss: 0.672
# Epoch 31: [4/4] Loss: 0.692
# Epoch 31: [4/4] Loss: 0.738
# Epoch 31: [4/4] Loss: 0.735
# Dice: 0.498  Val Loss: 0.591
# Checkpoint 32 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch32.pth
# Epoch 32: [4/4] Loss: 0.760
# Epoch 32: [4/4] Loss: 0.733
# Epoch 32: [4/4] Loss: 0.731
# Epoch 32: [4/4] Loss: 0.723
# Dice: 0.503  Val Loss: 0.575
# Checkpoint 33 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch33.pth
# Epoch 33: [4/4] Loss: 0.689
# Epoch 33: [4/4] Loss: 0.706
# Epoch 33: [4/4] Loss: 0.705
# Epoch 33: [4/4] Loss: 0.715
# Dice: 0.511  Val Loss: 0.545
# Checkpoint 34 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch34.pth
# Epoch 34: [4/4] Loss: 0.725
# Epoch 34: [4/4] Loss: 0.786
# Epoch 34: [4/4] Loss: 0.708
# Epoch 34: [4/4] Loss: 0.692
# Dice: 0.521  Val Loss: 0.526
# Checkpoint 35 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch35.pth
# Epoch 35: [4/4] Loss: 0.679
# Epoch 35: [4/4] Loss: 0.714
# Epoch 35: [4/4] Loss: 0.695
# Epoch 35: [4/4] Loss: 0.663
# Dice: 0.526  Val Loss: 0.535
# Checkpoint 36 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch36.pth
# Epoch 36: [4/4] Loss: 0.652
# Epoch 36: [4/4] Loss: 0.636
# Epoch 36: [4/4] Loss: 0.646
# Epoch 36: [4/4] Loss: 0.673
# Dice: 0.531  Val Loss: 0.536
# Checkpoint 37 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch37.pth
# Epoch 37: [4/4] Loss: 0.710
# Epoch 37: [4/4] Loss: 0.651
# Epoch 37: [4/4] Loss: 0.670
# Epoch 37: [4/4] Loss: 0.650
# Dice: 0.528  Val Loss: 0.531
# Checkpoint 38 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch38.pth
# Epoch 38: [4/4] Loss: 0.680
# Epoch 38: [4/4] Loss: 0.675
# Epoch 38: [4/4] Loss: 0.650
# Epoch 38: [4/4] Loss: 0.635
# Dice: 0.524  Val Loss: 0.510
# Checkpoint 39 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch39.pth
# Epoch 39: [4/4] Loss: 0.556
# Epoch 39: [4/4] Loss: 0.640
# Epoch 39: [4/4] Loss: 0.644
# Epoch 39: [4/4] Loss: 0.636
# Dice: 0.527  Val Loss: 0.512
# Checkpoint 40 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch40.pth
# Epoch 40: [4/4] Loss: 0.585
# Epoch 40: [4/4] Loss: 0.599
# Epoch 40: [4/4] Loss: 0.595
# Epoch 40: [4/4] Loss: 0.617
# Dice: 0.525  Val Loss: 0.509
# Checkpoint 41 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch41.pth
# Epoch 41: [4/4] Loss: 0.543
# Epoch 41: [4/4] Loss: 0.567
# Epoch 41: [4/4] Loss: 0.582
# Epoch 41: [4/4] Loss: 0.596
# Dice: 0.536  Val Loss: 0.476
# Checkpoint 42 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch42.pth
# Epoch 42: [4/4] Loss: 0.666
# Epoch 42: [4/4] Loss: 0.608
# Epoch 42: [4/4] Loss: 0.576
# Epoch 42: [4/4] Loss: 0.592
# Dice: 0.551  Val Loss: 0.494
# Checkpoint 43 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch43.pth
# Epoch 43: [4/4] Loss: 0.590
# Epoch 43: [4/4] Loss: 0.644
# Epoch 43: [4/4] Loss: 0.586
# Epoch 43: [4/4] Loss: 0.596
# Dice: 0.558  Val Loss: 0.490
# Checkpoint 44 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch44.pth
# Epoch 44: [4/4] Loss: 0.474
# Epoch 44: [4/4] Loss: 0.548
# Epoch 44: [4/4] Loss: 0.572
# Epoch 44: [4/4] Loss: 0.577
# Dice: 0.557  Val Loss: 0.476
# Checkpoint 45 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch45.pth
# Epoch 45: [4/4] Loss: 0.611
# Epoch 45: [4/4] Loss: 0.586
# Epoch 45: [4/4] Loss: 0.576
# Epoch 45: [4/4] Loss: 0.580
# Dice: 0.553  Val Loss: 0.478
# Checkpoint 46 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch46.pth
# Epoch 46: [4/4] Loss: 0.575
# Epoch 46: [4/4] Loss: 0.579
# Epoch 46: [4/4] Loss: 0.585
# Epoch 46: [4/4] Loss: 0.557
# Dice: 0.547  Val Loss: 0.460
# Checkpoint 47 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch47.pth
# Epoch 47: [4/4] Loss: 0.474
# Epoch 47: [4/4] Loss: 0.554
# Epoch 47: [4/4] Loss: 0.547
# Epoch 47: [4/4] Loss: 0.522
# Dice: 0.543  Val Loss: 0.444
# Checkpoint 48 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch48.pth
# Epoch 48: [4/4] Loss: 0.511
# Epoch 48: [4/4] Loss: 0.471
# Epoch 48: [4/4] Loss: 0.527
# Epoch 48: [4/4] Loss: 0.538
# Dice: 0.547  Val Loss: 0.435
# Checkpoint 49 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch49.pth
# Epoch 49: [4/4] Loss: 0.551
# Epoch 49: [4/4] Loss: 0.560
# Epoch 49: [4/4] Loss: 0.527
# Epoch 49: [4/4] Loss: 0.511
# Dice: 0.553  Val Loss: 0.446
# Checkpoint 50 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch50.pth
# Epoch 50: [4/4] Loss: 0.598
# Epoch 50: [4/4] Loss: 0.574
# Epoch 50: [4/4] Loss: 0.552
# Epoch 50: [4/4] Loss: 0.521
# Dice: 0.563  Val Loss: 0.446
# Checkpoint 51 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch51.pth
# Epoch 51: [4/4] Loss: 0.527
# Epoch 51: [4/4] Loss: 0.514
# Epoch 51: [4/4] Loss: 0.524
# Epoch 51: [4/4] Loss: 0.517
# Dice: 0.567  Val Loss: 0.441
# Checkpoint 52 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch52.pth
# Epoch 52: [4/4] Loss: 0.523
# Epoch 52: [4/4] Loss: 0.523
# Epoch 52: [4/4] Loss: 0.504
# Epoch 52: [4/4] Loss: 0.503
# Dice: 0.567  Val Loss: 0.456
# Checkpoint 53 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch53.pth
# Epoch 53: [4/4] Loss: 0.520
# Epoch 53: [4/4] Loss: 0.563
# Epoch 53: [4/4] Loss: 0.551
# Epoch 53: [4/4] Loss: 0.509
# Dice: 0.567  Val Loss: 0.440
# Checkpoint 54 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch54.pth
# Epoch 54: [4/4] Loss: 0.605
# Epoch 54: [4/4] Loss: 0.503
# Epoch 54: [4/4] Loss: 0.504
# Epoch 54: [4/4] Loss: 0.487
# Dice: 0.574  Val Loss: 0.438
# Checkpoint 55 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch55.pth
# Epoch 55: [4/4] Loss: 0.553
# Epoch 55: [4/4] Loss: 0.517
# Epoch 55: [4/4] Loss: 0.490
# Epoch 55: [4/4] Loss: 0.477
# Dice: 0.577  Val Loss: 0.428
# Checkpoint 56 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch56.pth
# Epoch 56: [4/4] Loss: 0.417
# Epoch 56: [4/4] Loss: 0.494
# Epoch 56: [4/4] Loss: 0.446
# Epoch 56: [4/4] Loss: 0.476
# Dice: 0.577  Val Loss: 0.427
# Checkpoint 57 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch57.pth
# Epoch 57: [4/4] Loss: 0.488
# Epoch 57: [4/4] Loss: 0.458
# Epoch 57: [4/4] Loss: 0.512
# Epoch 57: [4/4] Loss: 0.485
# Dice: 0.575  Val Loss: 0.429
# Checkpoint 58 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch58.pth
# Epoch 58: [4/4] Loss: 0.476
# Epoch 58: [4/4] Loss: 0.468
# Epoch 58: [4/4] Loss: 0.519
# Epoch 58: [4/4] Loss: 0.483
# Dice: 0.575  Val Loss: 0.423
# Checkpoint 59 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch59.pth
# Epoch 59: [4/4] Loss: 0.518
# Epoch 59: [4/4] Loss: 0.473
# Epoch 59: [4/4] Loss: 0.467
# Epoch 59: [4/4] Loss: 0.453
# Dice: 0.570  Val Loss: 0.426
# Checkpoint 60 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch60.pth
# Epoch 60: [4/4] Loss: 0.495
# Epoch 60: [4/4] Loss: 0.466
# Epoch 60: [4/4] Loss: 0.462
# Epoch 60: [4/4] Loss: 0.473
# Dice: 0.568  Val Loss: 0.425
# Checkpoint 61 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch61.pth
# Epoch 61: [4/4] Loss: 0.574
# Epoch 61: [4/4] Loss: 0.481
# Epoch 61: [4/4] Loss: 0.477
# Epoch 61: [4/4] Loss: 0.472
# Dice: 0.567  Val Loss: 0.428
# Checkpoint 62 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch62.pth
# Epoch 62: [4/4] Loss: 0.509
# Epoch 62: [4/4] Loss: 0.451
# Epoch 62: [4/4] Loss: 0.451
# Epoch 62: [4/4] Loss: 0.474
# Dice: 0.574  Val Loss: 0.414
# Checkpoint 63 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch63.pth
# Epoch 63: [4/4] Loss: 0.402
# Epoch 63: [4/4] Loss: 0.442
# Epoch 63: [4/4] Loss: 0.438
# Epoch 63: [4/4] Loss: 0.467
# Dice: 0.577  Val Loss: 0.404
# Checkpoint 64 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch64.pth
# Epoch 64: [4/4] Loss: 0.377
# Epoch 64: [4/4] Loss: 0.424
# Epoch 64: [4/4] Loss: 0.449
# Epoch 64: [4/4] Loss: 0.439
# Dice: 0.586  Val Loss: 0.387
# Checkpoint 65 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch65.pth
# Epoch 65: [4/4] Loss: 0.415
# Epoch 65: [4/4] Loss: 0.397
# Epoch 65: [4/4] Loss: 0.419
# Epoch 65: [4/4] Loss: 0.441
# Dice: 0.589  Val Loss: 0.397
# Checkpoint 66 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch66.pth
# Epoch 66: [4/4] Loss: 0.354
# Epoch 66: [4/4] Loss: 0.428
# Epoch 66: [4/4] Loss: 0.456
# Epoch 66: [4/4] Loss: 0.434
# Dice: 0.587  Val Loss: 0.409
# Checkpoint 67 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch67.pth
# Epoch 67: [4/4] Loss: 0.458
# Epoch 67: [4/4] Loss: 0.418
# Epoch 67: [4/4] Loss: 0.427
# Epoch 67: [4/4] Loss: 0.448
# Dice: 0.591  Val Loss: 0.400
# Checkpoint 68 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch68.pth
# Epoch 68: [4/4] Loss: 0.504
# Epoch 68: [4/4] Loss: 0.467
# Epoch 68: [4/4] Loss: 0.418
# Epoch 68: [4/4] Loss: 0.425
# Dice: 0.592  Val Loss: 0.402
# Checkpoint 69 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch69.pth
# Epoch 69: [4/4] Loss: 0.371
# Epoch 69: [4/4] Loss: 0.345
# Epoch 69: [4/4] Loss: 0.412
# Epoch 69: [4/4] Loss: 0.426
# Dice: 0.595  Val Loss: 0.389
# Checkpoint 70 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch70.pth
# Epoch 70: [4/4] Loss: 0.342
# Epoch 70: [4/4] Loss: 0.396
# Epoch 70: [4/4] Loss: 0.410
# Epoch 70: [4/4] Loss: 0.427
# Dice: 0.595  Val Loss: 0.388
# Checkpoint 71 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch71.pth
# Epoch 71: [4/4] Loss: 0.445
# Epoch 71: [4/4] Loss: 0.455
# Epoch 71: [4/4] Loss: 0.411
# Epoch 71: [4/4] Loss: 0.422
# Dice: 0.597  Val Loss: 0.398
# Checkpoint 72 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch72.pth
# Epoch 72: [4/4] Loss: 0.441
# Epoch 72: [4/4] Loss: 0.447
# Epoch 72: [4/4] Loss: 0.435
# Epoch 72: [4/4] Loss: 0.435
# Dice: 0.600  Val Loss: 0.399
# Checkpoint 73 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch73.pth
# Epoch 73: [4/4] Loss: 0.491
# Epoch 73: [4/4] Loss: 0.458
# Epoch 73: [4/4] Loss: 0.435
# Epoch 73: [4/4] Loss: 0.430
# Dice: 0.595  Val Loss: 0.399
# Checkpoint 74 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch74.pth
# Epoch 74: [4/4] Loss: 0.462
# Epoch 74: [4/4] Loss: 0.420
# Epoch 74: [4/4] Loss: 0.440
# Epoch 74: [4/4] Loss: 0.423
# Dice: 0.598  Val Loss: 0.393
# Checkpoint 75 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch75.pth
# Epoch 75: [4/4] Loss: 0.538
# Epoch 75: [4/4] Loss: 0.446
# Epoch 75: [4/4] Loss: 0.429
# Epoch 75: [4/4] Loss: 0.424
# Dice: 0.605  Val Loss: 0.381
# Checkpoint 76 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch76.pth
# Epoch 76: [4/4] Loss: 0.507
# Epoch 76: [4/4] Loss: 0.423
# Epoch 76: [4/4] Loss: 0.405
# Epoch 76: [4/4] Loss: 0.403
# Dice: 0.613  Val Loss: 0.380
# Checkpoint 77 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch77.pth
# Epoch 77: [4/4] Loss: 0.416
# Epoch 77: [4/4] Loss: 0.407
# Epoch 77: [4/4] Loss: 0.435
# Epoch 77: [4/4] Loss: 0.445
# Dice: 0.622  Val Loss: 0.386
# Checkpoint 78 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch78.pth
# Epoch 78: [4/4] Loss: 0.586
# Epoch 78: [4/4] Loss: 0.532
# Epoch 78: [4/4] Loss: 0.468
# Epoch 78: [4/4] Loss: 0.445
# Dice: 0.628  Val Loss: 0.380
# Checkpoint 79 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch79.pth
# Epoch 79: [4/4] Loss: 0.401
# Epoch 79: [4/4] Loss: 0.407
# Epoch 79: [4/4] Loss: 0.418
# Epoch 79: [4/4] Loss: 0.421
# Dice: 0.632  Val Loss: 0.379
# Checkpoint 80 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch80.pth
# Epoch 80: [4/4] Loss: 0.467
# Epoch 80: [4/4] Loss: 0.446
# Epoch 80: [4/4] Loss: 0.423
# Epoch 80: [4/4] Loss: 0.420
# Dice: 0.630  Val Loss: 0.369
# Checkpoint 81 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch81.pth
# Epoch 81: [4/4] Loss: 0.341
# Epoch 81: [4/4] Loss: 0.420
# Epoch 81: [4/4] Loss: 0.406
# Epoch 81: [4/4] Loss: 0.413
# Dice: 0.631  Val Loss: 0.371
# Checkpoint 82 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch82.pth
# Epoch 82: [4/4] Loss: 0.468
# Epoch 82: [4/4] Loss: 0.426
# Epoch 82: [4/4] Loss: 0.394
# Epoch 82: [4/4] Loss: 0.401
# Dice: 0.625  Val Loss: 0.372
# Checkpoint 83 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch83.pth
# Epoch 83: [4/4] Loss: 0.311
# Epoch 83: [4/4] Loss: 0.346
# Epoch 83: [4/4] Loss: 0.391
# Epoch 83: [4/4] Loss: 0.410
# Dice: 0.619  Val Loss: 0.383
# Checkpoint 84 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch84.pth
# Epoch 84: [4/4] Loss: 0.407
# Epoch 84: [4/4] Loss: 0.415
# Epoch 84: [4/4] Loss: 0.404
# Epoch 84: [4/4] Loss: 0.403
# Dice: 0.617  Val Loss: 0.374
# Checkpoint 85 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch85.pth
# Epoch 85: [4/4] Loss: 0.331
# Epoch 85: [4/4] Loss: 0.358
# Epoch 85: [4/4] Loss: 0.402
# Epoch 85: [4/4] Loss: 0.387
# Dice: 0.617  Val Loss: 0.373
# Checkpoint 86 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch86.pth
# Epoch 86: [4/4] Loss: 0.438
# Epoch 86: [4/4] Loss: 0.395
# Epoch 86: [4/4] Loss: 0.412
# Epoch 86: [4/4] Loss: 0.398
# Dice: 0.611  Val Loss: 0.371
# Checkpoint 87 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch87.pth
# Epoch 87: [4/4] Loss: 0.478
# Epoch 87: [4/4] Loss: 0.387
# Epoch 87: [4/4] Loss: 0.382
# Epoch 87: [4/4] Loss: 0.385
# Dice: 0.613  Val Loss: 0.367
# Checkpoint 88 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch88.pth
# Epoch 88: [4/4] Loss: 0.321
# Epoch 88: [4/4] Loss: 0.407
# Epoch 88: [4/4] Loss: 0.393
# Epoch 88: [4/4] Loss: 0.412
# Dice: 0.614  Val Loss: 0.370
# Checkpoint 89 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch89.pth
# Epoch 89: [4/4] Loss: 0.369
# Epoch 89: [4/4] Loss: 0.393
# Epoch 89: [4/4] Loss: 0.364
# Epoch 89: [4/4] Loss: 0.391
# Dice: 0.614  Val Loss: 0.363
# Checkpoint 90 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch90.pth
# Epoch 90: [4/4] Loss: 0.346
# Epoch 90: [4/4] Loss: 0.376
# Epoch 90: [4/4] Loss: 0.375
# Epoch 90: [4/4] Loss: 0.389
# Dice: 0.617  Val Loss: 0.354
# Checkpoint 91 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch91.pth
# Epoch 91: [4/4] Loss: 0.446
# Epoch 91: [4/4] Loss: 0.385
# Epoch 91: [4/4] Loss: 0.361
# Epoch 91: [4/4] Loss: 0.367
# Dice: 0.616  Val Loss: 0.361
# Checkpoint 92 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch92.pth
# Epoch 92: [4/4] Loss: 0.404
# Epoch 92: [4/4] Loss: 0.336
# Epoch 92: [4/4] Loss: 0.353
# Epoch 92: [4/4] Loss: 0.369
# Dice: 0.612  Val Loss: 0.372
# Checkpoint 93 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch93.pth
# Epoch 93: [4/4] Loss: 0.358
# Epoch 93: [4/4] Loss: 0.363
# Epoch 93: [4/4] Loss: 0.363
# Epoch 93: [4/4] Loss: 0.358
# Dice: 0.613  Val Loss: 0.368
# Checkpoint 94 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch94.pth
# Epoch 94: [4/4] Loss: 0.287
# Epoch 94: [4/4] Loss: 0.342
# Epoch 94: [4/4] Loss: 0.350
# Epoch 94: [4/4] Loss: 0.384
# Dice: 0.620  Val Loss: 0.355
# Checkpoint 95 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch95.pth
# Epoch 95: [4/4] Loss: 0.353
# Epoch 95: [4/4] Loss: 0.351
# Epoch 95: [4/4] Loss: 0.366
# Epoch 95: [4/4] Loss: 0.373
# Dice: 0.616  Val Loss: 0.362
# Checkpoint 96 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch96.pth
# Epoch 96: [4/4] Loss: 0.443
# Epoch 96: [4/4] Loss: 0.379
# Epoch 96: [4/4] Loss: 0.369
# Epoch 96: [4/4] Loss: 0.371
# Dice: 0.618  Val Loss: 0.356
# Checkpoint 97 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch97.pth
# Epoch 97: [4/4] Loss: 0.295
# Epoch 97: [4/4] Loss: 0.343
# Epoch 97: [4/4] Loss: 0.362
# Epoch 97: [4/4] Loss: 0.373
# Dice: 0.616  Val Loss: 0.358
# Checkpoint 98 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch98.pth
# Epoch 98: [4/4] Loss: 0.350
# Epoch 98: [4/4] Loss: 0.365
# Epoch 98: [4/4] Loss: 0.357
# Epoch 98: [4/4] Loss: 0.368
# Dice: 0.612  Val Loss: 0.367
# Checkpoint 99 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch99.pth
# Epoch 99: [4/4] Loss: 0.377
# Epoch 99: [4/4] Loss: 0.338
# Epoch 99: [4/4] Loss: 0.335
# Epoch 99: [4/4] Loss: 0.352
# Dice: 0.617  Val Loss: 0.356
# Checkpoint 100 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch100.pth
# Epoch 100: [4/4] Loss: 0.402
# Epoch 100: [4/4] Loss: 0.408
# Epoch 100: [4/4] Loss: 0.363
# Epoch 100: [4/4] Loss: 0.355
# Dice: 0.617  Val Loss: 0.353
# Checkpoint 101 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch101.pth
# Epoch 101: [4/4] Loss: 0.368
# Epoch 101: [4/4] Loss: 0.335
# Epoch 101: [4/4] Loss: 0.344
# Epoch 101: [4/4] Loss: 0.348
# Dice: 0.617  Val Loss: 0.351
# Checkpoint 102 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch102.pth
# Epoch 102: [4/4] Loss: 0.338
# Epoch 102: [4/4] Loss: 0.343
# Epoch 102: [4/4] Loss: 0.357
# Epoch 102: [4/4] Loss: 0.350
# Dice: 0.616  Val Loss: 0.356
# Checkpoint 103 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch103.pth
# Epoch 103: [4/4] Loss: 0.323
# Epoch 103: [4/4] Loss: 0.341
# Epoch 103: [4/4] Loss: 0.336
# Epoch 103: [4/4] Loss: 0.352
# Dice: 0.614  Val Loss: 0.361
# Checkpoint 104 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch104.pth
# Epoch 104: [4/4] Loss: 0.329
# Epoch 104: [4/4] Loss: 0.350
# Epoch 104: [4/4] Loss: 0.334
# Epoch 104: [4/4] Loss: 0.341
# Dice: 0.618  Val Loss: 0.357
# Checkpoint 105 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch105.pth
# Epoch 105: [4/4] Loss: 0.372
# Epoch 105: [4/4] Loss: 0.401
# Epoch 105: [4/4] Loss: 0.357
# Epoch 105: [4/4] Loss: 0.340
# Dice: 0.621  Val Loss: 0.356
# Checkpoint 106 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch106.pth
# Epoch 106: [4/4] Loss: 0.362
# Epoch 106: [4/4] Loss: 0.333
# Epoch 106: [4/4] Loss: 0.344
# Epoch 106: [4/4] Loss: 0.346
# Dice: 0.625  Val Loss: 0.344
# Checkpoint 107 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch107.pth
# Epoch 107: [4/4] Loss: 0.313
# Epoch 107: [4/4] Loss: 0.328
# Epoch 107: [4/4] Loss: 0.325
# Epoch 107: [4/4] Loss: 0.346
# Dice: 0.626  Val Loss: 0.342
# Checkpoint 108 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch108.pth
# Epoch 108: [4/4] Loss: 0.359
# Epoch 108: [4/4] Loss: 0.372
# Epoch 108: [4/4] Loss: 0.389
# Epoch 108: [4/4] Loss: 0.380
# Dice: 0.628  Val Loss: 0.347
# Checkpoint 109 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch109.pth
# Epoch 109: [4/4] Loss: 0.391
# Epoch 109: [4/4] Loss: 0.350
# Epoch 109: [4/4] Loss: 0.364
# Epoch 109: [4/4] Loss: 0.361
# Dice: 0.630  Val Loss: 0.355
# Checkpoint 110 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch110.pth
# Epoch 110: [4/4] Loss: 0.436
# Epoch 110: [4/4] Loss: 0.404
# Epoch 110: [4/4] Loss: 0.392
# Epoch 110: [4/4] Loss: 0.391
# Dice: 0.634  Val Loss: 0.340
# Checkpoint 111 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch111.pth
# Epoch 111: [4/4] Loss: 0.350
# Epoch 111: [4/4] Loss: 0.315
# Epoch 111: [4/4] Loss: 0.352
# Epoch 111: [4/4] Loss: 0.363
# Dice: 0.630  Val Loss: 0.352
# Checkpoint 112 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch112.pth
# Epoch 112: [4/4] Loss: 0.342
# Epoch 112: [4/4] Loss: 0.411
# Epoch 112: [4/4] Loss: 0.366
# Epoch 112: [4/4] Loss: 0.359
# Dice: 0.630  Val Loss: 0.349
# Checkpoint 113 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch113.pth
# Epoch 113: [4/4] Loss: 0.339
# Epoch 113: [4/4] Loss: 0.377
# Epoch 113: [4/4] Loss: 0.351
# Epoch 113: [4/4] Loss: 0.360
# Dice: 0.635  Val Loss: 0.349
# Checkpoint 114 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch114.pth
# Epoch 114: [4/4] Loss: 0.351
# Epoch 114: [4/4] Loss: 0.330
# Epoch 114: [4/4] Loss: 0.367
# Epoch 114: [4/4] Loss: 0.358
# Dice: 0.638  Val Loss: 0.341
# Checkpoint 115 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch115.pth
# Epoch 115: [4/4] Loss: 0.310
# Epoch 115: [4/4] Loss: 0.325
# Epoch 115: [4/4] Loss: 0.340
# Epoch 115: [4/4] Loss: 0.342
# Dice: 0.639  Val Loss: 0.334
# Checkpoint 116 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch116.pth
# Epoch 116: [4/4] Loss: 0.338
# Epoch 116: [4/4] Loss: 0.342
# Epoch 116: [4/4] Loss: 0.336
# Epoch 116: [4/4] Loss: 0.349
# Dice: 0.629  Val Loss: 0.350
# Checkpoint 117 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch117.pth
# Epoch 117: [4/4] Loss: 0.321
# Epoch 117: [4/4] Loss: 0.361
# Epoch 117: [4/4] Loss: 0.346
# Epoch 117: [4/4] Loss: 0.365
# Dice: 0.626  Val Loss: 0.352
# Checkpoint 118 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch118.pth
# Epoch 118: [4/4] Loss: 0.264
# Epoch 118: [4/4] Loss: 0.324
# Epoch 118: [4/4] Loss: 0.355
# Epoch 118: [4/4] Loss: 0.359
# Dice: 0.626  Val Loss: 0.350
# Checkpoint 119 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch119.pth
# Epoch 119: [4/4] Loss: 0.319
# Epoch 119: [4/4] Loss: 0.340
# Epoch 119: [4/4] Loss: 0.323
# Epoch 119: [4/4] Loss: 0.347
# Dice: 0.625  Val Loss: 0.343
# Checkpoint 120 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch120.pth
# Epoch 120: [4/4] Loss: 0.268
# Epoch 120: [4/4] Loss: 0.328
# Epoch 120: [4/4] Loss: 0.354
# Epoch 120: [4/4] Loss: 0.369
# Dice: 0.630  Val Loss: 0.332
# Checkpoint 121 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch121.pth
# Epoch 121: [4/4] Loss: 0.384
# Epoch 121: [4/4] Loss: 0.376
# Epoch 121: [4/4] Loss: 0.343
# Epoch 121: [4/4] Loss: 0.361
# Dice: 0.630  Val Loss: 0.341
# Checkpoint 122 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch122.pth
# Epoch 122: [4/4] Loss: 0.349
# Epoch 122: [4/4] Loss: 0.362
# Epoch 122: [4/4] Loss: 0.376
# Epoch 122: [4/4] Loss: 0.356
# Dice: 0.623  Val Loss: 0.354
# Checkpoint 123 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch123.pth
# Epoch 123: [4/4] Loss: 0.391
# Epoch 123: [4/4] Loss: 0.360
# Epoch 123: [4/4] Loss: 0.349
# Epoch 123: [4/4] Loss: 0.341
# Dice: 0.622  Val Loss: 0.353
# Checkpoint 124 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch124.pth
# Epoch 124: [4/4] Loss: 0.280
# Epoch 124: [4/4] Loss: 0.334
# Epoch 124: [4/4] Loss: 0.331
# Epoch 124: [4/4] Loss: 0.351
# Dice: 0.625  Val Loss: 0.353
# Checkpoint 125 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch125.pth
# Epoch 125: [4/4] Loss: 0.292
# Epoch 125: [4/4] Loss: 0.312
# Epoch 125: [4/4] Loss: 0.355
# Epoch 125: [4/4] Loss: 0.343
# Dice: 0.632  Val Loss: 0.340
# Checkpoint 126 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch126.pth
# Epoch 126: [4/4] Loss: 0.411
# Epoch 126: [4/4] Loss: 0.407
# Epoch 126: [4/4] Loss: 0.365
# Epoch 126: [4/4] Loss: 0.355
# Dice: 0.636  Val Loss: 0.328
# Checkpoint 127 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch127.pth
# Epoch 127: [4/4] Loss: 0.361
# Epoch 127: [4/4] Loss: 0.354
# Epoch 127: [4/4] Loss: 0.359
# Epoch 127: [4/4] Loss: 0.363
# Dice: 0.634  Val Loss: 0.335
# Checkpoint 128 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch128.pth
# Epoch 128: [4/4] Loss: 0.302
# Epoch 128: [4/4] Loss: 0.350
# Epoch 128: [4/4] Loss: 0.354
# Epoch 128: [4/4] Loss: 0.345
# Dice: 0.632  Val Loss: 0.341
# Checkpoint 129 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch129.pth
# Epoch 129: [4/4] Loss: 0.307
# Epoch 129: [4/4] Loss: 0.318
# Epoch 129: [4/4] Loss: 0.323
# Epoch 129: [4/4] Loss: 0.339
# Dice: 0.629  Val Loss: 0.343
# Checkpoint 130 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch130.pth
# Epoch 130: [4/4] Loss: 0.280
# Epoch 130: [4/4] Loss: 0.315
# Epoch 130: [4/4] Loss: 0.313
# Epoch 130: [4/4] Loss: 0.344
# Dice: 0.628  Val Loss: 0.345
# Checkpoint 131 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch131.pth
# Epoch 131: [4/4] Loss: 0.404
# Epoch 131: [4/4] Loss: 0.400
# Epoch 131: [4/4] Loss: 0.369
# Epoch 131: [4/4] Loss: 0.346
# Dice: 0.630  Val Loss: 0.340
# Checkpoint 132 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch132.pth
# Epoch 132: [4/4] Loss: 0.311
# Epoch 132: [4/4] Loss: 0.293
# Epoch 132: [4/4] Loss: 0.312
# Epoch 132: [4/4] Loss: 0.327
# Dice: 0.634  Val Loss: 0.339
# Checkpoint 133 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch133.pth
# Epoch 133: [4/4] Loss: 0.341
# Epoch 133: [4/4] Loss: 0.343
# Epoch 133: [4/4] Loss: 0.331
# Epoch 133: [4/4] Loss: 0.346
# Dice: 0.633  Val Loss: 0.335
# Checkpoint 134 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch134.pth
# Epoch 134: [4/4] Loss: 0.272
# Epoch 134: [4/4] Loss: 0.315
# Epoch 134: [4/4] Loss: 0.310
# Epoch 134: [4/4] Loss: 0.327
# Dice: 0.634  Val Loss: 0.332
# Checkpoint 135 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch135.pth
# Epoch 135: [4/4] Loss: 0.303
# Epoch 135: [4/4] Loss: 0.323
# Epoch 135: [4/4] Loss: 0.347
# Epoch 135: [4/4] Loss: 0.329
# Dice: 0.631  Val Loss: 0.338
# Checkpoint 136 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch136.pth
# Epoch 136: [4/4] Loss: 0.310
# Epoch 136: [4/4] Loss: 0.303
# Epoch 136: [4/4] Loss: 0.324
# Epoch 136: [4/4] Loss: 0.322
# Dice: 0.631  Val Loss: 0.343
# Checkpoint 137 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch137.pth
# Epoch 137: [4/4] Loss: 0.410
# Epoch 137: [4/4] Loss: 0.374
# Epoch 137: [4/4] Loss: 0.349
# Epoch 137: [4/4] Loss: 0.334
# Dice: 0.632  Val Loss: 0.337
# Checkpoint 138 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch138.pth
# Epoch 138: [4/4] Loss: 0.332
# Epoch 138: [4/4] Loss: 0.307
# Epoch 138: [4/4] Loss: 0.320
# Epoch 138: [4/4] Loss: 0.340
# Dice: 0.632  Val Loss: 0.339
# Checkpoint 139 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch139.pth
# Epoch 139: [4/4] Loss: 0.311
# Epoch 139: [4/4] Loss: 0.317
# Epoch 139: [4/4] Loss: 0.329
# Epoch 139: [4/4] Loss: 0.328
# Dice: 0.637  Val Loss: 0.332
# Checkpoint 140 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch140.pth
# Epoch 140: [4/4] Loss: 0.321
# Epoch 140: [4/4] Loss: 0.301
# Epoch 140: [4/4] Loss: 0.344
# Epoch 140: [4/4] Loss: 0.338
# Dice: 0.639  Val Loss: 0.330
# Checkpoint 141 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch141.pth
# Epoch 141: [4/4] Loss: 0.370
# Epoch 141: [4/4] Loss: 0.341
# Epoch 141: [4/4] Loss: 0.322
# Epoch 141: [4/4] Loss: 0.325
# Dice: 0.642  Val Loss: 0.326
# Checkpoint 142 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch142.pth
# Epoch 142: [4/4] Loss: 0.335
# Epoch 142: [4/4] Loss: 0.323
# Epoch 142: [4/4] Loss: 0.326
# Epoch 142: [4/4] Loss: 0.337
# Dice: 0.640  Val Loss: 0.329
# Checkpoint 143 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch143.pth
# Epoch 143: [4/4] Loss: 0.304
# Epoch 143: [4/4] Loss: 0.319
# Epoch 143: [4/4] Loss: 0.327
# Epoch 143: [4/4] Loss: 0.341
# Dice: 0.641  Val Loss: 0.325
# Checkpoint 144 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch144.pth
# Epoch 144: [4/4] Loss: 0.303
# Epoch 144: [4/4] Loss: 0.334
# Epoch 144: [4/4] Loss: 0.323
# Epoch 144: [4/4] Loss: 0.328
# Dice: 0.641  Val Loss: 0.327
# Checkpoint 145 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch145.pth
# Epoch 145: [4/4] Loss: 0.269
# Epoch 145: [4/4] Loss: 0.303
# Epoch 145: [4/4] Loss: 0.329
# Epoch 145: [4/4] Loss: 0.326
# Dice: 0.637  Val Loss: 0.340
# Checkpoint 146 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch146.pth
# Epoch 146: [4/4] Loss: 0.369
# Epoch 146: [4/4] Loss: 0.365
# Epoch 146: [4/4] Loss: 0.334
# Epoch 146: [4/4] Loss: 0.344
# Dice: 0.636  Val Loss: 0.341
# Checkpoint 147 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch147.pth
# Epoch 147: [4/4] Loss: 0.288
# Epoch 147: [4/4] Loss: 0.294
# Epoch 147: [4/4] Loss: 0.307
# Epoch 147: [4/4] Loss: 0.327
# Dice: 0.643  Val Loss: 0.332
# Checkpoint 148 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch148.pth
# Epoch 148: [4/4] Loss: 0.288
# Epoch 148: [4/4] Loss: 0.313
# Epoch 148: [4/4] Loss: 0.334
# Epoch 148: [4/4] Loss: 0.329
# Dice: 0.651  Val Loss: 0.320
# Checkpoint 149 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch149.pth
# Epoch 149: [4/4] Loss: 0.279
# Epoch 149: [4/4] Loss: 0.257
# Epoch 149: [4/4] Loss: 0.311
# Epoch 149: [4/4] Loss: 0.318
# Dice: 0.653  Val Loss: 0.319
# Checkpoint 150 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch150.pth
# Epoch 150: [4/4] Loss: 0.345
# Epoch 150: [4/4] Loss: 0.356
# Epoch 150: [4/4] Loss: 0.349
# Epoch 150: [4/4] Loss: 0.328
# Dice: 0.654  Val Loss: 0.321
# Checkpoint 151 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch151.pth
# Epoch 151: [4/4] Loss: 0.374
# Epoch 151: [4/4] Loss: 0.341
# Epoch 151: [4/4] Loss: 0.332
# Epoch 151: [4/4] Loss: 0.317
# Dice: 0.648  Val Loss: 0.331
# Checkpoint 152 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch152.pth
# Epoch 152: [4/4] Loss: 0.352
# Epoch 152: [4/4] Loss: 0.331
# Epoch 152: [4/4] Loss: 0.337
# Epoch 152: [4/4] Loss: 0.325
# Dice: 0.645  Val Loss: 0.332
# Checkpoint 153 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch153.pth
# Epoch 153: [4/4] Loss: 0.309
# Epoch 153: [4/4] Loss: 0.315
# Epoch 153: [4/4] Loss: 0.324
# Epoch 153: [4/4] Loss: 0.344
# Dice: 0.642  Val Loss: 0.334
# Checkpoint 154 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch154.pth
# Epoch 154: [4/4] Loss: 0.332
# Epoch 154: [4/4] Loss: 0.326
# Epoch 154: [4/4] Loss: 0.314
# Epoch 154: [4/4] Loss: 0.319
# Dice: 0.645  Val Loss: 0.332
# Checkpoint 155 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch155.pth
# Epoch 155: [4/4] Loss: 0.312
# Epoch 155: [4/4] Loss: 0.304
# Epoch 155: [4/4] Loss: 0.314
# Epoch 155: [4/4] Loss: 0.320
# Dice: 0.646  Val Loss: 0.328
# Checkpoint 156 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch156.pth
# Epoch 156: [4/4] Loss: 0.343
# Epoch 156: [4/4] Loss: 0.312
# Epoch 156: [4/4] Loss: 0.321
# Epoch 156: [4/4] Loss: 0.314
# Dice: 0.648  Val Loss: 0.326
# Checkpoint 157 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch157.pth
# Epoch 157: [4/4] Loss: 0.306
# Epoch 157: [4/4] Loss: 0.327
# Epoch 157: [4/4] Loss: 0.316
# Epoch 157: [4/4] Loss: 0.309
# Dice: 0.646  Val Loss: 0.337
# Checkpoint 158 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch158.pth
# Epoch 158: [4/4] Loss: 0.310
# Epoch 158: [4/4] Loss: 0.315
# Epoch 158: [4/4] Loss: 0.310
# Epoch 158: [4/4] Loss: 0.321
# Dice: 0.649  Val Loss: 0.328
# Checkpoint 159 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch159.pth
# Epoch 159: [4/4] Loss: 0.300
# Epoch 159: [4/4] Loss: 0.342
# Epoch 159: [4/4] Loss: 0.326
# Epoch 159: [4/4] Loss: 0.325
# Dice: 0.656  Val Loss: 0.317
# Checkpoint 160 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch160.pth
# Epoch 160: [4/4] Loss: 0.319
# Epoch 160: [4/4] Loss: 0.290
# Epoch 160: [4/4] Loss: 0.318
# Epoch 160: [4/4] Loss: 0.327
# Dice: 0.653  Val Loss: 0.322
# Checkpoint 161 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch161.pth
# Epoch 161: [4/4] Loss: 0.344
# Epoch 161: [4/4] Loss: 0.344
# Epoch 161: [4/4] Loss: 0.314
# Epoch 161: [4/4] Loss: 0.310
# Dice: 0.650  Val Loss: 0.328
# Checkpoint 162 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch162.pth
# Epoch 162: [4/4] Loss: 0.339
# Epoch 162: [4/4] Loss: 0.335
# Epoch 162: [4/4] Loss: 0.318
# Epoch 162: [4/4] Loss: 0.321
# Dice: 0.652  Val Loss: 0.323
# Checkpoint 163 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch163.pth
# Epoch 163: [4/4] Loss: 0.329
# Epoch 163: [4/4] Loss: 0.337
# Epoch 163: [4/4] Loss: 0.340
# Epoch 163: [4/4] Loss: 0.318
# Dice: 0.652  Val Loss: 0.323
# Checkpoint 164 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch164.pth
# Epoch 164: [4/4] Loss: 0.269
# Epoch 164: [4/4] Loss: 0.306
# Epoch 164: [4/4] Loss: 0.297
# Epoch 164: [4/4] Loss: 0.310
# Dice: 0.651  Val Loss: 0.327
# Checkpoint 165 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch165.pth
# Epoch 165: [4/4] Loss: 0.290
# Epoch 165: [4/4] Loss: 0.334
# Epoch 165: [4/4] Loss: 0.334
# Epoch 165: [4/4] Loss: 0.320
# Dice: 0.652  Val Loss: 0.327
# Checkpoint 166 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch166.pth
# Epoch 166: [4/4] Loss: 0.345
# Epoch 166: [4/4] Loss: 0.331
# Epoch 166: [4/4] Loss: 0.328
# Epoch 166: [4/4] Loss: 0.322
# Dice: 0.658  Val Loss: 0.316
# Checkpoint 167 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch167.pth
# Epoch 167: [4/4] Loss: 0.332
# Epoch 167: [4/4] Loss: 0.294
# Epoch 167: [4/4] Loss: 0.305
# Epoch 167: [4/4] Loss: 0.315
# Dice: 0.656  Val Loss: 0.317
# Checkpoint 168 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch168.pth
# Epoch 168: [4/4] Loss: 0.292
# Epoch 168: [4/4] Loss: 0.313
# Epoch 168: [4/4] Loss: 0.313
# Epoch 168: [4/4] Loss: 0.306
# Dice: 0.649  Val Loss: 0.328
# Checkpoint 169 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch169.pth
# Epoch 169: [4/4] Loss: 0.336
# Epoch 169: [4/4] Loss: 0.305
# Epoch 169: [4/4] Loss: 0.316
# Epoch 169: [4/4] Loss: 0.313
# Dice: 0.654  Val Loss: 0.322
# Checkpoint 170 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch170.pth
# Epoch 170: [4/4] Loss: 0.272
# Epoch 170: [4/4] Loss: 0.312
# Epoch 170: [4/4] Loss: 0.312
# Epoch 170: [4/4] Loss: 0.314
# Dice: 0.660  Val Loss: 0.313
# Checkpoint 171 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch171.pth
# Epoch 171: [4/4] Loss: 0.347
# Epoch 171: [4/4] Loss: 0.306
# Epoch 171: [4/4] Loss: 0.313
# Epoch 171: [4/4] Loss: 0.309
# Dice: 0.658  Val Loss: 0.317
# Checkpoint 172 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch172.pth
# Epoch 172: [4/4] Loss: 0.338
# Epoch 172: [4/4] Loss: 0.315
# Epoch 172: [4/4] Loss: 0.322
# Epoch 172: [4/4] Loss: 0.312
# Dice: 0.657  Val Loss: 0.318
# Checkpoint 173 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch173.pth
# Epoch 173: [4/4] Loss: 0.328
# Epoch 173: [4/4] Loss: 0.285
# Epoch 173: [4/4] Loss: 0.291
# Epoch 173: [4/4] Loss: 0.304
# Dice: 0.661  Val Loss: 0.314
# Checkpoint 174 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch174.pth
# Epoch 174: [4/4] Loss: 0.330
# Epoch 174: [4/4] Loss: 0.313
# Epoch 174: [4/4] Loss: 0.313
# Epoch 174: [4/4] Loss: 0.314
# Dice: 0.666  Val Loss: 0.303
# Checkpoint 175 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch175.pth
# Epoch 175: [4/4] Loss: 0.335
# Epoch 175: [4/4] Loss: 0.321
# Epoch 175: [4/4] Loss: 0.302
# Epoch 175: [4/4] Loss: 0.312
# Dice: 0.671  Val Loss: 0.299
# Checkpoint 176 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch176.pth
# Epoch 176: [4/4] Loss: 0.309
# Epoch 176: [4/4] Loss: 0.286
# Epoch 176: [4/4] Loss: 0.312
# Epoch 176: [4/4] Loss: 0.310
# Dice: 0.668  Val Loss: 0.305
# Checkpoint 177 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch177.pth
# Epoch 177: [4/4] Loss: 0.309
# Epoch 177: [4/4] Loss: 0.308
# Epoch 177: [4/4] Loss: 0.296
# Epoch 177: [4/4] Loss: 0.294
# Dice: 0.663  Val Loss: 0.307
# Checkpoint 178 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch178.pth
# Epoch 178: [4/4] Loss: 0.348
# Epoch 178: [4/4] Loss: 0.315
# Epoch 178: [4/4] Loss: 0.297
# Epoch 178: [4/4] Loss: 0.299
# Dice: 0.669  Val Loss: 0.302
# Checkpoint 179 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch179.pth
# Epoch 179: [4/4] Loss: 0.270
# Epoch 179: [4/4] Loss: 0.301
# Epoch 179: [4/4] Loss: 0.315
# Epoch 179: [4/4] Loss: 0.315
# Dice: 0.668  Val Loss: 0.312
# Checkpoint 180 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch180.pth
# Epoch 180: [4/4] Loss: 0.276
# Epoch 180: [4/4] Loss: 0.317
# Epoch 180: [4/4] Loss: 0.301
# Epoch 180: [4/4] Loss: 0.350
# Dice: 0.665  Val Loss: 0.330
# Checkpoint 181 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch181.pth
# Epoch 181: [4/4] Loss: 0.372
# Epoch 181: [4/4] Loss: 0.367
# Epoch 181: [4/4] Loss: 0.351
# Epoch 181: [4/4] Loss: 0.372
# Dice: 0.669  Val Loss: 0.323
# Checkpoint 182 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch182.pth
# Epoch 182: [4/4] Loss: 0.437
# Epoch 182: [4/4] Loss: 0.383
# Epoch 182: [4/4] Loss: 0.376
# Epoch 182: [4/4] Loss: 0.355
# Dice: 0.672  Val Loss: 0.326
# Checkpoint 183 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch183.pth
# Epoch 183: [4/4] Loss: 0.469
# Epoch 183: [4/4] Loss: 0.418
# Epoch 183: [4/4] Loss: 0.384
# Epoch 183: [4/4] Loss: 0.381
# Dice: 0.677  Val Loss: 0.312
# Checkpoint 184 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch184.pth
# Epoch 184: [4/4] Loss: 0.338
# Epoch 184: [4/4] Loss: 0.393
# Epoch 184: [4/4] Loss: 0.360
# Epoch 184: [4/4] Loss: 0.386
# Dice: 0.681  Val Loss: 0.302
# Checkpoint 185 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch185.pth
# Epoch 185: [4/4] Loss: 0.425
# Epoch 185: [4/4] Loss: 0.376
# Epoch 185: [4/4] Loss: 0.402
# Epoch 185: [4/4] Loss: 0.383
# Dice: 0.681  Val Loss: 0.299
# Checkpoint 186 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch186.pth
# Epoch 186: [4/4] Loss: 0.429
# Epoch 186: [4/4] Loss: 0.381
# Epoch 186: [4/4] Loss: 0.395
# Epoch 186: [4/4] Loss: 0.390
# Dice: 0.679  Val Loss: 0.301
# Checkpoint 187 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch187.pth
# Epoch 187: [4/4] Loss: 0.355
# Epoch 187: [4/4] Loss: 0.376
# Epoch 187: [4/4] Loss: 0.355
# Epoch 187: [4/4] Loss: 0.363
# Dice: 0.678  Val Loss: 0.296
# Checkpoint 188 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch188.pth
# Epoch 188: [4/4] Loss: 0.359
# Epoch 188: [4/4] Loss: 0.350
# Epoch 188: [4/4] Loss: 0.327
# Epoch 188: [4/4] Loss: 0.334
# Dice: 0.673  Val Loss: 0.342
# Checkpoint 189 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch189.pth
# Epoch 189: [4/4] Loss: 0.371
# Epoch 189: [4/4] Loss: 0.357
# Epoch 189: [4/4] Loss: 0.364
# Epoch 189: [4/4] Loss: 0.373
# Dice: 0.673  Val Loss: 0.317
# Checkpoint 190 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch190.pth
# Epoch 190: [4/4] Loss: 0.370
# Epoch 190: [4/4] Loss: 0.348
# Epoch 190: [4/4] Loss: 0.359
# Epoch 190: [4/4] Loss: 0.352
# Dice: 0.678  Val Loss: 0.298
# Checkpoint 191 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch191.pth
# Epoch 191: [4/4] Loss: 0.330
# Epoch 191: [4/4] Loss: 0.325
# Epoch 191: [4/4] Loss: 0.336
# Epoch 191: [4/4] Loss: 0.324
# Dice: 0.678  Val Loss: 0.300
# Checkpoint 192 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch192.pth
# Epoch 192: [4/4] Loss: 0.266
# Epoch 192: [4/4] Loss: 0.300
# Epoch 192: [4/4] Loss: 0.322
# Epoch 192: [4/4] Loss: 0.321
# Dice: 0.676  Val Loss: 0.302
# Checkpoint 193 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch193.pth
# Epoch 193: [4/4] Loss: 0.310
# Epoch 193: [4/4] Loss: 0.314
# Epoch 193: [4/4] Loss: 0.315
# Epoch 193: [4/4] Loss: 0.313
# Dice: 0.681  Val Loss: 0.302
# Checkpoint 194 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch194.pth
# Epoch 194: [4/4] Loss: 0.288
# Epoch 194: [4/4] Loss: 0.320
# Epoch 194: [4/4] Loss: 0.319
# Epoch 194: [4/4] Loss: 0.325
# Dice: 0.679  Val Loss: 0.307
# Checkpoint 195 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch195.pth
# Epoch 195: [4/4] Loss: 0.319
# Epoch 195: [4/4] Loss: 0.318
# Epoch 195: [4/4] Loss: 0.314
# Epoch 195: [4/4] Loss: 0.304
# Dice: 0.673  Val Loss: 0.313
# Checkpoint 196 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch196.pth
# Epoch 196: [4/4] Loss: 0.335
# Epoch 196: [4/4] Loss: 0.300
# Epoch 196: [4/4] Loss: 0.324
# Epoch 196: [4/4] Loss: 0.326
# Dice: 0.678  Val Loss: 0.322
# Checkpoint 197 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch197.pth
# Epoch 197: [4/4] Loss: 0.370
# Epoch 197: [4/4] Loss: 0.362
# Epoch 197: [4/4] Loss: 0.349
# Epoch 197: [4/4] Loss: 0.347
# Dice: 0.685  Val Loss: 0.298
# Checkpoint 198 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch198.pth
# Epoch 198: [4/4] Loss: 0.322
# Epoch 198: [4/4] Loss: 0.355
# Epoch 198: [4/4] Loss: 0.339
# Epoch 198: [4/4] Loss: 0.329
# Dice: 0.690  Val Loss: 0.292
# Checkpoint 199 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch199.pth
# Epoch 199: [4/4] Loss: 0.324
# Epoch 199: [4/4] Loss: 0.304
# Epoch 199: [4/4] Loss: 0.332
# Epoch 199: [4/4] Loss: 0.311
# Dice: 0.687  Val Loss: 0.302
# Checkpoint 200 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch200.pth
# Epoch 200: [4/4] Loss: 0.337
# Epoch 200: [4/4] Loss: 0.323
# Epoch 200: [4/4] Loss: 0.303
# Epoch 200: [4/4] Loss: 0.327
# Dice: 0.681  Val Loss: 0.302
# Checkpoint 201 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch201.pth
# Epoch 201: [4/4] Loss: 0.345
# Epoch 201: [4/4] Loss: 0.339
# Epoch 201: [4/4] Loss: 0.311
# Epoch 201: [4/4] Loss: 0.309
# Dice: 0.677  Val Loss: 0.306
# Checkpoint 202 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch202.pth
# Epoch 202: [4/4] Loss: 0.288
# Epoch 202: [4/4] Loss: 0.291
# Epoch 202: [4/4] Loss: 0.287
# Epoch 202: [4/4] Loss: 0.305
# Dice: 0.678  Val Loss: 0.306
# Checkpoint 203 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch203.pth
# Epoch 203: [4/4] Loss: 0.282
# Epoch 203: [4/4] Loss: 0.299
# Epoch 203: [4/4] Loss: 0.287
# Epoch 203: [4/4] Loss: 0.299
# Dice: 0.682  Val Loss: 0.300
# Checkpoint 204 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch204.pth
# Epoch 204: [4/4] Loss: 0.362
# Epoch 204: [4/4] Loss: 0.308
# Epoch 204: [4/4] Loss: 0.311
# ...
# Epoch 333: [4/4] Loss: 0.197
# Epoch 333: [4/4] Loss: 0.193
# Epoch 333: [4/4] Loss: 0.196
# Epoch 333: [4/4] Loss: 0.195
# Dice: 0.779  Val Loss: 0.195
# Checkpoint 334 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch334.pth
# Epoch 334: [4/4] Loss: 0.213
# Epoch 334: [4/4] Loss: 0.202
# Epoch 334: [4/4] Loss: 0.202
# Epoch 334: [4/4] Loss: 0.195
# Dice: 0.778  Val Loss: 0.193
# Checkpoint 335 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch335.pth
# Epoch 335: [4/4] Loss: 0.163
# Epoch 335: [4/4] Loss: 0.196
# Epoch 335: [4/4] Loss: 0.197
# Epoch 335: [4/4] Loss: 0.194
# Dice: 0.779  Val Loss: 0.194
# Checkpoint 336 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch336.pth
# Epoch 336: [4/4] Loss: 0.173
# Epoch 336: [4/4] Loss: 0.183
# Epoch 336: [4/4] Loss: 0.185
# Epoch 336: [4/4] Loss: 0.188
# Dice: 0.781  Val Loss: 0.193
# Checkpoint 337 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch337.pth
# Epoch 337: [4/4] Loss: 0.186
# Epoch 337: [4/4] Loss: 0.198
# Epoch 337: [4/4] Loss: 0.194
# Epoch 337: [4/4] Loss: 0.189
# Dice: 0.781  Val Loss: 0.192
# Checkpoint 338 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch338.pth
# Epoch 338: [4/4] Loss: 0.247
# Epoch 338: [4/4] Loss: 0.205
# Epoch 338: [4/4] Loss: 0.198
# Epoch 338: [4/4] Loss: 0.202
# Dice: 0.785  Val Loss: 0.202
# Checkpoint 339 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch339.pth
# Epoch 339: [4/4] Loss: 0.227
# Epoch 339: [4/4] Loss: 0.249
# Epoch 339: [4/4] Loss: 0.237
# Epoch 339: [4/4] Loss: 0.235
# Dice: 0.783  Val Loss: 0.197
# Checkpoint 340 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch340.pth
# Epoch 340: [4/4] Loss: 0.201
# Epoch 340: [4/4] Loss: 0.219
# Epoch 340: [4/4] Loss: 0.223
# Epoch 340: [4/4] Loss: 0.223
# Dice: 0.780  Val Loss: 0.191
# Checkpoint 341 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch341.pth
# Epoch 341: [4/4] Loss: 0.179
# Epoch 341: [4/4] Loss: 0.208
# Epoch 341: [4/4] Loss: 0.216
# Epoch 341: [4/4] Loss: 0.209
# Dice: 0.780  Val Loss: 0.196
# Checkpoint 342 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch342.pth
# Epoch 342: [4/4] Loss: 0.222
# Epoch 342: [4/4] Loss: 0.202
# Epoch 342: [4/4] Loss: 0.206
# Epoch 342: [4/4] Loss: 0.203
# Dice: 0.781  Val Loss: 0.191
# Checkpoint 343 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch343.pth
# Epoch 343: [4/4] Loss: 0.209
# Epoch 343: [4/4] Loss: 0.188
# Epoch 343: [4/4] Loss: 0.198
# Epoch 343: [4/4] Loss: 0.194
# Dice: 0.783  Val Loss: 0.191
# Checkpoint 344 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch344.pth
# Epoch 344: [4/4] Loss: 0.212
# Epoch 344: [4/4] Loss: 0.201
# Epoch 344: [4/4] Loss: 0.198
# Epoch 344: [4/4] Loss: 0.190
# Dice: 0.784  Val Loss: 0.190
# Checkpoint 345 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch345.pth
# Epoch 345: [4/4] Loss: 0.173
# Epoch 345: [4/4] Loss: 0.178
# Epoch 345: [4/4] Loss: 0.190
# Epoch 345: [4/4] Loss: 0.188
# Dice: 0.782  Val Loss: 0.186
# Checkpoint 346 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch346.pth
# Epoch 346: [4/4] Loss: 0.207
# Epoch 346: [4/4] Loss: 0.190
# Epoch 346: [4/4] Loss: 0.182
# Epoch 346: [4/4] Loss: 0.182
# Dice: 0.789  Val Loss: 0.187
# Checkpoint 347 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch347.pth
# Epoch 347: [4/4] Loss: 0.180
# Epoch 347: [4/4] Loss: 0.187
# Epoch 347: [4/4] Loss: 0.184
# Epoch 347: [4/4] Loss: 0.182
# Dice: 0.787  Val Loss: 0.185
# Checkpoint 348 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch348.pth
# Epoch 348: [4/4] Loss: 0.182
# Epoch 348: [4/4] Loss: 0.179
# Epoch 348: [4/4] Loss: 0.173
# Epoch 348: [4/4] Loss: 0.180
# Dice: 0.787  Val Loss: 0.188
# Checkpoint 349 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch349.pth
# Epoch 349: [4/4] Loss: 0.172
# Epoch 349: [4/4] Loss: 0.191
# Epoch 349: [4/4] Loss: 0.182
# Epoch 349: [4/4] Loss: 0.180
# Dice: 0.781  Val Loss: 0.186
# Checkpoint 350 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch350.pth
# Epoch 350: [4/4] Loss: 0.157
# Epoch 350: [4/4] Loss: 0.171
# Epoch 350: [4/4] Loss: 0.177
# Epoch 350: [4/4] Loss: 0.178
# Dice: 0.788  Val Loss: 0.186
# Checkpoint 351 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch351.pth
# Epoch 351: [4/4] Loss: 0.202
# Epoch 351: [4/4] Loss: 0.183
# Epoch 351: [4/4] Loss: 0.181
# Epoch 351: [4/4] Loss: 0.176
# Dice: 0.790  Val Loss: 0.184
# Checkpoint 352 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch352.pth
# Epoch 352: [4/4] Loss: 0.164
# Epoch 352: [4/4] Loss: 0.173
# Epoch 352: [4/4] Loss: 0.170
# Epoch 352: [4/4] Loss: 0.175
# Dice: 0.793  Val Loss: 0.185
# Checkpoint 353 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch353.pth
# Epoch 353: [4/4] Loss: 0.149
# Epoch 353: [4/4] Loss: 0.164
# Epoch 353: [4/4] Loss: 0.172
# Epoch 353: [4/4] Loss: 0.178
# Dice: 0.788  Val Loss: 0.185
# Checkpoint 354 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch354.pth
# Epoch 354: [4/4] Loss: 0.173
# Epoch 354: [4/4] Loss: 0.187
# Epoch 354: [4/4] Loss: 0.187
# Epoch 354: [4/4] Loss: 0.179
# Dice: 0.787  Val Loss: 0.185
# Checkpoint 355 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch355.pth
# Epoch 355: [4/4] Loss: 0.215
# Epoch 355: [4/4] Loss: 0.190
# Epoch 355: [4/4] Loss: 0.190
# Epoch 355: [4/4] Loss: 0.184
# Dice: 0.789  Val Loss: 0.183
# Checkpoint 356 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch356.pth
# Epoch 356: [4/4] Loss: 0.174
# Epoch 356: [4/4] Loss: 0.166
# Epoch 356: [4/4] Loss: 0.180
# Epoch 356: [4/4] Loss: 0.175
# Dice: 0.785  Val Loss: 0.184
# Checkpoint 357 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch357.pth
# Epoch 357: [4/4] Loss: 0.186
# Epoch 357: [4/4] Loss: 0.176
# Epoch 357: [4/4] Loss: 0.178
# Epoch 357: [4/4] Loss: 0.185
# Dice: 0.790  Val Loss: 0.189
# Checkpoint 358 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch358.pth
# Epoch 358: [4/4] Loss: 0.173
# Epoch 358: [4/4] Loss: 0.179
# Epoch 358: [4/4] Loss: 0.185
# Epoch 358: [4/4] Loss: 0.182
# Dice: 0.781  Val Loss: 0.184
# Checkpoint 359 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch359.pth
# Epoch 359: [4/4] Loss: 0.219
# Epoch 359: [4/4] Loss: 0.199
# Epoch 359: [4/4] Loss: 0.188
# Epoch 359: [4/4] Loss: 0.180
# Dice: 0.787  Val Loss: 0.186
# Checkpoint 360 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch360.pth
# Epoch 360: [4/4] Loss: 0.198
# Epoch 360: [4/4] Loss: 0.182
# Epoch 360: [4/4] Loss: 0.174
# Epoch 360: [4/4] Loss: 0.181
# Dice: 0.791  Val Loss: 0.181
# Checkpoint 361 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch361.pth
# Epoch 361: [4/4] Loss: 0.199
# Epoch 361: [4/4] Loss: 0.176
# Epoch 361: [4/4] Loss: 0.173
# Epoch 361: [4/4] Loss: 0.181
# Dice: 0.796  Val Loss: 0.183
# Checkpoint 362 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch362.pth
# Epoch 362: [4/4] Loss: 0.159
# Epoch 362: [4/4] Loss: 0.162
# Epoch 362: [4/4] Loss: 0.167
# Epoch 362: [4/4] Loss: 0.181
# Dice: 0.794  Val Loss: 0.181
# Checkpoint 363 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch363.pth
# Epoch 363: [4/4] Loss: 0.172
# Epoch 363: [4/4] Loss: 0.179
# Epoch 363: [4/4] Loss: 0.181
# Epoch 363: [4/4] Loss: 0.180
# Dice: 0.790  Val Loss: 0.188
# Checkpoint 364 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch364.pth
# Epoch 364: [4/4] Loss: 0.195
# Epoch 364: [4/4] Loss: 0.207
# Epoch 364: [4/4] Loss: 0.190
# Epoch 364: [4/4] Loss: 0.181
# Dice: 0.788  Val Loss: 0.184
# Checkpoint 365 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch365.pth
# Epoch 365: [4/4] Loss: 0.188
# Epoch 365: [4/4] Loss: 0.170
# Epoch 365: [4/4] Loss: 0.178
# Epoch 365: [4/4] Loss: 0.176
# Dice: 0.787  Val Loss: 0.185
# Checkpoint 366 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch366.pth
# Epoch 366: [4/4] Loss: 0.184
# Epoch 366: [4/4] Loss: 0.172
# Epoch 366: [4/4] Loss: 0.176
# Epoch 366: [4/4] Loss: 0.181
# Dice: 0.792  Val Loss: 0.195
# Checkpoint 367 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch367.pth
# Epoch 367: [4/4] Loss: 0.244
# Epoch 367: [4/4] Loss: 0.209
# Epoch 367: [4/4] Loss: 0.201
# Epoch 367: [4/4] Loss: 0.192
# Dice: 0.794  Val Loss: 0.182
# Checkpoint 368 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch368.pth
# Epoch 368: [4/4] Loss: 0.169
# Epoch 368: [4/4] Loss: 0.173
# Epoch 368: [4/4] Loss: 0.187
# Epoch 368: [4/4] Loss: 0.180
# Dice: 0.795  Val Loss: 0.181
# Checkpoint 369 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch369.pth
# Epoch 369: [4/4] Loss: 0.189
# Epoch 369: [4/4] Loss: 0.181
# Epoch 369: [4/4] Loss: 0.174
# Epoch 369: [4/4] Loss: 0.175
# Dice: 0.794  Val Loss: 0.179
# Checkpoint 370 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch370.pth
# Epoch 370: [4/4] Loss: 0.171
# Epoch 370: [4/4] Loss: 0.170
# Epoch 370: [4/4] Loss: 0.170
# Epoch 370: [4/4] Loss: 0.172
# Dice: 0.793  Val Loss: 0.184
# Checkpoint 371 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch371.pth
# Epoch 371: [4/4] Loss: 0.160
# Epoch 371: [4/4] Loss: 0.161
# Epoch 371: [4/4] Loss: 0.170
# Epoch 371: [4/4] Loss: 0.167
# Dice: 0.791  Val Loss: 0.181
# Checkpoint 372 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch372.pth
# Epoch 372: [4/4] Loss: 0.179
# Epoch 372: [4/4] Loss: 0.182
# Epoch 372: [4/4] Loss: 0.175
# Epoch 372: [4/4] Loss: 0.176
# Dice: 0.787  Val Loss: 0.185
# Checkpoint 373 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch373.pth
# Epoch 373: [4/4] Loss: 0.186
# Epoch 373: [4/4] Loss: 0.179
# Epoch 373: [4/4] Loss: 0.179
# Epoch 373: [4/4] Loss: 0.179
# Dice: 0.780  Val Loss: 0.182
# Checkpoint 374 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch374.pth
# Epoch 374: [4/4] Loss: 0.180
# Epoch 374: [4/4] Loss: 0.167
# Epoch 374: [4/4] Loss: 0.184
# Epoch 374: [4/4] Loss: 0.182
# Dice: 0.794  Val Loss: 0.191
# Checkpoint 375 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch375.pth
# Epoch 375: [4/4] Loss: 0.212
# Epoch 375: [4/4] Loss: 0.212
# Epoch 375: [4/4] Loss: 0.204
# Epoch 375: [4/4] Loss: 0.193
# Dice: 0.775  Val Loss: 0.185
# Checkpoint 376 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch376.pth
# Epoch 376: [4/4] Loss: 0.222
# Epoch 376: [4/4] Loss: 0.191
# Epoch 376: [4/4] Loss: 0.183
# Epoch 376: [4/4] Loss: 0.183
# Dice: 0.789  Val Loss: 0.182
# Checkpoint 377 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch377.pth
# Epoch 377: [4/4] Loss: 0.181
# Epoch 377: [4/4] Loss: 0.188
# Epoch 377: [4/4] Loss: 0.176
# Epoch 377: [4/4] Loss: 0.182
# Dice: 0.793  Val Loss: 0.179
# Checkpoint 378 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch378.pth
# Epoch 378: [4/4] Loss: 0.174
# Epoch 378: [4/4] Loss: 0.184
# Epoch 378: [4/4] Loss: 0.183
# Epoch 378: [4/4] Loss: 0.178
# Dice: 0.797  Val Loss: 0.177
# Checkpoint 379 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch379.pth
# Epoch 379: [4/4] Loss: 0.192
# Epoch 379: [4/4] Loss: 0.179
# Epoch 379: [4/4] Loss: 0.182
# Epoch 379: [4/4] Loss: 0.177
# Dice: 0.789  Val Loss: 0.178
# Checkpoint 380 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch380.pth
# Epoch 380: [4/4] Loss: 0.147
# Epoch 380: [4/4] Loss: 0.165
# Epoch 380: [4/4] Loss: 0.172
# Epoch 380: [4/4] Loss: 0.184
# Dice: 0.785  Val Loss: 0.180
# Checkpoint 381 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch381.pth
# Epoch 381: [4/4] Loss: 0.181
# Epoch 381: [4/4] Loss: 0.188
# Epoch 381: [4/4] Loss: 0.180
# Epoch 381: [4/4] Loss: 0.174
# Dice: 0.789  Val Loss: 0.183
# Checkpoint 382 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch382.pth
# Epoch 382: [4/4] Loss: 0.159
# Epoch 382: [4/4] Loss: 0.172
# Epoch 382: [4/4] Loss: 0.176
# Epoch 382: [4/4] Loss: 0.170
# Dice: 0.781  Val Loss: 0.181
# Checkpoint 383 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch383.pth
# Epoch 383: [4/4] Loss: 0.168
# Epoch 383: [4/4] Loss: 0.162
# Epoch 383: [4/4] Loss: 0.165
# Epoch 383: [4/4] Loss: 0.168
# Dice: 0.787  Val Loss: 0.187
# Checkpoint 384 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch384.pth
# Epoch 384: [4/4] Loss: 0.157
# Epoch 384: [4/4] Loss: 0.167
# Epoch 384: [4/4] Loss: 0.173
# Epoch 384: [4/4] Loss: 0.180
# Dice: 0.787  Val Loss: 0.182
# Checkpoint 385 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch385.pth
# Epoch 385: [4/4] Loss: 0.175
# Epoch 385: [4/4] Loss: 0.200
# Epoch 385: [4/4] Loss: 0.191
# Epoch 385: [4/4] Loss: 0.192
# Dice: 0.791  Val Loss: 0.183
# Checkpoint 386 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch386.pth
# Epoch 386: [4/4] Loss: 0.188
# Epoch 386: [4/4] Loss: 0.197
# Epoch 386: [4/4] Loss: 0.190
# Epoch 386: [4/4] Loss: 0.197
# Dice: 0.795  Val Loss: 0.189
# Checkpoint 387 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch387.pth
# Epoch 387: [4/4] Loss: 0.157
# Epoch 387: [4/4] Loss: 0.196
# Epoch 387: [4/4] Loss: 0.195
# Epoch 387: [4/4] Loss: 0.199
# Dice: 0.787  Val Loss: 0.185
# Checkpoint 388 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch388.pth
# Epoch 388: [4/4] Loss: 0.217
# Epoch 388: [4/4] Loss: 0.201
# Epoch 388: [4/4] Loss: 0.195
# Epoch 388: [4/4] Loss: 0.194
# Dice: 0.793  Val Loss: 0.184
# Checkpoint 389 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch389.pth
# Epoch 389: [4/4] Loss: 0.225
# Epoch 389: [4/4] Loss: 0.218
# Epoch 389: [4/4] Loss: 0.203
# Epoch 389: [4/4] Loss: 0.200
# Dice: 0.793  Val Loss: 0.191
# Checkpoint 390 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch390.pth
# Epoch 390: [4/4] Loss: 0.217
# Epoch 390: [4/4] Loss: 0.202
# Epoch 390: [4/4] Loss: 0.202
# Epoch 390: [4/4] Loss: 0.194
# Dice: 0.791  Val Loss: 0.185
# Checkpoint 391 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch391.pth
# Epoch 391: [4/4] Loss: 0.204
# Epoch 391: [4/4] Loss: 0.207
# Epoch 391: [4/4] Loss: 0.209
# Epoch 391: [4/4] Loss: 0.198
# Dice: 0.792  Val Loss: 0.194
# Checkpoint 392 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch392.pth
# Epoch 392: [4/4] Loss: 0.251
# Epoch 392: [4/4] Loss: 0.208
# Epoch 392: [4/4] Loss: 0.221
# Epoch 392: [4/4] Loss: 0.205
# Dice: 0.795  Val Loss: 0.193
# Checkpoint 393 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch393.pth
# Epoch 393: [4/4] Loss: 0.210
# Epoch 393: [4/4] Loss: 0.204
# Epoch 393: [4/4] Loss: 0.214
# Epoch 393: [4/4] Loss: 0.207
# Dice: 0.795  Val Loss: 0.183
# Checkpoint 394 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch394.pth
# Epoch 394: [4/4] Loss: 0.175
# Epoch 394: [4/4] Loss: 0.164
# Epoch 394: [4/4] Loss: 0.181
# Epoch 394: [4/4] Loss: 0.191
# Dice: 0.791  Val Loss: 0.181
# Checkpoint 395 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch395.pth
# Epoch 395: [4/4] Loss: 0.185
# Epoch 395: [4/4] Loss: 0.193
# Epoch 395: [4/4] Loss: 0.183
# Epoch 395: [4/4] Loss: 0.192
# Dice: 0.794  Val Loss: 0.179
# Checkpoint 396 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch396.pth
# Epoch 396: [4/4] Loss: 0.179
# Epoch 396: [4/4] Loss: 0.192
# Epoch 396: [4/4] Loss: 0.186
# Epoch 396: [4/4] Loss: 0.185
# Dice: 0.793  Val Loss: 0.184
# Checkpoint 397 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch397.pth
# Epoch 397: [4/4] Loss: 0.213
# Epoch 397: [4/4] Loss: 0.191
# Epoch 397: [4/4] Loss: 0.188
# Epoch 397: [4/4] Loss: 0.189
# Dice: 0.792  Val Loss: 0.182
# Checkpoint 398 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch398.pth
# Epoch 398: [4/4] Loss: 0.191
# Epoch 398: [4/4] Loss: 0.188
# Epoch 398: [4/4] Loss: 0.180
# Epoch 398: [4/4] Loss: 0.180
# Dice: 0.795  Val Loss: 0.180
# Checkpoint 399 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch399.pth
# Epoch 399: [4/4] Loss: 0.162
# Epoch 399: [4/4] Loss: 0.168
# Epoch 399: [4/4] Loss: 0.181
# Epoch 399: [4/4] Loss: 0.171
# Dice: 0.797  Val Loss: 0.186
# Checkpoint 400 saved to /scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch400.pth

# %%
# Plot training loss and validation loss
plt.grid('on')
plt.plot(np.arange(NUM_EPOCH),train_loss_list,label='train_loss')
plt.plot(np.arange(NUM_EPOCH),val_loss_list, label='val_loss')
plt.legend()

# %% [markdown]
# # 6.Test

# %% [markdown]
# ## Reload the model

# %%
checkpoint_path = '/scratch/hp2173/mri/SelfAttention_U-net_3D_model/MRISegEpoch400.pth'
net = SelfAttention_UNet(4,1).to(device)
net.load_state_dict(torch.load(checkpoint_path))
net.eval()
# Out:
# SelfAttention_UNet(
#   (lrelu): LeakyReLU(negative_slope=0.01)
#   (dropout3d): Dropout3d(p=0.6, inplace=False)
#   (upsacle): Upsample(scale_factor=2.0, mode=nearest)
#   (softmax): Softmax(dim=1)
#   (conv3d_c1_1): Conv3d(4, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (conv3d_c1_2): Conv3d(8, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (lrelu_conv_c1): Sequential(
#     (0): LeakyReLU(negative_slope=0.01)
#     (1): Conv3d(8, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   )
#   (inorm3d_c1): InstanceNorm3d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (conv3d_c2): Conv3d(8, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#   (norm_lrelu_conv_c2): Sequential(
#     (0): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   )
#   (inorm3d_c2): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (conv3d_c3): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#   (norm_lrelu_conv_c3): Sequential(
#     (0): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   )
#   (inorm3d_c3): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (conv3d_c4): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#   (norm_lrelu_conv_c4): Sequential(
#     (0): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   )
#   (inorm3d_c4): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (conv3d_c5): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#   (norm_lrelu_conv_c5): Sequential(
#     (0): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   )
#   (norm_lrelu_upscale_conv_norm_lrelu_l0): Sequential(
#     (0): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Upsample(scale_factor=2.0, mode=nearest)
#     (3): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (4): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (5): LeakyReLU(negative_slope=0.01)
#   )
#   (conv3d_l0): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (inorm3d_l0): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (conv_norm_lrelu_l1): Sequential(
#     (0): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (1): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (conv3d_l1): Conv3d(128, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (norm_lrelu_upscale_conv_norm_lrelu_l1): Sequential(
#     (0): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Upsample(scale_factor=2.0, mode=nearest)
#     (3): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (4): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (5): LeakyReLU(negative_slope=0.01)
#   )
#   (conv_norm_lrelu_l2): Sequential(
#     (0): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (1): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (conv3d_l2): Conv3d(64, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (norm_lrelu_upscale_conv_norm_lrelu_l2): Sequential(
#     (0): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Upsample(scale_factor=2.0, mode=nearest)
#     (3): Conv3d(32, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (4): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (5): LeakyReLU(negative_slope=0.01)
#   )
#   (conv_norm_lrelu_l3): Sequential(
#     (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (1): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (conv3d_l3): Conv3d(32, 16, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (norm_lrelu_upscale_conv_norm_lrelu_l3): Sequential(
#     (0): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Upsample(scale_factor=2.0, mode=nearest)
#     (3): Conv3d(16, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (4): InstanceNorm3d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (5): LeakyReLU(negative_slope=0.01)
#   )
#   (conv_norm_lrelu_l4): Sequential(
#     (0): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (1): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (conv3d_l4): Conv3d(16, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (ds2_1x1_conv3d): Conv3d(64, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (ds3_1x1_conv3d): Conv3d(32, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (sigmoid): Sigmoid()
#   (attention1): SelfAttention_3D(
#     (fc_q1): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_k1): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_v1): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_q2): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_k2): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_v2): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_q3): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_k3): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_v3): Linear(in_features=14812, out_features=10, bias=True)
#     (fc_o): Linear(in_features=30, out_features=14812, bias=True)
#   )
#   (attention2): SelfAttention_3D(
#     (fc_q1): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_k1): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_v1): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_q2): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_k2): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_v2): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_q3): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_k3): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_v3): Linear(in_features=116380, out_features=10, bias=True)
#     (fc_o): Linear(in_features=30, out_features=116380, bias=True)
#   )
#   (attention3): SelfAttention_3D(
#     (fc_q1): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_k1): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_v1): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_q2): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_k2): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_v2): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_q3): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_k3): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_v3): Linear(in_features=902629, out_features=10, bias=True)
#     (fc_o): Linear(in_features=30, out_features=902629, bias=True)
#   )
# )

# %% [markdown]
# ## Reload the data with mask1 and mask2

# %%
test_dataset_mask1 = MRIDataset(test_img_list, test_label1_list, test_label2_list, RULE = 'mask1', IF_TRAIN= False)
test_dataset_mask2 = MRIDataset(test_img_list, test_label1_list, test_label2_list, RULE = 'mask2', IF_TRAIN= False)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]<ipython-input-7-976d5a4983b3>:25: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2f = torch.Tensor(nib.load(self.mri_path_list[idx][0]).get_data())
# <ipython-input-7-976d5a4983b3>:28: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t1w = torch.Tensor(nib.load(self.mri_path_list[idx][1]).get_data())
# <ipython-input-7-976d5a4983b3>:31: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_pd = torch.Tensor(nib.load(self.mri_path_list[idx][2]).get_data())
# <ipython-input-7-976d5a4983b3>:34: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2w = torch.Tensor(nib.load(self.mri_path_list[idx][3]).get_data())
# <ipython-input-16-527bb657da25>:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1=nib.load(mask1_path).get_data()
# <ipython-input-16-527bb657da25>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2=nib.load(mask2_path).get_data()
# <ipython-input-7-976d5a4983b3>:40: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1 = torch.Tensor(nib.load(self.label1_path_list[idx]).get_data())
# <ipython-input-7-976d5a4983b3>:41: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2 = torch.Tensor(nib.load(self.label2_path_list[idx]).get_data())
# 100%|██████████| 2/2 [00:28<00:00, 14.11s/it]
# 100%|██████████| 2/2 [00:27<00:00, 13.78s/it]

# %%
test_loader_mask1 = torch.utils.data.DataLoader(test_dataset_mask1, 
                                         batch_size=BATCH_SIZE, 
                                         shuffle=False, 
                                         num_workers=0)
test_loader_mask2 = torch.utils.data.DataLoader(test_dataset_mask2, 
                                         batch_size=BATCH_SIZE, 
                                         shuffle=False, 
                                         num_workers=0)

# %% [markdown]
# ## Test with mask1 and mask2

# %%
test_loss, test_dice = eval_epoch(net, test_loader_mask1, dice_coeff, criterion)
test_loss, test_dice = eval_epoch(net, test_loader_mask2, dice_coeff, criterion)
# Out:
# Dice: 0.720  Val Loss: 0.286
# Dice: 0.699  Val Loss: 0.302

# %% [markdown]
# ## Dispaly the output mask

# %%
img, mask1 = test_dataset_mask1[0]
img, mask2 = test_dataset_mask2[0]
result = net(img.unsqueeze(0).to(device)).detach()
mask_pred = result.cpu().numpy()[0,0,:,:,:]
mask_pred[mask_pred>0.3] = 1
mask_pred[mask_pred<=0.3] = 0
print(mask_pred.shape)
# Out:
# (181, 217, 181)

# %%
plt.figure(figsize = (16,32))
plt.subplot(1,7,1)
plt.imshow(img[0,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('T1-weighted')
plt.subplot(1,7,2)
plt.imshow(img[1,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('T2-weighted')
plt.subplot(1,7,3)
plt.imshow(img[2,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('PD-weighted')
plt.subplot(1,7,4)
plt.imshow(img[3,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('T2-weighted FLAIR')
plt.subplot(1,7,5)
plt.imshow(mask1.cpu().numpy()[:,:,90],'gray')
plt.title('mask1')
plt.subplot(1,7,6)
plt.imshow(mask2.cpu().numpy()[:,:,90],'gray')
plt.title('mask2')
plt.subplot(1,7,7)
plt.imshow(mask_pred[:,:,90],'gray')
plt.title('mask_pred')

print('Manual Volume for mask1:',mask1.cpu().numpy().sum())
print('Manual Volume for mask2:',mask2.cpu().numpy().sum())
print('Segmentation Volume:',mask_pred.sum())
# Out:
# Manual Volume for mask1: 31494.0
# Manual Volume for mask2: 34719.0
# Segmentation Volume: 35295.0

# %%
img, mask1 = test_dataset_mask1[1]
img, mask2 = test_dataset_mask2[1]
result = net(img.unsqueeze(0).to(device)).detach()
mask_pred = result.cpu().numpy()[0,0,:,:,:]
mask_pred[mask_pred>0.1] = 1
mask_pred[mask_pred<=0.1] = 0
print(mask_pred.shape)
# Out:
# (181, 217, 181)

# %%
plt.figure(figsize = (16,32))
plt.subplot(1,7,1)
plt.imshow(img[0,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('T1-weighted')
plt.subplot(1,7,2)
plt.imshow(img[1,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('T2-weighted')
plt.subplot(1,7,3)
plt.imshow(img[2,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('PD-weighted')
plt.subplot(1,7,4)
plt.imshow(img[3,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('T2-weighted FLAIR')
plt.subplot(1,7,5)
plt.imshow(mask1.cpu().numpy()[:,:,90],'gray')
plt.title('mask1')
plt.subplot(1,7,6)
plt.imshow(mask2.cpu().numpy()[:,:,90],'gray')
plt.title('mask2')
plt.subplot(1,7,7)
plt.imshow(mask_pred[:,:,90],'gray')
plt.title('mask_pred')

print('Manual Volume for mask1:',mask1.cpu().numpy().sum())
print('Manual Volume for mask2:',mask2.cpu().numpy().sum())
print('Segmentation Volume:',mask_pred.sum())
# Out:
# Manual Volume for mask1: 31494.0
# Manual Volume for mask2: 4013.0
# Segmentation Volume: 9263.0

# %% [markdown]
# ### Comparing with original and preprocessed

# %%
test_datapath = '/scratch/hp2173/testdata_website'

# %%
class MRITestDataset(Dataset):
    def __init__(self, img_path_list, IF_TRAIN= False):
        self.mri_path_list = img_path_list
        self.IF_TRAIN = IF_TRAIN
        #self.transform=transforms.Compose([transforms.Normalize((0.5,),(0.5,))])
        self.mri_list = self.preprocess() 

    def __len__(self):
        return len(self.mri_list)

    def preprocess(self):
        mri_list = []
        for idx in tqdm(range(len(self.mri_path_list))):
            mri_t2f = torch.Tensor(nib.load(self.mri_path_list[idx][0]).get_data())
            mri_t2f = (mri_t2f-mri_t2f.min())/(mri_t2f.max()-mri_t2f.min())
            
            mri_t1w = torch.Tensor(nib.load(self.mri_path_list[idx][1]).get_data())
            mri_t1w = (mri_t1w-mri_t1w.min())/(mri_t1w.max()-mri_t1w.min())
            
            mri_pd = torch.Tensor(nib.load(self.mri_path_list[idx][2]).get_data())
            mri_pd = (mri_pd-mri_pd.min())/(mri_pd.max()-mri_pd.min())
            
            mri_t2w = torch.Tensor(nib.load(self.mri_path_list[idx][3]).get_data())
            mri_t2w = (mri_t2w-mri_t2w.min())/(mri_t2w.max()-mri_t2w.min())
            
            mri = torch.cat((mri_t1w.unsqueeze(0),mri_t2w.unsqueeze(0),mri_pd.unsqueeze(0),mri_t2f.unsqueeze(0)),axis=0)
        
            
            mri_list.append(mri)

        return mri_list

    def __getitem__ (self,idx):
        img = self.mri_list[idx]
        return img

# %%
second_testing_path_list = []
for i in range(1,15):
    if i<10:
        second_testing_path_list.append('test0' + str(i) + '/')
    else:
        second_testing_path_list.append('test' + str(i) + '/')
        
print(second_testing_path_list)
mri_test_list = []

for i in range(14):
    timepoint1_path = os.path.join(test_datapath, second_testing_path_list[i], 'preprocessed/*_01_*.nii')
    timepoint2_path = os.path.join(test_datapath, second_testing_path_list[i], 'preprocessed/*_02_*.nii')
    timepoint3_path = os.path.join(test_datapath, second_testing_path_list[i], 'preprocessed/*_03_*.nii')
    timepoint4_path = os.path.join(test_datapath, second_testing_path_list[i], 'preprocessed/*_04_*.nii')
    if (i==1 or i==9 or i==10 or i==13):
        timepoint5_path = os.path.join(test_datapath, second_testing_path_list[i], 'preprocessed/*_05_*.nii')
    if i==9: 
        timepoint6_path = os.path.join(test_datapath, second_testing_path_list[i], 'preprocessed/*_06_*.nii') 
        print(timepoint6_path)
    
    timepoint1_list = sorted(glob.glob(timepoint1_path))
    timepoint2_list = sorted(glob.glob(timepoint2_path))
    timepoint3_list = sorted(glob.glob(timepoint3_path))
    timepoint4_list = sorted(glob.glob(timepoint4_path))

    
    if (i==1 or i==9 or i==10 or i==13):
        timepoint5_list = sorted(glob.glob(timepoint5_path))
    if i==9:
        timepoint6_list = sorted(glob.glob(timepoint6_path))
    
    mri_test_list.append(timepoint1_list)
    mri_test_list.append(timepoint2_list)
    mri_test_list.append(timepoint3_list)
    mri_test_list.append(timepoint4_list)

    if (i==1 or i==9 or i==10 or i==13):
        mri_test_list.append(timepoint5_list)

    if i==9:
        mri_test_list.append(timepoint6_list)
        

print('Data Collected:', len(mri_test_list))
# Out:
# ['test01/', 'test02/', 'test03/', 'test04/', 'test05/', 'test06/', 'test07/', 'test08/', 'test09/', 'test10/', 'test11/', 'test12/', 'test13/', 'test14/']
# /scratch/hp2173/testdata_website/test10/preprocessed/*_06_*.nii
# Data Collected: 61

# %%
test_dataset = MRITestDataset(mri_test_list, IF_TRAIN= True)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]<ipython-input-15-cca191b18e00>:14: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2f = torch.Tensor(nib.load(self.mri_path_list[idx][0]).get_data())
# <ipython-input-15-cca191b18e00>:17: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t1w = torch.Tensor(nib.load(self.mri_path_list[idx][1]).get_data())
# <ipython-input-15-cca191b18e00>:20: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_pd = torch.Tensor(nib.load(self.mri_path_list[idx][2]).get_data())
# <ipython-input-15-cca191b18e00>:23: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2w = torch.Tensor(nib.load(self.mri_path_list[idx][3]).get_data())
# 100%|██████████| 61/61 [00:35<00:00,  1.73it/s]

# %%
test_loader = torch.utils.data.DataLoader(test_dataset, 
                                         batch_size=1, 
                                         shuffle=False, 
                                         num_workers=0)

# %%
def pre_and_save(net, dataloader):
    net = net.eval()
    num_list = [4,5,4,4,4,4,4,4,4,6,5,4,4,5]
    cnt_num = 0;
    cnt = 0;
    for i, test_input in enumerate(dataloader):
        test_input = test_input.to(device)
        with torch.no_grad():
            pred = net(test_input[0].unsqueeze(0).to(device)).detach()
            pred[pred>0.35] = 1
            pred[pred<=0.35] = 0
            pred = pred.cpu().numpy().squeeze()
            new_image = nib.Nifti1Image(pred, np.eye(4)) 
            
        if (cnt == num_list[cnt_num]):
            cnt_num += 1
            cnt = 0;
        if i < 37:
            nib.save(new_image, '/scratch/hp2173/mri/results/self_attention_decoder_3d_unet/' + 'test0' + str(cnt_num+1) + '_0' + str(cnt+1)+ '_NYU.nii')
        else:
            nib.save(new_image, '/scratch/hp2173/mri/results/self_attention_decoder_3d_unet/' + 'test' + str(cnt_num+1) + '_0' + str(cnt+1)+ '_NYU.nii')
        cnt = cnt+1

# %%
num_list = [4,5,4,4,4,4,4,4,4,6,5,4,4,5]
print(sum(num_list))
# Out:
# 61

# %%
pre_and_save(net, test_loader)

# %%
testimg = nib.load('/scratch/hp2173/mri/results/self_attention_decoder_3d_unet/test10_02_NYU.nii').get_data()
print(testimg.shape)
plt.imshow(testimg[:,:,90], cmap='gray')
# Out:
# (181, 217, 181)
# <ipython-input-26-1a374869436c>:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   testimg = nib.load('/scratch/hp2173/mri/results/self_attention_decoder_3d_unet/test10_02_NYU.nii').get_data()
