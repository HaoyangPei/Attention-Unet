# %%
pwd
# Out:
# '/scratch/hp2173/mri'

# %% [markdown]
# # 2.Preprocess the Datasets

# %%
pip install nibabel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nibabel in /home/hp2173/.local/lib/python3.8/site-packages (3.2.1)
# Requirement already satisfied: numpy>=1.14 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages/numpy-1.19.2-py3.8-linux-x86_64.egg (from nibabel) (1.19.2)
# Requirement already satisfied: packaging>=14.3 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from nibabel) (20.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from packaging>=14.3->nibabel) (2.4.7)
# Requirement already satisfied: six in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from packaging>=14.3->nibabel) (1.15.0)
# WARNING: You are using pip version 20.2.3; however, version 21.1.1 is available.
# You should consider upgrading via the '/share/apps/python/3.8.6/intel/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
from nibabel.testing import data_path
import nibabel as nib
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1) Visualize the MRI images

# %%
T1_weighted_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_mprage_pp.nii').get_data()
T2_weighted_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_t2_pp.nii').get_data()
PD_weighted_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_pd_pp.nii').get_data()
T2_weighted_flair_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_flair_pp.nii').get_data()
mask1_example = nib.load('/scratch/hp2173/training/training01/masks/training01_01_mask1.nii').get_data()
mask2_example = nib.load('/scratch/hp2173/training/training01/masks/training01_01_mask2.nii').get_data()
plt.figure(figsize=(25,10))
plt.subplot(2,4,1)
plt.imshow(T1_weighted_example[:,:,90],'gray')
plt.title('T1_weighted_example')
plt.subplot(2,4,2)
plt.imshow(T2_weighted_example[:,:,90],'gray')
plt.title('T2_weighted_example')
plt.subplot(2,4,3)
plt.imshow(PD_weighted_example[:,:,90],'gray')
plt.title('PD_weighted_example')
plt.subplot(2,4,4)
plt.imshow(T2_weighted_flair_example[:,:,90],'gray')
plt.title('T2_weighted_flair_example')
plt.subplot(2,4,5)
plt.imshow(mask1_example[:,:,90],'gray')
plt.title('mask1_example')
plt.subplot(2,4,6)
plt.imshow(mask2_example[:,:,90],'gray')
plt.title('mask2_example')

plt.pause(3)
# Out:
# <ipython-input-11-daae39f04b2f>:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   T1_weighted_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_mprage_pp.nii').get_data()
# <ipython-input-11-daae39f04b2f>:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   T2_weighted_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_t2_pp.nii').get_data()
# <ipython-input-11-daae39f04b2f>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   PD_weighted_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_pd_pp.nii').get_data()
# <ipython-input-11-daae39f04b2f>:4: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   T2_weighted_flair_example = nib.load('/scratch/hp2173/training/training01/preprocessed/training01_01_flair_pp.nii').get_data()
# <ipython-input-11-daae39f04b2f>:5: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1_example = nib.load('/scratch/hp2173/training/training01/masks/training01_01_mask1.nii').get_data()
# <ipython-input-11-daae39f04b2f>:6: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2_example = nib.load('/scratch/hp2173/training/training01/masks/training01_01_mask2.nii').get_data()

# %%
# ipywidgets for some interactive plots
from ipywidgets.widgets import * 
import ipywidgets as widgets
# slide through dicom images using a slide bar 
def dicom_animation(x):
    plt.figure(figsize=(20,10))
    plt.imshow(T1_weighted_example[:,:,x],'gray')
    return x
interact(dicom_animation, x=(0, len(T1_weighted_example)-1))
# Out:
# interactive(children=(IntSlider(value=90, description='x', max=180), Output()), _dom_classes=('widget-interact…
# <function __main__.dicom_animation(x)>

# %% [markdown]
# ## 2) Define function to process 2 raters' groundtruth

# %%
def weight_ground_truth(mask1_path, mask2_path):
  mask1=nib.load(mask1_path).get_data()
  mask2=nib.load(mask2_path).get_data()
  if mask1.shape==mask2.shape:
    fig_shape = mask1.shape 
  else:
    print('Number inconformity for mask, double check path!')
  
  n=fig_shape[2]

  mask_and_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)
  mask_or_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)
  mask_rnd_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)

  for i in range(n):
    mask_and_weight[:,:,i] = mask1[:,:,i] & mask2[:,:,i]
    mask_or_weight[:,:,i] = mask1[:,:,i] | mask2[:,:,i]
    mask_rnd_weight = (mask_or_weight - mask_and_weight)*np.random.randint(0,2,(fig_shape[0],fig_shape[1],n)) + mask_and_weight


  return mask_and_weight, mask_or_weight, mask_rnd_weight

# %%
root = '/scratch/hp2173/training/'
#mask_or_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)
#mask_and_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)
mask1_path = os.path.join(root,'training01/masks/training01_01_mask1.nii')
mask2_path = os.path.join(root,'training01/masks/training01_01_mask2.nii')
mask3_path = os.path.join(root,'training02/masks/training02_02_mask1.nii')
mask4_path = os.path.join(root,'training02/masks/training02_02_mask2.nii')

mask_and_weight, mask_or_weight, mask_rnd_weight = weight_ground_truth(mask1_path, mask2_path)
mask_and_weight2, mask_or_weight2, mask_rnd_weight2 = weight_ground_truth(mask3_path, mask4_path)

plt.figure(figsize=(25,10))
plt.subplot(2,3,1)
plt.imshow(mask_and_weight[:,:,90],'gray')
plt.title('mask_and_weight')
plt.subplot(2,3,2)
plt.imshow(mask_or_weight[:,:,90],'gray')
plt.title('mask_or_weight')
plt.subplot(2,3,3)
plt.imshow(mask_rnd_weight[:,:,90],'gray')
plt.title('mask_rnd_weight')
plt.subplot(2,3,4)
plt.imshow(mask_and_weight2[:,:,90],'gray')
plt.title('mask_and_weight')
plt.subplot(2,3,5)
plt.imshow(mask_or_weight2[:,:,90],'gray')
plt.title('mask_or_weight')
plt.subplot(2,3,6)
plt.imshow(mask_rnd_weight2[:,:,90],'gray')
plt.title('mask_rnd_weight')
# Out:
# <ipython-input-6-527bb657da25>:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1=nib.load(mask1_path).get_data()
# <ipython-input-6-527bb657da25>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2=nib.load(mask2_path).get_data()
# Text(0.5, 1.0, 'mask_rnd_weight')

# %%
root = '/content/gdrive/MyDrive/ImageVedioPrecessingProject/training/'
#mask_or_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)
#mask_and_weight=np.zeros((fig_shape[0], fig_shape[1], n), dtype=np.int)


mask_and_weight, mask_or_weight, mask_rnd_weight = weight_ground_truth(mask1_path, mask2_path)
plt.figure(figsize=(25,10))
plt.subplot(1,3,1)
plt.imshow(mask_and_weight[:,:,90],'gray')
plt.title('mask_and_weight')
plt.subplot(1,3,2)
plt.imshow(mask_or_weight[:,:,90],'gray')
plt.title('mask_or_weight')
plt.subplot(1,3,3)
plt.imshow(mask_rnd_weight[:,:,90],'gray')
plt.title('mask_rnd_weight')
# Out:
# <ipython-input-6-527bb657da25>:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1=nib.load(mask1_path).get_data()
# <ipython-input-6-527bb657da25>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2=nib.load(mask2_path).get_data()
# Text(0.5, 1.0, 'mask_rnd_weight')

# %% [markdown]
# ## 3) Make the custom dataset

# %%
import glob

# %%
base_path = '/scratch/hp2173/training/'
second_path_list = ['training01/','training02/','training03/','training04/','training05/']
mri_list = []
mask1_list = []
mask2_list = []
for i in range(5):
    timepoint1_path = os.path.join(base_path, second_path_list[i], 'preprocessed/*_01_*.nii')
    timepoint2_path = os.path.join(base_path, second_path_list[i], 'preprocessed/*_02_*.nii')
    timepoint3_path = os.path.join(base_path, second_path_list[i], 'preprocessed/*_03_*.nii')
    timepoint4_path = os.path.join(base_path, second_path_list[i], 'preprocessed/*_04_*.nii')
    if i==2:
        timepoint5_path = os.path.join(base_path, second_path_list[i], 'preprocessed/*_05_*.nii')
    mask1_path = os.path.join(base_path, second_path_list[i], 'masks/*1.nii')
    mask2_path = os.path.join(base_path, second_path_list[i], 'masks/*2.nii')
    timepoint1_list = sorted(glob.glob(timepoint1_path))
    timepoint2_list = sorted(glob.glob(timepoint2_path))
    timepoint3_list = sorted(glob.glob(timepoint3_path))
    timepoint4_list = sorted(glob.glob(timepoint4_path))
    if i==2:
        timepoint5_list = sorted(glob.glob(timepoint5_path))
    mri_list.append(timepoint1_list)
    mri_list.append(timepoint2_list)
    mri_list.append(timepoint3_list)
    mri_list.append(timepoint4_list)
    if i==2:
        mri_list.append(timepoint5_list)
    mask1_list = mask1_list + sorted(glob.glob(mask1_path))
    mask2_list = mask2_list + sorted(glob.glob(mask2_path))
print('Data Collected:', len(mri_list))
print('Mask1 Collected:', len(mask1_list))
print('Mask2 Collected:', len(mask2_list))
# Out:
# Data Collected: 21
# Mask1 Collected: 21
# Mask2 Collected: 21

# %%
# 0-3:training 1(4 time points)
# 4-7:training 2(4 time points)
# 8-12:training 3(5 time points)
# 13-16:training 4(4 time points)
# 17-20:training 5(4 time points)
# order in one training set: t2_flair_weight, t1_weight, pd_weight, t2_weight

#Display one timepoint(4 type MRI) for one of the training set
index = 0
for i in range(4):
    ex = nib.load(mri_list[0][index+i]).get_data()
    ms1 = nib.load(mask1_list[0]).get_data()
    ms2 = nib.load(mask2_list[0]).get_data()
    plt.figure(figsize=(15,25))
    plt.subplot(5,3,3*i+1)
    plt.imshow(ex[:,:,90],'gray')
    plt.subplot(5,3,3*i+2)
    plt.imshow(ms1[:,:,90],'gray')
    plt.subplot(5,3,3*i+3)
    plt.imshow(ms2[:,:,90],'gray')
# Out:
# <ipython-input-15-bbfdd6332bd2>:11: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   ex = nib.load(mri_list[0][index+i]).get_data()
# <ipython-input-15-bbfdd6332bd2>:12: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   ms1 = nib.load(mask1_list[0]).get_data()
# <ipython-input-15-bbfdd6332bd2>:13: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   ms2 = nib.load(mask2_list[0]).get_data()

# %%
from random import shuffle
def shuffle_two_lists(listA, listB, listC):
  temp = list(zip(listA, listB, listC))
  shuffle(temp)
  return zip(*temp)
train_split_ratio = 0.8
test_split_ratio = 0.1
num_samples = len(mri_list)

train_size = int(num_samples * train_split_ratio)
test_size = int(num_samples * test_split_ratio)
val_size = num_samples - train_size - test_size
mri_list_shuffled, mask1_list_shuffled, mask2_list_shuffled = shuffle_two_lists(mri_list, mask1_list, mask2_list)

train_img_list, train_label1_list, train_label2_list = mri_list_shuffled[:train_size], mask1_list_shuffled[:train_size], mask2_list_shuffled[:train_size]
val_img_list, val_label1_list, val_label2_list = mri_list_shuffled[train_size:train_size+ val_size], mask1_list_shuffled[train_size:train_size + val_size], mask2_list_shuffled[train_size:train_size + val_size]
test_img_list, test_label1_list, test_label2_list = mri_list_shuffled[train_size+ val_size:], mask1_list_shuffled[train_size+ val_size:], mask2_list_shuffled[train_size+ val_size:]

print ("Training set size: {}". format(len(train_img_list)))
print ("Validation set size: {}". format(len(val_img_list)))
print ("Test set size: {}". format(len(test_img_list)))
# Out:
# Training set size: 16
# Validation set size: 3
# Test set size: 2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
from torchvision import transforms, datasets
from torch.utils.data import Dataset
from tqdm import tqdm

class MRIDataset(Dataset):
    def __init__(self, img_path_list, label1_path_list, label2_path_list, RULE = 'and', IF_TRAIN= False):
        self.mri_path_list = img_path_list
        self.label1_path_list = label1_path_list
        self.label2_path_list = label2_path_list
        self.rule = RULE
        self.IF_TRAIN = IF_TRAIN
        #self.transform=transforms.Compose([transforms.Normalize((0.5,),(0.5,))])
        self.mri_list, self.mask1_list, self.mask2_list, self.mask_and_list, self.mask_or_list, self.mask_rnd_list = self.preprocess() 

    def __len__(self):
        return len(self.mri_list)

    def preprocess(self):
        mri_list, mask1_list, mask2_list, mask_and_list, mask_or_list, mask_rnd_list = [], [], [], [], [], []
        for idx in tqdm(range(len(self.mri_path_list))):
            mri_t2f = torch.Tensor(nib.load(self.mri_path_list[idx][0]).get_data())
            mri_t2f = (mri_t2f-mri_t2f.min())/(mri_t2f.max()-mri_t2f.min())
            
            mri_t1w = torch.Tensor(nib.load(self.mri_path_list[idx][1]).get_data())
            mri_t1w = (mri_t1w-mri_t1w.min())/(mri_t1w.max()-mri_t1w.min())
            
            mri_pd = torch.Tensor(nib.load(self.mri_path_list[idx][2]).get_data())
            mri_pd = (mri_pd-mri_pd.min())/(mri_pd.max()-mri_pd.min())
            
            mri_t2w = torch.Tensor(nib.load(self.mri_path_list[idx][3]).get_data())
            mri_t2w = (mri_t2w-mri_t2w.min())/(mri_t2w.max()-mri_t2w.min())
            
            mri = torch.cat((mri_t1w.unsqueeze(0),mri_t2w.unsqueeze(0),mri_pd.unsqueeze(0),mri_t2f.unsqueeze(0)),axis=0)
            #mri = self.transform(mri)
            mask_and, mask_or, mask_rnd = weight_ground_truth(self.label1_path_list[idx], self.label2_path_list[idx])
            mask1 = torch.Tensor(nib.load(self.label1_path_list[idx]).get_data())
            mask2 = torch.Tensor(nib.load(self.label2_path_list[idx]).get_data())
            
            mri_list.append(mri)
            mask1_list.append(mask1)
            mask2_list.append(mask2)
            mask_and_list.append(mask_and)
            mask_or_list.append(mask_or)
            mask_rnd_list.append(mask_rnd)
        return mri_list, mask1_list, mask2_list, mask_and_list, mask_or_list, mask_rnd_list

    def __getitem__ (self,idx):
        img = self.mri_list[idx]
        if self.rule=='and':
            mask = self.mask_and_list[idx]
        elif self.rule=='or':
            mask = self.mask_or_list[idx]
        elif self.rule=='random':
            mask = self.mask_rnd_list[idx]
        elif self.rule=='mask1':
            mask = self.mask1_list[idx]
        elif self.rule=='mask2':
            mask = self.mask2_list[idx]
            
        label = torch.Tensor(mask)

        return img, label

# %%
dataset = MRIDataset(test_img_list, test_label1_list, test_label2_list, RULE = 'and', IF_TRAIN= True)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]<ipython-input-7-976d5a4983b3>:25: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2f = torch.Tensor(nib.load(self.mri_path_list[idx][0]).get_data())
# <ipython-input-7-976d5a4983b3>:28: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t1w = torch.Tensor(nib.load(self.mri_path_list[idx][1]).get_data())
# <ipython-input-7-976d5a4983b3>:31: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_pd = torch.Tensor(nib.load(self.mri_path_list[idx][2]).get_data())
# <ipython-input-7-976d5a4983b3>:34: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2w = torch.Tensor(nib.load(self.mri_path_list[idx][3]).get_data())
# <ipython-input-3-527bb657da25>:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1=nib.load(mask1_path).get_data()
# <ipython-input-3-527bb657da25>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2=nib.load(mask2_path).get_data()
# <ipython-input-7-976d5a4983b3>:40: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1 = torch.Tensor(nib.load(self.label1_path_list[idx]).get_data())
# <ipython-input-7-976d5a4983b3>:41: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2 = torch.Tensor(nib.load(self.label2_path_list[idx]).get_data())
# 100%|██████████| 2/2 [00:29<00:00, 14.81s/it]

# %%
img, mask = dataset[0]
print(img.shape)
print(mask.shape)
plt.figure(figsize = (16,32))
plt.subplot(1,5,1)
plt.imshow(img[0,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.subplot(1,5,2)
plt.imshow(img[1,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.subplot(1,5,3)
plt.imshow(img[2,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.subplot(1,5,4)
plt.imshow(img[3,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.subplot(1,5,5)
plt.imshow(mask.cpu().numpy()[:,:,90],'gray')
print(img[0,:,:,:].cpu().numpy().max())
print(img[1,:,:,:].cpu().numpy().max())
print(img[2,:,:,:].cpu().numpy().max())
print(img[3,:,:,:].cpu().numpy().max())
# Out:
# torch.Size([4, 181, 217, 181])
# torch.Size([181, 217, 181])
# 1.0
# 1.0
# 1.0
# 1.0

# %%
train_dataset = MRIDataset(train_img_list, train_label1_list, train_label2_list, RULE = 'random', IF_TRAIN= True)
val_dataset = MRIDataset(val_img_list, val_label1_list, val_label2_list, RULE = 'random', IF_TRAIN= False)
test_dataset = MRIDataset(test_img_list, test_label1_list, test_label2_list, RULE = 'random', IF_TRAIN= False)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]<ipython-input-7-976d5a4983b3>:25: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2f = torch.Tensor(nib.load(self.mri_path_list[idx][0]).get_data())
# <ipython-input-7-976d5a4983b3>:28: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t1w = torch.Tensor(nib.load(self.mri_path_list[idx][1]).get_data())
# <ipython-input-7-976d5a4983b3>:31: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_pd = torch.Tensor(nib.load(self.mri_path_list[idx][2]).get_data())
# <ipython-input-7-976d5a4983b3>:34: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2w = torch.Tensor(nib.load(self.mri_path_list[idx][3]).get_data())
# <ipython-input-3-527bb657da25>:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1=nib.load(mask1_path).get_data()
# <ipython-input-3-527bb657da25>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2=nib.load(mask2_path).get_data()
# <ipython-input-7-976d5a4983b3>:40: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1 = torch.Tensor(nib.load(self.label1_path_list[idx]).get_data())
# <ipython-input-7-976d5a4983b3>:41: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2 = torch.Tensor(nib.load(self.label2_path_list[idx]).get_data())
# 100%|██████████| 16/16 [03:51<00:00, 14.49s/it]
# 100%|██████████| 3/3 [00:43<00:00, 14.46s/it]
# 100%|██████████| 2/2 [00:29<00:00, 14.74s/it]

# %%
NUM_EPOCH = 100
BATCH_SIZE = 4
LR = 0.0005
SAVE_PATH = "/scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/"

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, 
                                           batch_size=BATCH_SIZE, 
                                           shuffle=True, 
                                           num_workers=0)
val_loader = torch.utils.data.DataLoader(val_dataset, 
                                         batch_size=BATCH_SIZE, 
                                         shuffle=False, 
                                         num_workers=0)
test_loader = torch.utils.data.DataLoader(test_dataset, 
                                         batch_size=BATCH_SIZE, 
                                         shuffle=False, 
                                         num_workers=0)

# %% [markdown]
# # 3.Build the Network

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class SelfAttention_3D(nn.Module):
    def __init__(self, feature_dims, dim_q):
        super(SelfAttention_3D, self).__init__()
        self.fc_q1 = nn.Linear(feature_dims, dim_q)
        self.fc_k1 = nn.Linear(feature_dims, dim_q)
        self.fc_v1 = nn.Linear(feature_dims, dim_q)
        
        self.fc_q2 = nn.Linear(feature_dims, dim_q)
        self.fc_k2 = nn.Linear(feature_dims, dim_q)
        self.fc_v2 = nn.Linear(feature_dims, dim_q)
        
        self.fc_q3 = nn.Linear(feature_dims, dim_q)
        self.fc_k3 = nn.Linear(feature_dims, dim_q)
        self.fc_v3 = nn.Linear(feature_dims, dim_q)
        
        self.fc_o = nn.Linear(3*dim_q, feature_dims)

    def forward(self, input_data):
        # Expect input_data to be of shape (batch_size, channels, l, w, h).
        batch_size, channels, l, w, h  = input_data.size()
        # (batch_size, n_pixels, channels)
        input_data = input_data.flatten().reshape(batch_size, channels, -1)

        # Linear transforms(head_1).
        queries1 = self.fc_q1(input=input_data)  # (batch_size, feature_dims, dim_q)
        keys1 = self.fc_k1(input=input_data)  # (batch_size, feature_dims, dim_q)
        values1 = self.fc_v1(input=input_data)  # (batch_size, feature_dims, dim_q)
        
        # Attention matrix1.
        dot1 = torch.bmm(queries1, keys1.transpose(1, 2))  # (batch_size, channels, channels)
        scaled_dot1 = torch.div(dot1, torch.sqrt(torch.tensor(l*w*h).float())) # scale
        atten_matrix1 = F.softmax(scaled_dot1, dim=1)
        atten_weighted1 = torch.bmm(atten_matrix1, values1)
        
        # Linear transforms(head_2).
        queries2 = self.fc_q2(input=input_data)  # (batch_size, feature_dims, dim_q)
        keys2 = self.fc_k2(input=input_data)  # (batch_size, feature_dims, dim_q)
        values2 = self.fc_v2(input=input_data)  # (batch_size, feature_dims, dim_q)
        
        # Attention matrix2.
        dot2 = torch.bmm(queries2, keys2.transpose(1, 2))  # (batch_size, channels, channels)
        scaled_dot2 = torch.div(dot2, torch.sqrt(torch.tensor(l*w*h).float())) # scale
        atten_matrix2 = F.softmax(scaled_dot2, dim=1)
        atten_weighted2 = torch.bmm(atten_matrix2, values2)
        
        # Linear transforms(head_3).
        queries3 = self.fc_q3(input=input_data)  # (batch_size, feature_dims, dim_q)
        keys3 = self.fc_k3(input=input_data)  # (batch_size, feature_dims, dim_q)
        values3 = self.fc_v3(input=input_data)  # (batch_size, feature_dims, dim_q)
        
        # Attention matrix1.
        dot3 = torch.bmm(queries3, keys3.transpose(1, 2))  # (batch_size, channels, channels)
        scaled_dot3 = torch.div(dot3, torch.sqrt(torch.tensor(l*w*h).float())) # scale
        atten_matrix3 = F.softmax(scaled_dot3, dim=1)
        atten_weighted3 = torch.bmm(atten_matrix3, values3)
        
        catlayer = torch.cat((atten_weighted1,atten_weighted2,atten_weighted3),dim=2)
        output = self.fc_o(catlayer).flatten().reshape(batch_size, channels, l, w, h)
        
        return output

# %%
net = SelfAttention_3D(1000, 10)
a = torch.zeros(4, 90, 10, 10, 10)
b = net(a)
print(a.shape)
print(b.shape)
# Out:
# torch.Size([4, 90, 10, 10, 10])
# torch.Size([4, 90, 10, 10, 10])

# %%
class SelfAttention_UNet(nn.Module):

    def __init__(self, in_channels, n_classes):
        super(SelfAttention_UNet, self).__init__()
        self.down1 = nn.Sequential(
            nn.Conv3d(in_channels, out_channels=8, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(8),
            nn.ReLU(inplace=True),
            
            nn.Conv3d(in_channels=8, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(16),
            nn.ReLU(inplace=True)
        )
        
        self.pool1 = nn.MaxPool3d(kernel_size=2, stride=2, padding=0)
        
        self.down2 = nn.Sequential(
            nn.Conv3d(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(16),
            nn.ReLU(inplace=True),
            
            nn.Conv3d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(32),
            nn.ReLU(inplace=True)
        )
        
        self.pool2 = nn.MaxPool3d(kernel_size=2, stride=2, padding=0)
        
        self.down3 = nn.Sequential(
            nn.Conv3d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(32),
            nn.ReLU(inplace=True),
            
            nn.Conv3d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(64),
            nn.ReLU(inplace=True),
            
            SelfAttention_3D(45*54*45,10)
        )
        
        self.pool3 = nn.MaxPool3d(kernel_size=2, stride=2, padding=0)
        
        self.bottom = nn.Sequential(
            nn.Conv3d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(64),
            nn.ReLU(inplace=True),
            
            nn.Conv3d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(128),
            nn.ReLU(inplace=True),
            
            SelfAttention_3D(22*27*22,10)
        )
     
        self.upconv3 = nn.ConvTranspose3d(in_channels=128, out_channels=64, kernel_size=3, 
                                       stride=2, padding=0, output_padding=0, bias=True, padding_mode='zeros')
        
        self.up3 = nn.Sequential(
            nn.Conv3d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(128),
            nn.ReLU(inplace=True),
            
            nn.Conv3d(in_channels=128, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(64),
            nn.ReLU(inplace=True),
            
            SelfAttention_3D(45*54*45,10)
            
        )
        
        self.upconv2 = nn.ConvTranspose3d(in_channels=64, out_channels=32, kernel_size=3, 
                                       stride=2, padding=1, output_padding=1, bias=True, padding_mode='zeros')
        
        self.up2 = nn.Sequential(
            nn.Conv3d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(64),
            nn.ReLU(inplace=True),
            
            nn.Conv3d(in_channels=64, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(32),
            nn.ReLU(inplace=True),
        )
        
        self.upconv1 = nn.ConvTranspose3d(in_channels=32, out_channels=16, kernel_size=3, 
                                       stride=2, padding=0, output_padding=0, bias=True, padding_mode='zeros')
        
        self.up1 = nn.Sequential(
            nn.Conv3d(in_channels=32, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(16),
            nn.ReLU(inplace=True),
            
            nn.Conv3d(in_channels=16, out_channels=8, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.BatchNorm3d(8),
            nn.ReLU(inplace=True),
        )
        
        self.out = nn.Sequential(
            nn.Conv3d(in_channels=8, out_channels=n_classes, kernel_size=3, stride=1, padding=1, bias=True, padding_mode='zeros'),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        x = self.down1(x)
        left1 = x
        x = self.pool1(x)
        
        x = self.down2(x)
        left2 = x
        x = self.pool2(x)
        
        x = self.down3(x)
        left3 = x
        x = self.pool3(x)
        
        x = self.bottom(x)
        
        x = self.upconv3(x)[:,:,:,0:-1,:]
        x = torch.cat((left3,x),dim=1)
        x = self.up3(x)
        
        x = self.upconv2(x)
        x = torch.cat((left2,x),dim=1)
        x = self.up2(x)
        
        x = self.upconv1(x)
        x = torch.cat((left1,x),dim=1)
        x = self.up1(x)
        
        x = self.out(x)

        return x

# %%
net = SelfAttention_UNet(4,1).to(device)
a = torch.zeros(1, 4, 181, 217, 181).to(device)
b = net(a)
print(a.shape)
print(b.shape)
# Out:
# torch.Size([1, 4, 181, 217, 181])
# torch.Size([1, 1, 181, 217, 181])

# %%
'''
class SelfAttention_UNet(nn.Module):

    def __init__(self, in_channels, n_classes):
        super(SelfAttention_UNet, self).__init__()
        self.down1 = nn.Sequential(
            nn.Conv3d(in_channels, out_channels=32, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(32),
            nn.ReLU(),
            
            nn.Conv3d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(64),
            nn.ReLU()
        )
        
        self.pool1 = nn.MaxPool3d(kernel_size=2, stride=2, padding=0)
        
        self.down2 = nn.Sequential(
            nn.Conv3d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(64),
            nn.ReLU(),
            
            nn.Conv3d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(128),
            nn.ReLU()
        )
        
        self.pool2 = nn.MaxPool3d(kernel_size=2, stride=2, padding=0)
        
        self.down3 = nn.Sequential(
            nn.Conv3d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(128),
            nn.ReLU(),
            
            nn.Conv3d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(256),
            nn.ReLU(),
        )
        
        self.pool3 = nn.MaxPool3d(kernel_size=2, stride=2, padding=0)
        
        self.down4 = nn.Sequential(
            nn.Conv3d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(256),
            nn.ReLU(),
            
            nn.Conv3d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(512),
            nn.ReLU(),
            
            SelfAttention_3D(22*27*22,10)
        )
        
        self.pool4 = nn.MaxPool3d(kernel_size=2, stride=2, padding=0)
        
        self.bottom = nn.Sequential(
            nn.Conv3d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(512),
            nn.ReLU(),
            
            nn.Conv3d(in_channels=512, out_channels=1024, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(1024),
            nn.ReLU(),
            
            SelfAttention_3D(11*13*11,10)
        )
        
        self.upconv4 = nn.ConvTranspose3d(in_channels=1024, out_channels=512, kernel_size=3, 
                                       stride=2, padding=1, output_padding=1, bias=False, padding_mode='zeros')
        
        self.up4 = nn.Sequential(
            nn.Conv3d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(1024),
            nn.ReLU(),
            
            nn.Conv3d(in_channels=1024, out_channels=512, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(512),
            nn.ReLU(),
            
            SelfAttention_3D(22*26*22,10)
        )
        
        self.upconv3 = nn.ConvTranspose3d(in_channels=512, out_channels=256, kernel_size=3, 
                                       stride=2, padding=0, output_padding=0, bias=False, padding_mode='zeros')
        
        self.up3 = nn.Sequential(
            nn.Conv3d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(512),
            nn.ReLU(),
            
            nn.Conv3d(in_channels=512, out_channels=256, kernel_size=3, stride=1, padding=2, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(256),
            nn.ReLU(),
            
        )
        
        self.upconv2 = nn.ConvTranspose3d(in_channels=256, out_channels=128, kernel_size=3, 
                                       stride=2, padding=2, output_padding=1, bias=False, padding_mode='zeros')
        
        self.up2 = nn.Sequential(
            nn.Conv3d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(256),
            nn.ReLU(),
            
            nn.Conv3d(in_channels=256, out_channels=128, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(128),
            nn.ReLU(),
        )
        
        self.upconv1 = nn.ConvTranspose3d(in_channels=128, out_channels=64, kernel_size=3, 
                                       stride=2, padding=0, output_padding=0, bias=False, padding_mode='zeros')
        
        self.up1 = nn.Sequential(
            nn.Conv3d(in_channels=128, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(64),
            nn.ReLU(),
            
            nn.Conv3d(in_channels=64, out_channels=32, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.BatchNorm3d(32),
            nn.ReLU(),
        )
        
        self.out = nn.Sequential(
            nn.Conv3d(in_channels=32, out_channels=n_classes, kernel_size=3, stride=1, padding=1, bias=False, padding_mode='zeros'),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        x = self.down1(x)
        left1 = x
        x = self.pool1(x)
        
        x = self.down2(x)
        left2 = x
        x = self.pool2(x)
        
        x = self.down3(x)
        left3 = x[:,:,:,0:-1,:]
        x = self.pool3(x)
        
        x = self.down4(x)
        left4 = x[:,:,:,0:-1,:]
        x = self.pool4(x)
        
        x = self.bottom(x)
        
        x = self.upconv4(x)
        x = torch.cat((left4,x),dim=1)
        x = self.up4(x)
        
        x = self.upconv3(x)
        x = torch.cat((left3,x),dim=1)
        x = self.up3(x)
        
        x = self.upconv2(x)[:,:,0:-2,:,0:-2]
        x = torch.cat((left2,x),dim=1)
        x = self.up2(x)
        
        x = self.upconv1(x)
        x = torch.cat((left1,x),dim=1)
        x = self.up1(x)
        
        x = self.out(x)
        
        return x
'''

# %% [markdown]
# # 4.Dice Loss

# %%
# define dice coefficient
def dice_coeff(pred, target):
    smooth = 1
    # First let's flatten the matrix to [Batch Size, -1]
    # The flatten operation does not afftect the computation of the above equation
    num = pred.size(0)
    m1 = pred. view(num, -1). float() # Flatten
    m2 = target. view(num, -1). float() # Flatten
    # Then we compute the intersection and the sum of cardinality
    intersection = 2*torch.sum(m1*m2,dim= 1) + smooth
    cardinality = torch.sum(m1**2,dim= 1) + torch.sum(m2**2,dim= 1) + smooth
    # Followed by Dice
    dice = intersection/cardinality
    return dice.mean()
# define SoftDICE loss as 1 - SoftDICE
class SoftDICELoss(nn. Module):
    def __init__(self, smooth = 1):
        super(SoftDICELoss, self). __init__()
        self. smooth = smooth
    def forward(self, pred, target):
        loss = 1 - dice_coeff(pred, target)
        return loss.mean()

# %% [markdown]
# # 5.Training

# %%
def train_epoch(net, data_loader, optimizer, criterion, epoch):

    net = net.train()
    optimizer.zero_grad()
    loss_stat = []
    for i, img_mask in enumerate(data_loader):
        img, mask = img_mask

        img = img.to(device)
        mask = mask.to(device)

        pred = net(img)

        loss = criterion(pred, mask)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        loss_stat += [loss.item()]*img.shape[0]
        print ("Epoch {}: [{}/{}] Loss: {:.3f}". format(epoch, len(data_loader), len(data_loader),np. mean(loss_stat)))
    return np.mean(loss_stat)

# %%
def eval_epoch(net, data_loader, metric, criterion):
    # set model in eval mode to avoid updating BN layer
    net = net.eval()
    
    metric_stat = []
    val_loss_stat = []
    for i, img_mask in enumerate(data_loader):
        img, mask = img_mask
        # send data to device
        img = img.to(device)
        mask = mask.to(device)
        # feed data to the model. No need to compute grad.
        with torch.no_grad():
            pred = net(img)
            val_loss = criterion(pred, mask)
            
        # eval the results using DICE function as the metric
        # Convert probability to prediction mask
        pred = pred>0.4
        err = dice_coeff(pred, mask)
        metric_stat += [err.item()]*img.shape[0]
        val_loss_stat += [val_loss.item()]*img.shape[0]
        
    print ("Dice: {:.3f}  Val Loss: {:.3f} ".format(np.mean(metric_stat), np.mean(val_loss_stat)))
    
    return np.mean(val_loss_stat), np.mean(metric_stat)

# %%
net = SelfAttention_UNet(4,1).to(device)
print(net)
n_params = sum(p.numel() for p in net.parameters() if p.requires_grad)
print('Number of parameters in network: ', n_params)
# Out:
# SelfAttention_UNet(
#   (down1): Sequential(
#     (0): Conv3d(4, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(8, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (pool1): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (down2): Sequential(
#     (0): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (pool2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (down3): Sequential(
#     (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): SelfAttention_3D(
#       (fc_q1): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_k1): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_v1): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_q2): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_k2): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_v2): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_q3): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_k3): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_v3): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_o): Linear(in_features=30, out_features=109350, bias=True)
#     )
#   )
#   (pool3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bottom): Sequential(
#     (0): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): SelfAttention_3D(
#       (fc_q1): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_k1): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_v1): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_q2): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_k2): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_v2): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_q3): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_k3): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_v3): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_o): Linear(in_features=30, out_features=13068, bias=True)
#     )
#   )
#   (upconv3): ConvTranspose3d(128, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2))
#   (up3): Sequential(
#     (0): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): SelfAttention_3D(
#       (fc_q1): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_k1): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_v1): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_q2): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_k2): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_v2): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_q3): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_k3): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_v3): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_o): Linear(in_features=30, out_features=109350, bias=True)
#     )
#   )
#   (upconv2): ConvTranspose3d(64, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#   (up2): Sequential(
#     (0): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (upconv1): ConvTranspose3d(32, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2))
#   (up1): Sequential(
#     (0): Conv3d(32, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(16, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (out): Sequential(
#     (0): Conv3d(8, 1, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): Sigmoid()
#   )
# )
# Number of parameters in network:  29623343

# %%
optimizer = optim.Adam(net.parameters(), lr= LR)
criterion = SoftDICELoss()
train_loss_list = []
val_loss_list = []

# %%
for epoch in range(NUM_EPOCH):    
    loss = train_epoch(net, train_loader, optimizer, criterion, epoch)
    val_loss, dice = eval_epoch(net, val_loader, dice_coeff, criterion)
    
    # Record losses for each epoch
    train_loss_list.append(loss)
    val_loss_list.append(val_loss)
    
    # Save the model after each epoch
    if os.path.isdir(SAVE_PATH):
        torch.save(net.state_dict(),SAVE_PATH + 'MRISegEpoch{}.pth'.format(epoch + 1))
    else:
        os.makedirs(SAVE_PATH, exist_ok=True)
        torch.save(net.state_dict(),SAVE_PATH + 'MRISegEpoch{}.pth'.format(epoch + 1))
    print('Checkpoint {} saved to {}'.format(epoch + 1, SAVE_PATH + 'MRISegEpoch{}.pth'.format(epoch + 1)))
# Out:
# Epoch 0: [4/4] Loss: 0.993
# Epoch 0: [4/4] Loss: 0.994
# Epoch 0: [4/4] Loss: 0.991
# Epoch 0: [4/4] Loss: 0.991
# Dice: 0.001  Val Loss: 0.997
# Checkpoint 1 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch1.pth
# Epoch 1: [4/4] Loss: 0.991
# Epoch 1: [4/4] Loss: 0.991
# Epoch 1: [4/4] Loss: 0.989
# Epoch 1: [4/4] Loss: 0.987
# Dice: 0.001  Val Loss: 0.997
# Checkpoint 2 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch2.pth
# Epoch 2: [4/4] Loss: 0.992
# Epoch 2: [4/4] Loss: 0.990
# Epoch 2: [4/4] Loss: 0.987
# Epoch 2: [4/4] Loss: 0.984
# Dice: 0.001  Val Loss: 0.997
# Checkpoint 3 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch3.pth
# Epoch 3: [4/4] Loss: 0.995
# Epoch 3: [4/4] Loss: 0.993
# Epoch 3: [4/4] Loss: 0.986
# Epoch 3: [4/4] Loss: 0.982
# Dice: 0.005  Val Loss: 0.996
# Checkpoint 4 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch4.pth
# Epoch 4: [4/4] Loss: 0.968
# Epoch 4: [4/4] Loss: 0.981
# Epoch 4: [4/4] Loss: 0.979
# Epoch 4: [4/4] Loss: 0.974
# Dice: 0.002  Val Loss: 0.997
# Checkpoint 5 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch5.pth
# Epoch 5: [4/4] Loss: 0.994
# Epoch 5: [4/4] Loss: 0.971
# Epoch 5: [4/4] Loss: 0.961
# Epoch 5: [4/4] Loss: 0.959
# Dice: 0.001  Val Loss: 0.997
# Checkpoint 6 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch6.pth
# Epoch 6: [4/4] Loss: 0.915
# Epoch 6: [4/4] Loss: 0.922
# Epoch 6: [4/4] Loss: 0.930
# Epoch 6: [4/4] Loss: 0.946
# Dice: 0.001  Val Loss: 0.997
# Checkpoint 7 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch7.pth
# Epoch 7: [4/4] Loss: 0.895
# Epoch 7: [4/4] Loss: 0.912
# Epoch 7: [4/4] Loss: 0.936
# Epoch 7: [4/4] Loss: 0.924
# Dice: 0.003  Val Loss: 0.995
# Checkpoint 8 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch8.pth
# Epoch 8: [4/4] Loss: 0.873
# Epoch 8: [4/4] Loss: 0.896
# Epoch 8: [4/4] Loss: 0.893
# Epoch 8: [4/4] Loss: 0.903
# Dice: 0.131  Val Loss: 0.856
# Checkpoint 9 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch9.pth
# Epoch 9: [4/4] Loss: 0.839
# Epoch 9: [4/4] Loss: 0.823
# Epoch 9: [4/4] Loss: 0.850
# Epoch 9: [4/4] Loss: 0.856
# Dice: 0.000  Val Loss: 0.983
# Checkpoint 10 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch10.pth
# Epoch 10: [4/4] Loss: 0.852
# Epoch 10: [4/4] Loss: 0.844
# Epoch 10: [4/4] Loss: 0.831
# Epoch 10: [4/4] Loss: 0.829
# Dice: 0.001  Val Loss: 0.996
# Checkpoint 11 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch11.pth
# Epoch 11: [4/4] Loss: 0.817
# Epoch 11: [4/4] Loss: 0.811
# Epoch 11: [4/4] Loss: 0.784
# Epoch 11: [4/4] Loss: 0.834
# Dice: 0.003  Val Loss: 0.992
# Checkpoint 12 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch12.pth
# Epoch 12: [4/4] Loss: 0.763
# Epoch 12: [4/4] Loss: 0.783
# Epoch 12: [4/4] Loss: 0.820
# Epoch 12: [4/4] Loss: 0.849
# Dice: 0.425  Val Loss: 0.606
# Checkpoint 13 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch13.pth
# Epoch 13: [4/4] Loss: 0.795
# Epoch 13: [4/4] Loss: 0.764
# Epoch 13: [4/4] Loss: 0.810
# Epoch 13: [4/4] Loss: 0.797
# Dice: 0.291  Val Loss: 0.684
# Checkpoint 14 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch14.pth
# Epoch 14: [4/4] Loss: 0.663
# Epoch 14: [4/4] Loss: 0.747
# Epoch 14: [4/4] Loss: 0.755
# Epoch 14: [4/4] Loss: 0.752
# Dice: 0.495  Val Loss: 0.649
# Checkpoint 15 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch15.pth
# Epoch 15: [4/4] Loss: 0.651
# Epoch 15: [4/4] Loss: 0.711
# Epoch 15: [4/4] Loss: 0.684
# Epoch 15: [4/4] Loss: 0.708
# Dice: 0.001  Val Loss: 0.998
# Checkpoint 16 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch16.pth
# Epoch 16: [4/4] Loss: 0.711
# Epoch 16: [4/4] Loss: 0.762
# Epoch 16: [4/4] Loss: 0.708
# Epoch 16: [4/4] Loss: 0.700
# Dice: 0.001  Val Loss: 0.998
# Checkpoint 17 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch17.pth
# Epoch 17: [4/4] Loss: 0.617
# Epoch 17: [4/4] Loss: 0.695
# Epoch 17: [4/4] Loss: 0.722
# Epoch 17: [4/4] Loss: 0.723
# Dice: 0.001  Val Loss: 0.997
# Checkpoint 18 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch18.pth
# Epoch 18: [4/4] Loss: 0.628
# Epoch 18: [4/4] Loss: 0.615
# Epoch 18: [4/4] Loss: 0.637
# Epoch 18: [4/4] Loss: 0.650
# Dice: 0.001  Val Loss: 0.997
# Checkpoint 19 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch19.pth
# Epoch 19: [4/4] Loss: 0.688
# Epoch 19: [4/4] Loss: 0.602
# Epoch 19: [4/4] Loss: 0.610
# Epoch 19: [4/4] Loss: 0.637
# Dice: 0.003  Val Loss: 0.993
# Checkpoint 20 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch20.pth
# Epoch 20: [4/4] Loss: 0.540
# Epoch 20: [4/4] Loss: 0.616
# Epoch 20: [4/4] Loss: 0.625
# Epoch 20: [4/4] Loss: 0.616
# Dice: 0.002  Val Loss: 0.994
# Checkpoint 21 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch21.pth
# Epoch 21: [4/4] Loss: 0.595
# Epoch 21: [4/4] Loss: 0.609
# Epoch 21: [4/4] Loss: 0.589
# Epoch 21: [4/4] Loss: 0.581
# Dice: 0.190  Val Loss: 0.848
# Checkpoint 22 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch22.pth
# Epoch 22: [4/4] Loss: 0.556
# Epoch 22: [4/4] Loss: 0.495
# Epoch 22: [4/4] Loss: 0.533
# Epoch 22: [4/4] Loss: 0.576
# Dice: 0.329  Val Loss: 0.732
# Checkpoint 23 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch23.pth
# Epoch 23: [4/4] Loss: 0.557
# Epoch 23: [4/4] Loss: 0.523
# Epoch 23: [4/4] Loss: 0.534
# Epoch 23: [4/4] Loss: 0.552
# Dice: 0.486  Val Loss: 0.590
# Checkpoint 24 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch24.pth
# Epoch 24: [4/4] Loss: 0.433
# Epoch 24: [4/4] Loss: 0.549
# Epoch 24: [4/4] Loss: 0.544
# Epoch 24: [4/4] Loss: 0.625
# Dice: 0.513  Val Loss: 0.536
# Checkpoint 25 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch25.pth
# Epoch 25: [4/4] Loss: 0.701
# Epoch 25: [4/4] Loss: 0.606
# Epoch 25: [4/4] Loss: 0.613
# Epoch 25: [4/4] Loss: 0.590
# Dice: 0.501  Val Loss: 0.476
# Checkpoint 26 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch26.pth
# Epoch 26: [4/4] Loss: 0.523
# Epoch 26: [4/4] Loss: 0.462
# Epoch 26: [4/4] Loss: 0.526
# Epoch 26: [4/4] Loss: 0.558
# Dice: 0.434  Val Loss: 0.556
# Checkpoint 27 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch27.pth
# Epoch 27: [4/4] Loss: 0.502
# Epoch 27: [4/4] Loss: 0.498
# Epoch 27: [4/4] Loss: 0.488
# Epoch 27: [4/4] Loss: 0.493
# Dice: 0.365  Val Loss: 0.635
# Checkpoint 28 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch28.pth
# Epoch 28: [4/4] Loss: 0.542
# Epoch 28: [4/4] Loss: 0.472
# Epoch 28: [4/4] Loss: 0.475
# Epoch 28: [4/4] Loss: 0.516
# Dice: 0.516  Val Loss: 0.499
# Checkpoint 29 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch29.pth
# Epoch 29: [4/4] Loss: 0.468
# Epoch 29: [4/4] Loss: 0.451
# Epoch 29: [4/4] Loss: 0.442
# Epoch 29: [4/4] Loss: 0.451
# Dice: 0.484  Val Loss: 0.527
# Checkpoint 30 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch30.pth
# Epoch 30: [4/4] Loss: 0.652
# Epoch 30: [4/4] Loss: 0.552
# Epoch 30: [4/4] Loss: 0.499
# Epoch 30: [4/4] Loss: 0.532
# Dice: 0.552  Val Loss: 0.443
# Checkpoint 31 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch31.pth
# Epoch 31: [4/4] Loss: 0.457
# Epoch 31: [4/4] Loss: 0.432
# Epoch 31: [4/4] Loss: 0.449
# Epoch 31: [4/4] Loss: 0.451
# Dice: 0.552  Val Loss: 0.446
# Checkpoint 32 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch32.pth
# Epoch 32: [4/4] Loss: 0.441
# Epoch 32: [4/4] Loss: 0.447
# Epoch 32: [4/4] Loss: 0.424
# Epoch 32: [4/4] Loss: 0.433
# Dice: 0.478  Val Loss: 0.629
# Checkpoint 33 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch33.pth
# Epoch 33: [4/4] Loss: 0.600
# Epoch 33: [4/4] Loss: 0.612
# Epoch 33: [4/4] Loss: 0.572
# Epoch 33: [4/4] Loss: 0.536
# Dice: 0.380  Val Loss: 0.606
# Checkpoint 34 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch34.pth
# Epoch 34: [4/4] Loss: 0.425
# Epoch 34: [4/4] Loss: 0.449
# Epoch 34: [4/4] Loss: 0.434
# Epoch 34: [4/4] Loss: 0.484
# Dice: 0.274  Val Loss: 0.708
# Checkpoint 35 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch35.pth
# Epoch 35: [4/4] Loss: 0.452
# Epoch 35: [4/4] Loss: 0.462
# Epoch 35: [4/4] Loss: 0.440
# Epoch 35: [4/4] Loss: 0.432
# Dice: 0.652  Val Loss: 0.338
# Checkpoint 36 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch36.pth
# Epoch 36: [4/4] Loss: 0.437
# Epoch 36: [4/4] Loss: 0.402
# Epoch 36: [4/4] Loss: 0.416
# Epoch 36: [4/4] Loss: 0.420
# Dice: 0.633  Val Loss: 0.349
# Checkpoint 37 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch37.pth
# Epoch 37: [4/4] Loss: 0.474
# Epoch 37: [4/4] Loss: 0.439
# Epoch 37: [4/4] Loss: 0.418
# Epoch 37: [4/4] Loss: 0.421
# Dice: 0.620  Val Loss: 0.337
# Checkpoint 38 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch38.pth
# Epoch 38: [4/4] Loss: 0.899
# Epoch 38: [4/4] Loss: 0.700
# Epoch 38: [4/4] Loss: 0.608
# Epoch 38: [4/4] Loss: 0.550
# Dice: 0.574  Val Loss: 0.391
# Checkpoint 39 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch39.pth
# Epoch 39: [4/4] Loss: 0.371
# Epoch 39: [4/4] Loss: 0.425
# Epoch 39: [4/4] Loss: 0.424
# Epoch 39: [4/4] Loss: 0.432
# Dice: 0.001  Val Loss: 0.998
# Checkpoint 40 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch40.pth
# Epoch 40: [4/4] Loss: 0.413
# Epoch 40: [4/4] Loss: 0.426
# Epoch 40: [4/4] Loss: 0.444
# Epoch 40: [4/4] Loss: 0.449
# Dice: 0.001  Val Loss: 0.998
# Checkpoint 41 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch41.pth
# Epoch 41: [4/4] Loss: 0.611
# Epoch 41: [4/4] Loss: 0.624
# Epoch 41: [4/4] Loss: 0.602
# Epoch 41: [4/4] Loss: 0.602
# Dice: 0.001  Val Loss: 0.998
# Checkpoint 42 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch42.pth
# Epoch 42: [4/4] Loss: 0.442
# Epoch 42: [4/4] Loss: 0.482
# Epoch 42: [4/4] Loss: 0.475
# Epoch 42: [4/4] Loss: 0.466
# Dice: 0.001  Val Loss: 0.998
# Checkpoint 43 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch43.pth
# Epoch 43: [4/4] Loss: 0.412
# Epoch 43: [4/4] Loss: 0.450
# Epoch 43: [4/4] Loss: 0.486
# Epoch 43: [4/4] Loss: 0.470
# Dice: 0.001  Val Loss: 0.998
# Checkpoint 44 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch44.pth
# Epoch 44: [4/4] Loss: 0.395
# Epoch 44: [4/4] Loss: 0.403
# Epoch 44: [4/4] Loss: 0.428
# Epoch 44: [4/4] Loss: 0.428
# Dice: 0.335  Val Loss: 0.654
# Checkpoint 45 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch45.pth
# Epoch 45: [4/4] Loss: 0.415
# Epoch 45: [4/4] Loss: 0.537
# Epoch 45: [4/4] Loss: 0.484
# Epoch 45: [4/4] Loss: 0.503
# Dice: 0.001  Val Loss: 0.997
# Checkpoint 46 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch46.pth
# Epoch 46: [4/4] Loss: 0.492
# Epoch 46: [4/4] Loss: 0.530
# Epoch 46: [4/4] Loss: 0.487
# Epoch 46: [4/4] Loss: 0.518
# Dice: 0.001  Val Loss: 0.998
# Checkpoint 47 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch47.pth
# Epoch 47: [4/4] Loss: 0.574
# Epoch 47: [4/4] Loss: 0.588
# Epoch 47: [4/4] Loss: 0.517
# Epoch 47: [4/4] Loss: 0.512
# Dice: 0.001  Val Loss: 0.997
# Checkpoint 48 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch48.pth
# Epoch 48: [4/4] Loss: 0.608
# Epoch 48: [4/4] Loss: 0.493
# Epoch 48: [4/4] Loss: 0.475
# Epoch 48: [4/4] Loss: 0.464
# Dice: 0.001  Val Loss: 0.998
# Checkpoint 49 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch49.pth
# Epoch 49: [4/4] Loss: 0.456
# Epoch 49: [4/4] Loss: 0.517
# Epoch 49: [4/4] Loss: 0.476
# Epoch 49: [4/4] Loss: 0.461
# Dice: 0.001  Val Loss: 0.998
# Checkpoint 50 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch50.pth
# Epoch 50: [4/4] Loss: 0.442
# Epoch 50: [4/4] Loss: 0.432
# Epoch 50: [4/4] Loss: 0.417
# Epoch 50: [4/4] Loss: 0.450
# Dice: 0.528  Val Loss: 0.445
# Checkpoint 51 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch51.pth
# Epoch 51: [4/4] Loss: 0.620
# Epoch 51: [4/4] Loss: 0.510
# Epoch 51: [4/4] Loss: 0.477
# Epoch 51: [4/4] Loss: 0.457
# Dice: 0.541  Val Loss: 0.433
# Checkpoint 52 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch52.pth
# Epoch 52: [4/4] Loss: 0.402
# Epoch 52: [4/4] Loss: 0.451
# Epoch 52: [4/4] Loss: 0.430
# Epoch 52: [4/4] Loss: 0.431
# Dice: 0.395  Val Loss: 0.751
# Checkpoint 53 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch53.pth
# Epoch 53: [4/4] Loss: 0.392
# Epoch 53: [4/4] Loss: 0.434
# Epoch 53: [4/4] Loss: 0.430
# Epoch 53: [4/4] Loss: 0.434
# Dice: 0.104  Val Loss: 0.967
# Checkpoint 54 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch54.pth
# Epoch 54: [4/4] Loss: 0.493
# Epoch 54: [4/4] Loss: 0.520
# Epoch 54: [4/4] Loss: 0.544
# Epoch 54: [4/4] Loss: 0.511
# Dice: 0.499  Val Loss: 0.464
# Checkpoint 55 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch55.pth
# Epoch 55: [4/4] Loss: 0.453
# Epoch 55: [4/4] Loss: 0.460
# Epoch 55: [4/4] Loss: 0.438
# Epoch 55: [4/4] Loss: 0.469
# Dice: 0.596  Val Loss: 0.368
# Checkpoint 56 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch56.pth
# Epoch 56: [4/4] Loss: 0.418
# Epoch 56: [4/4] Loss: 0.388
# Epoch 56: [4/4] Loss: 0.407
# Epoch 56: [4/4] Loss: 0.428
# Dice: 0.625  Val Loss: 0.341
# Checkpoint 57 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch57.pth
# Epoch 57: [4/4] Loss: 0.448
# Epoch 57: [4/4] Loss: 0.436
# Epoch 57: [4/4] Loss: 0.408
# Epoch 57: [4/4] Loss: 0.417
# Dice: 0.657  Val Loss: 0.310
# Checkpoint 58 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch58.pth
# Epoch 58: [4/4] Loss: 0.484
# Epoch 58: [4/4] Loss: 0.464
# Epoch 58: [4/4] Loss: 0.448
# Epoch 58: [4/4] Loss: 0.457
# Dice: 0.647  Val Loss: 0.362
# Checkpoint 59 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch59.pth
# Epoch 59: [4/4] Loss: 0.496
# Epoch 59: [4/4] Loss: 0.439
# Epoch 59: [4/4] Loss: 0.432
# Epoch 59: [4/4] Loss: 0.415
# Dice: 0.591  Val Loss: 0.539
# Checkpoint 60 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch60.pth
# Epoch 60: [4/4] Loss: 0.420
# Epoch 60: [4/4] Loss: 0.386
# Epoch 60: [4/4] Loss: 0.383
# Epoch 60: [4/4] Loss: 0.365
# Dice: 0.610  Val Loss: 0.431
# Checkpoint 61 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch61.pth
# Epoch 61: [4/4] Loss: 0.226
# Epoch 61: [4/4] Loss: 0.285
# Epoch 61: [4/4] Loss: 0.288
# Epoch 61: [4/4] Loss: 0.302
# Dice: 0.540  Val Loss: 0.450
# Checkpoint 62 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch62.pth
# Epoch 62: [4/4] Loss: 0.313
# Epoch 62: [4/4] Loss: 0.276
# Epoch 62: [4/4] Loss: 0.294
# Epoch 62: [4/4] Loss: 0.317
# Dice: 0.611  Val Loss: 0.366
# Checkpoint 63 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch63.pth
# Epoch 63: [4/4] Loss: 0.314
# Epoch 63: [4/4] Loss: 0.277
# Epoch 63: [4/4] Loss: 0.281
# Epoch 63: [4/4] Loss: 0.295
# Dice: 0.393  Val Loss: 0.589
# Checkpoint 64 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch64.pth
# Epoch 64: [4/4] Loss: 0.381
# Epoch 64: [4/4] Loss: 0.333
# Epoch 64: [4/4] Loss: 0.310
# Epoch 64: [4/4] Loss: 0.299
# Dice: 0.079  Val Loss: 0.871
# Checkpoint 65 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch65.pth
# Epoch 65: [4/4] Loss: 0.241
# Epoch 65: [4/4] Loss: 0.312
# Epoch 65: [4/4] Loss: 0.314
# Epoch 65: [4/4] Loss: 0.301
# Dice: 0.183  Val Loss: 0.788
# Checkpoint 66 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch66.pth
# Epoch 66: [4/4] Loss: 0.273
# Epoch 66: [4/4] Loss: 0.258
# Epoch 66: [4/4] Loss: 0.260
# Epoch 66: [4/4] Loss: 0.275
# Dice: 0.319  Val Loss: 0.664
# Checkpoint 67 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch67.pth
# Epoch 67: [4/4] Loss: 0.255
# Epoch 67: [4/4] Loss: 0.228
# Epoch 67: [4/4] Loss: 0.252
# Epoch 67: [4/4] Loss: 0.261
# Dice: 0.418  Val Loss: 0.566
# Checkpoint 68 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch68.pth
# Epoch 68: [4/4] Loss: 0.279
# Epoch 68: [4/4] Loss: 0.240
# Epoch 68: [4/4] Loss: 0.276
# Epoch 68: [4/4] Loss: 0.262
# Dice: 0.519  Val Loss: 0.460
# Checkpoint 69 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch69.pth
# Epoch 69: [4/4] Loss: 0.210
# Epoch 69: [4/4] Loss: 0.261
# Epoch 69: [4/4] Loss: 0.259
# Epoch 69: [4/4] Loss: 0.267
# Dice: 0.448  Val Loss: 0.528
# Checkpoint 70 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch70.pth
# Epoch 70: [4/4] Loss: 0.259
# Epoch 70: [4/4] Loss: 0.298
# Epoch 70: [4/4] Loss: 0.300
# Epoch 70: [4/4] Loss: 0.271
# Dice: 0.632  Val Loss: 0.330
# Checkpoint 71 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch71.pth
# Epoch 71: [4/4] Loss: 0.341
# Epoch 71: [4/4] Loss: 0.291
# Epoch 71: [4/4] Loss: 0.259
# Epoch 71: [4/4] Loss: 0.294
# Dice: 0.518  Val Loss: 0.476
# Checkpoint 72 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch72.pth
# Epoch 72: [4/4] Loss: 0.227
# Epoch 72: [4/4] Loss: 0.218
# Epoch 72: [4/4] Loss: 0.270
# Epoch 72: [4/4] Loss: 0.266
# Dice: 0.631  Val Loss: 0.328
# Checkpoint 73 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch73.pth
# Epoch 73: [4/4] Loss: 0.238
# Epoch 73: [4/4] Loss: 0.240
# Epoch 73: [4/4] Loss: 0.270
# Epoch 73: [4/4] Loss: 0.271
# Dice: 0.632  Val Loss: 0.312
# Checkpoint 74 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch74.pth
# Epoch 74: [4/4] Loss: 0.229
# Epoch 74: [4/4] Loss: 0.285
# Epoch 74: [4/4] Loss: 0.269
# Epoch 74: [4/4] Loss: 0.260
# Dice: 0.631  Val Loss: 0.338
# Checkpoint 75 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch75.pth
# Epoch 75: [4/4] Loss: 0.235
# Epoch 75: [4/4] Loss: 0.240
# Epoch 75: [4/4] Loss: 0.243
# Epoch 75: [4/4] Loss: 0.241
# Dice: 0.634  Val Loss: 0.324
# Checkpoint 76 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch76.pth
# Epoch 76: [4/4] Loss: 0.216
# Epoch 76: [4/4] Loss: 0.226
# Epoch 76: [4/4] Loss: 0.240
# Epoch 76: [4/4] Loss: 0.231
# Dice: 0.628  Val Loss: 0.335
# Checkpoint 77 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch77.pth
# Epoch 77: [4/4] Loss: 0.238
# Epoch 77: [4/4] Loss: 0.219
# Epoch 77: [4/4] Loss: 0.229
# Epoch 77: [4/4] Loss: 0.225
# Dice: 0.635  Val Loss: 0.328
# Checkpoint 78 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch78.pth
# Epoch 78: [4/4] Loss: 0.233
# Epoch 78: [4/4] Loss: 0.237
# Epoch 78: [4/4] Loss: 0.228
# Epoch 78: [4/4] Loss: 0.222
# Dice: 0.658  Val Loss: 0.311
# Checkpoint 79 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch79.pth
# Epoch 79: [4/4] Loss: 0.229
# Epoch 79: [4/4] Loss: 0.245
# Epoch 79: [4/4] Loss: 0.229
# Epoch 79: [4/4] Loss: 0.220
# Dice: 0.658  Val Loss: 0.292
# Checkpoint 80 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch80.pth
# Epoch 80: [4/4] Loss: 0.249
# Epoch 80: [4/4] Loss: 0.223
# Epoch 80: [4/4] Loss: 0.221
# Epoch 80: [4/4] Loss: 0.213
# Dice: 0.670  Val Loss: 0.294
# Checkpoint 81 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch81.pth
# Epoch 81: [4/4] Loss: 0.170
# Epoch 81: [4/4] Loss: 0.195
# Epoch 81: [4/4] Loss: 0.203
# Epoch 81: [4/4] Loss: 0.213
# Dice: 0.690  Val Loss: 0.270
# Checkpoint 82 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch82.pth
# Epoch 82: [4/4] Loss: 0.256
# Epoch 82: [4/4] Loss: 0.246
# Epoch 82: [4/4] Loss: 0.228
# Epoch 82: [4/4] Loss: 0.220
# Dice: 0.677  Val Loss: 0.291
# Checkpoint 83 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch83.pth
# Epoch 83: [4/4] Loss: 0.177
# Epoch 83: [4/4] Loss: 0.215
# Epoch 83: [4/4] Loss: 0.211
# Epoch 83: [4/4] Loss: 0.213
# Dice: 0.672  Val Loss: 0.277
# Checkpoint 84 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch84.pth
# Epoch 84: [4/4] Loss: 0.222
# Epoch 84: [4/4] Loss: 0.222
# Epoch 84: [4/4] Loss: 0.225
# Epoch 84: [4/4] Loss: 0.217
# Dice: 0.653  Val Loss: 0.322
# Checkpoint 85 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch85.pth
# Epoch 85: [4/4] Loss: 0.218
# Epoch 85: [4/4] Loss: 0.207
# Epoch 85: [4/4] Loss: 0.220
# Epoch 85: [4/4] Loss: 0.223
# Dice: 0.656  Val Loss: 0.294
# Checkpoint 86 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch86.pth
# Epoch 86: [4/4] Loss: 0.172
# Epoch 86: [4/4] Loss: 0.220
# Epoch 86: [4/4] Loss: 0.232
# Epoch 86: [4/4] Loss: 0.225
# Dice: 0.676  Val Loss: 0.294
# Checkpoint 87 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch87.pth
# Epoch 87: [4/4] Loss: 0.245
# Epoch 87: [4/4] Loss: 0.257
# Epoch 87: [4/4] Loss: 0.227
# Epoch 87: [4/4] Loss: 0.223
# Dice: 0.682  Val Loss: 0.275
# Checkpoint 88 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch88.pth
# Epoch 88: [4/4] Loss: 0.203
# Epoch 88: [4/4] Loss: 0.243
# Epoch 88: [4/4] Loss: 0.240
# Epoch 88: [4/4] Loss: 0.228
# Dice: 0.680  Val Loss: 0.283
# Checkpoint 89 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch89.pth
# Epoch 89: [4/4] Loss: 0.217
# Epoch 89: [4/4] Loss: 0.218
# Epoch 89: [4/4] Loss: 0.203
# Epoch 89: [4/4] Loss: 0.233
# Dice: 0.683  Val Loss: 0.281
# Checkpoint 90 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch90.pth
# Epoch 90: [4/4] Loss: 0.249
# Epoch 90: [4/4] Loss: 0.231
# Epoch 90: [4/4] Loss: 0.246
# Epoch 90: [4/4] Loss: 0.236
# Dice: 0.674  Val Loss: 0.279
# Checkpoint 91 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch91.pth
# Epoch 91: [4/4] Loss: 0.252
# Epoch 91: [4/4] Loss: 0.252
# Epoch 91: [4/4] Loss: 0.239
# Epoch 91: [4/4] Loss: 0.232
# Dice: 0.679  Val Loss: 0.279
# Checkpoint 92 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch92.pth
# Epoch 92: [4/4] Loss: 0.264
# Epoch 92: [4/4] Loss: 0.243
# Epoch 92: [4/4] Loss: 0.243
# Epoch 92: [4/4] Loss: 0.237
# Dice: 0.662  Val Loss: 0.296
# Checkpoint 93 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch93.pth
# Epoch 93: [4/4] Loss: 0.184
# Epoch 93: [4/4] Loss: 0.188
# Epoch 93: [4/4] Loss: 0.215
# Epoch 93: [4/4] Loss: 0.227
# Dice: 0.658  Val Loss: 0.304
# Checkpoint 94 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch94.pth
# Epoch 94: [4/4] Loss: 0.217
# Epoch 94: [4/4] Loss: 0.222
# Epoch 94: [4/4] Loss: 0.215
# Epoch 94: [4/4] Loss: 0.221
# Dice: 0.680  Val Loss: 0.284
# Checkpoint 95 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch95.pth
# Epoch 95: [4/4] Loss: 0.210
# Epoch 95: [4/4] Loss: 0.224
# Epoch 95: [4/4] Loss: 0.221
# Epoch 95: [4/4] Loss: 0.222
# Dice: 0.676  Val Loss: 0.281
# Checkpoint 96 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch96.pth
# Epoch 96: [4/4] Loss: 0.185
# Epoch 96: [4/4] Loss: 0.193
# Epoch 96: [4/4] Loss: 0.209
# Epoch 96: [4/4] Loss: 0.213
# Dice: 0.650  Val Loss: 0.315
# Checkpoint 97 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch97.pth
# Epoch 97: [4/4] Loss: 0.260
# Epoch 97: [4/4] Loss: 0.232
# Epoch 97: [4/4] Loss: 0.215
# Epoch 97: [4/4] Loss: 0.207
# Dice: 0.672  Val Loss: 0.285
# Checkpoint 98 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch98.pth
# Epoch 98: [4/4] Loss: 0.203
# Epoch 98: [4/4] Loss: 0.180
# Epoch 98: [4/4] Loss: 0.207
# Epoch 98: [4/4] Loss: 0.212
# Dice: 0.634  Val Loss: 0.336
# Checkpoint 99 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch99.pth
# Epoch 99: [4/4] Loss: 0.238
# Epoch 99: [4/4] Loss: 0.236
# Epoch 99: [4/4] Loss: 0.228
# Epoch 99: [4/4] Loss: 0.211
# Dice: 0.668  Val Loss: 0.290
# Checkpoint 100 saved to /scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch100.pth

# %%
# Plot training loss and validation loss
plt.grid('on')
plt.plot(np.arange(NUM_EPOCH),train_loss_list,label='train_loss')
plt.plot(np.arange(NUM_EPOCH),val_loss_list, label='val_loss')
plt.legend()

# %% [markdown]
# # 6.Test

# %% [markdown]
# ## Reload the model

# %%
checkpoint_path = '/scratch/hp2173/mri/SelfAttention_U-net_Bothside_3D_model/MRISegEpoch82.pth'
net = SelfAttention_UNet(4,1).to(device)
net.load_state_dict(torch.load(checkpoint_path))
net.eval()
# Out:
# SelfAttention_UNet(
#   (down1): Sequential(
#     (0): Conv3d(4, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(8, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (pool1): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (down2): Sequential(
#     (0): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (pool2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (down3): Sequential(
#     (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): SelfAttention_3D(
#       (fc_q1): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_k1): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_v1): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_q2): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_k2): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_v2): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_q3): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_k3): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_v3): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_o): Linear(in_features=30, out_features=109350, bias=True)
#     )
#   )
#   (pool3): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bottom): Sequential(
#     (0): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): SelfAttention_3D(
#       (fc_q1): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_k1): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_v1): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_q2): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_k2): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_v2): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_q3): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_k3): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_v3): Linear(in_features=13068, out_features=10, bias=True)
#       (fc_o): Linear(in_features=30, out_features=13068, bias=True)
#     )
#   )
#   (upconv3): ConvTranspose3d(128, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2))
#   (up3): Sequential(
#     (0): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): SelfAttention_3D(
#       (fc_q1): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_k1): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_v1): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_q2): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_k2): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_v2): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_q3): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_k3): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_v3): Linear(in_features=109350, out_features=10, bias=True)
#       (fc_o): Linear(in_features=30, out_features=109350, bias=True)
#     )
#   )
#   (upconv2): ConvTranspose3d(64, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#   (up2): Sequential(
#     (0): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (upconv1): ConvTranspose3d(32, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2))
#   (up1): Sequential(
#     (0): Conv3d(32, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(16, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (4): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (out): Sequential(
#     (0): Conv3d(8, 1, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): Sigmoid()
#   )
# )

# %% [markdown]
# ## Reload the data with mask1 and mask2

# %%
test_dataset_mask1 = MRIDataset(test_img_list, test_label1_list, test_label2_list, RULE = 'mask1', IF_TRAIN= False)
test_dataset_mask2 = MRIDataset(test_img_list, test_label1_list, test_label2_list, RULE = 'mask2', IF_TRAIN= False)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]<ipython-input-7-976d5a4983b3>:25: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2f = torch.Tensor(nib.load(self.mri_path_list[idx][0]).get_data())
# <ipython-input-7-976d5a4983b3>:28: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t1w = torch.Tensor(nib.load(self.mri_path_list[idx][1]).get_data())
# <ipython-input-7-976d5a4983b3>:31: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_pd = torch.Tensor(nib.load(self.mri_path_list[idx][2]).get_data())
# <ipython-input-7-976d5a4983b3>:34: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2w = torch.Tensor(nib.load(self.mri_path_list[idx][3]).get_data())
# <ipython-input-3-527bb657da25>:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1=nib.load(mask1_path).get_data()
# <ipython-input-3-527bb657da25>:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2=nib.load(mask2_path).get_data()
# <ipython-input-7-976d5a4983b3>:40: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask1 = torch.Tensor(nib.load(self.label1_path_list[idx]).get_data())
# <ipython-input-7-976d5a4983b3>:41: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mask2 = torch.Tensor(nib.load(self.label2_path_list[idx]).get_data())
# 100%|██████████| 2/2 [00:28<00:00, 14.48s/it]
# 100%|██████████| 2/2 [00:28<00:00, 14.05s/it]

# %%
test_loader_mask1 = torch.utils.data.DataLoader(test_dataset_mask1, 
                                         batch_size=BATCH_SIZE, 
                                         shuffle=False, 
                                         num_workers=0)
test_loader_mask2 = torch.utils.data.DataLoader(test_dataset_mask2, 
                                         batch_size=BATCH_SIZE, 
                                         shuffle=False, 
                                         num_workers=0)

# %% [markdown]
# ## Test with mask1 and mask2

# %%
test_loss, test_dice = eval_epoch(net, test_loader_mask1, dice_coeff, criterion)
test_loss, test_dice = eval_epoch(net, test_loader_mask2, dice_coeff, criterion)
# Out:
# Dice: 0.761  Val Loss: 0.196
# Dice: 0.777  Val Loss: 0.194

# %% [markdown]
# ## Dispaly the output mask

# %%
img, mask1 = test_dataset_mask1[0]
img, mask2 = test_dataset_mask2[0]
result = net(img.unsqueeze(0).to(device)).detach()
mask_pred = result.cpu().numpy()[0,0,:,:,:]
mask_pred[mask_pred>0.2] = 1
mask_pred[mask_pred<=0.2] = 0
print(mask_pred.shape)
# Out:
# (181, 217, 181)

# %%
plt.figure(figsize = (16,32))
plt.subplot(1,7,1)
plt.imshow(img[0,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('T1-weighted')
plt.subplot(1,7,2)
plt.imshow(img[1,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('T2-weighted')
plt.subplot(1,7,3)
plt.imshow(img[2,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('PD-weighted')
plt.subplot(1,7,4)
plt.imshow(img[3,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('T2-weighted FLAIR')
plt.subplot(1,7,5)
plt.imshow(mask1.cpu().numpy()[:,:,90],'gray')
plt.title('mask1')
plt.subplot(1,7,6)
plt.imshow(mask1.cpu().numpy()[:,:,90],'gray')
plt.title('mask2')
plt.subplot(1,7,7)
plt.imshow(mask_pred[:,:,90],'gray')
plt.title('mask_pred')

print('Manual Volume for mask1:',mask1.cpu().numpy().sum())
print('Manual Volume for mask2:',mask2.cpu().numpy().sum())
print('Segmentation Volume:',mask_pred.sum())
# Out:
# Manual Volume for mask1: 16426.0
# Manual Volume for mask2: 18972.0
# Segmentation Volume: 18131.0

# %%
### img, mask1 = test_dataset_mask1[1]
img, mask2 = test_dataset_mask2[1]
result = net(img.unsqueeze(0).to(device)).detach()
mask_pred = result.cpu().numpy()[0,0,:,:,:]
mask_pred[mask_pred>0.1] = 1
mask_pred[mask_pred<=0.1] = 0
print(mask_pred.shape)
# Out:
# (181, 217, 181)

# %%
plt.figure(figsize = (16,32))
plt.subplot(1,7,1)
plt.imshow(img[0,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('T1-weighted')
plt.subplot(1,7,2)
plt.imshow(img[1,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('T2-weighted')
plt.subplot(1,7,3)
plt.imshow(img[2,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('PD-weighted')
plt.subplot(1,7,4)
plt.imshow(img[3,:,:,:].cpu().numpy()[:,:,90],'gray')
plt.title('T2-weighted FLAIR')
plt.subplot(1,7,5)
plt.imshow(mask1.cpu().numpy()[:,:,90],'gray')
plt.title('mask1')
plt.subplot(1,7,6)
plt.imshow(mask1.cpu().numpy()[:,:,90],'gray')
plt.title('mask2')
plt.subplot(1,7,7)
plt.imshow(mask_pred[:,:,90],'gray')
plt.title('mask_pred')

print('Manual Volume for mask1:',mask1.cpu().numpy().sum())
print('Manual Volume for mask2:',mask2.cpu().numpy().sum())
print('Segmentation Volume:',mask_pred.sum())
# Out:
# Manual Volume for mask1: 16426.0
# Manual Volume for mask2: 7265.0
# Segmentation Volume: 13507.0

# %% [markdown]
# ## Comparing with original and preprocessed

# %%
test_datapath = '/scratch/hp2173/testdata_website'

# %%
class MRITestDataset(Dataset):
    def __init__(self, img_path_list, IF_TRAIN= False):
        self.mri_path_list = img_path_list
        self.IF_TRAIN = IF_TRAIN
        #self.transform=transforms.Compose([transforms.Normalize((0.5,),(0.5,))])
        self.mri_list = self.preprocess() 

    def __len__(self):
        return len(self.mri_list)

    def preprocess(self):
        mri_list = []
        for idx in tqdm(range(len(self.mri_path_list))):
            mri_t2f = torch.Tensor(nib.load(self.mri_path_list[idx][0]).get_data())
            mri_t2f = (mri_t2f-mri_t2f.min())/(mri_t2f.max()-mri_t2f.min())
            
            mri_t1w = torch.Tensor(nib.load(self.mri_path_list[idx][1]).get_data())
            mri_t1w = (mri_t1w-mri_t1w.min())/(mri_t1w.max()-mri_t1w.min())
            
            mri_pd = torch.Tensor(nib.load(self.mri_path_list[idx][2]).get_data())
            mri_pd = (mri_pd-mri_pd.min())/(mri_pd.max()-mri_pd.min())
            
            mri_t2w = torch.Tensor(nib.load(self.mri_path_list[idx][3]).get_data())
            mri_t2w = (mri_t2w-mri_t2w.min())/(mri_t2w.max()-mri_t2w.min())
            
            mri = torch.cat((mri_t1w.unsqueeze(0),mri_t2w.unsqueeze(0),mri_pd.unsqueeze(0),mri_t2f.unsqueeze(0)),axis=0)
        
            
            mri_list.append(mri)

        return mri_list

    def __getitem__ (self,idx):
        img = self.mri_list[idx]
        return img

# %%
second_testing_path_list = []
for i in range(1,15):
    if i<10:
        second_testing_path_list.append('test0' + str(i) + '/')
    else:
        second_testing_path_list.append('test' + str(i) + '/')
        
print(second_testing_path_list)
mri_test_list = []

for i in range(14):
    timepoint1_path = os.path.join(test_datapath, second_testing_path_list[i], 'preprocessed/*_01_*.nii')
    timepoint2_path = os.path.join(test_datapath, second_testing_path_list[i], 'preprocessed/*_02_*.nii')
    timepoint3_path = os.path.join(test_datapath, second_testing_path_list[i], 'preprocessed/*_03_*.nii')
    timepoint4_path = os.path.join(test_datapath, second_testing_path_list[i], 'preprocessed/*_04_*.nii')
    if (i==1 or i==9 or i==10 or i==13):
        timepoint5_path = os.path.join(test_datapath, second_testing_path_list[i], 'preprocessed/*_05_*.nii')
    if i==9: 
        timepoint6_path = os.path.join(test_datapath, second_testing_path_list[i], 'preprocessed/*_06_*.nii') 
        print(timepoint6_path)
    
    timepoint1_list = sorted(glob.glob(timepoint1_path))
    timepoint2_list = sorted(glob.glob(timepoint2_path))
    timepoint3_list = sorted(glob.glob(timepoint3_path))
    timepoint4_list = sorted(glob.glob(timepoint4_path))

    
    if (i==1 or i==9 or i==10 or i==13):
        timepoint5_list = sorted(glob.glob(timepoint5_path))
    if i==9:
        timepoint6_list = sorted(glob.glob(timepoint6_path))
    
    mri_test_list.append(timepoint1_list)
    mri_test_list.append(timepoint2_list)
    mri_test_list.append(timepoint3_list)
    mri_test_list.append(timepoint4_list)

    if (i==1 or i==9 or i==10 or i==13):
        mri_test_list.append(timepoint5_list)

    if i==9:
        mri_test_list.append(timepoint6_list)
        

print('Data Collected:', len(mri_test_list))
# Out:
# ['test01/', 'test02/', 'test03/', 'test04/', 'test05/', 'test06/', 'test07/', 'test08/', 'test09/', 'test10/', 'test11/', 'test12/', 'test13/', 'test14/']
# /scratch/hp2173/testdata_website/test10/preprocessed/*_06_*.nii
# Data Collected: 61

# %%
test_dataset = MRITestDataset(mri_test_list, IF_TRAIN= True)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]<ipython-input-90-cca191b18e00>:14: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2f = torch.Tensor(nib.load(self.mri_path_list[idx][0]).get_data())
# <ipython-input-90-cca191b18e00>:17: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t1w = torch.Tensor(nib.load(self.mri_path_list[idx][1]).get_data())
# <ipython-input-90-cca191b18e00>:20: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_pd = torch.Tensor(nib.load(self.mri_path_list[idx][2]).get_data())
# <ipython-input-90-cca191b18e00>:23: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   mri_t2w = torch.Tensor(nib.load(self.mri_path_list[idx][3]).get_data())
# 100%|██████████| 61/61 [00:40<00:00,  1.51it/s]

# %%
test_loader = torch.utils.data.DataLoader(test_dataset, 
                                         batch_size=1, 
                                         shuffle=False, 
                                         num_workers=0)

# %%
def pre_and_save(net, dataloader):
    net = net.eval()
    num_list = [4,5,4,4,4,4,4,4,4,6,5,4,4,5]
    cnt_num = 0;
    cnt = 0;
    for i, test_input in enumerate(dataloader):
        test_input = test_input.to(device)
        with torch.no_grad():
            pred = net(test_input[0].unsqueeze(0).to(device)).detach()
            pred[pred>0.4] = 1
            pred[pred<=0.4] = 0
            pred = pred.cpu().numpy().squeeze()
            new_image = nib.Nifti1Image(pred, np.eye(4)) 
            
        if (cnt == num_list[cnt_num]):
            cnt_num += 1
            cnt = 0;
        if i < 37:
            nib.save(new_image, '/scratch/hp2173/mri/results/self_attention_bothside_3d_unet/' + 'test0' + str(cnt_num+1) + '_0' + str(cnt+1)+ '_NYU.nii')
        else:
            nib.save(new_image, '/scratch/hp2173/mri/results/self_attention_bothside_3d_unet/' + 'test' + str(cnt_num+1) + '_0' + str(cnt+1)+ '_NYU.nii')
        cnt = cnt+1

# %%
num_list = [4,5,4,4,4,4,4,4,4,6,5,4,4,5]
print(sum(num_list))
# Out:
# 61

# %%
pre_and_save(net, test_loader)

# %%
testimg = nib.load('/scratch/hp2173/mri/results/self_attention_bothside_3d_unet/test12_02_NYU.nii').get_data()
print(testimg.shape)
plt.imshow(testimg[:,:,90], cmap='gray')
# Out:
# (181, 217, 181)
# <ipython-input-103-58db3c1b2abc>:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   testimg = nib.load('/scratch/hp2173/mri/results/self_attention_bothside_3d_unet/test12_02_NYU.nii').get_data()
